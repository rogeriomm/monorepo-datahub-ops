# %% [markdown]
#    * https://cert-manager.io/docs/installation/helm/

# %%
# !kubecolor -n cert-manager get all
# Out:
# NAME                                           READY   STATUS    RESTARTS       AGE
# pod/cert-manager-7d67448f59-7m477              1/1     Running   18 (52m ago)   14d
# pod/cert-manager-7d67448f59-tmdp8              1/1     Running   20 (52m ago)   14d
# pod/cert-manager-cainjector-666b8b6b66-hpt22   1/1     Running   19 (52m ago)   14d
# pod/cert-manager-webhook-78cb4cf989-hfswh      1/1     Running   18 (52m ago)   14d
#
# NAME                              TYPE        CLUSTER-IP     EXTERNAL-IP   PORT(S)            AGE
# service/cert-manager              ClusterIP   10.43.215.82   <none>        9402/TCP           14d
# service/cert-manager-cainjector   ClusterIP   10.43.161.64   <none>        9402/TCP           14d
# service/cert-manager-webhook      ClusterIP   10.43.177.67   <none>        443/TCP,9402/TCP   14d
#
# NAME                                      READY   UP-TO-DATE   AVAILABLE   AGE
# deployment.apps/cert-manager              2/2     2            2           14d
# ...
