# %%
# !kubecolor -n zeppelin get all
# Out:
# NAME                                   READY   STATUS    RESTARTS       AGE
# pod/zeppelin-server-5ccd88cdcc-pw47v   3/3     Running   54 (40m ago)   14d
#
# NAME                      TYPE        CLUSTER-IP      EXTERNAL-IP   PORT(S)            AGE
# service/zeppelin-server   ClusterIP   10.43.232.115   <none>        80/TCP,12320/TCP   14d
#
# NAME                              READY   UP-TO-DATE   AVAILABLE   AGE
# deployment.apps/zeppelin-server   1/1     1            1           14d
#
# NAME                                         DESIRED   CURRENT   READY   AGE
# replicaset.apps/zeppelin-server-5ccd88cdcc   1         1         1       14d
