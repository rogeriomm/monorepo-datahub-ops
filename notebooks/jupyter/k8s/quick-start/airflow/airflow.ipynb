# %%
# !kubecolor -n airflow get all
# Out:
# NAME                                              READY   STATUS    RESTARTS       AGE
# pod/airflow-helm-db-migrations-7fbdd9868f-g4kp9   1/1     Running   35 (48m ago)   13d
# pod/airflow-helm-flower-7f95684745-sc66w          1/1     Running   17 (48m ago)   13d
# pod/airflow-helm-pgbouncer-7757d9d46b-cs6gr       1/1     Running   32 (48m ago)   13d
# pod/airflow-helm-postgresql-0                     1/1     Running   17 (48m ago)   13d
# pod/airflow-helm-redis-master-0                   1/1     Running   17 (48m ago)   13d
# pod/airflow-helm-scheduler-5dc45564ff-22jzz       2/2     Running   55 (48m ago)   13d
# pod/airflow-helm-sync-users-7c5dc9966f-scf24      1/1     Running   35 (48m ago)   13d
# pod/airflow-helm-triggerer-5d5d75f697-gkzhr       1/1     Running   39 (48m ago)   13d
# pod/airflow-helm-web-56846dfb4f-77l6h             1/1     Running   47 (48m ago)   13d
# pod/airflow-helm-worker-0                         2/2     Running   34 (48m ago)   13d
#
# ...
