# %%
# !ipython profile create

# %%
# !jupyter kernelspec list
# Out:
# Available kernels:
#   python3    /home/rogermm/git/monorepo-datahub-ops/.venv/share/jupyter/kernels/python3

# %%
# !ipython -c "import sys, json; print(json.dumps(sys.path, indent=2))"
# Out:
# /home/rogermm/.local/share/mise/installs/python/3.12.10/lib/python3.12/site-packages/IPython/core/interactiveshell.py:958: UserWarning: Attempting to work in a virtualenv. If you encounter problems, please install IPython inside the virtualenv.
#   warn(
# [
#   "/home/rogermm/git/monorepo-datahub-ops/.venv/lib/python3.12/site-packages",
#   "/home/rogermm/.local/share/mise/installs/python/3.12.10/bin",
#   "/home/rogermm/git/monorepo-datahub-ops",
#   "/home/rogermm/git/monorepo-datahub-ops/src-samples/rust/app-1/src",
#   "/home/rogermm/git/monorepo-datahub-ops/src-samples/rust/app-2/src",
#   "/home/rogermm/git/monorepo-datahub-ops/src-samples/rust/app-3/src",
#   "/home/rogermm/git/monorepo-datahub-ops/src-samples/rust/app-4/src",
#   "/home/rogermm/.local/share/JetBrains/Toolbox/apps/pycharm-professional/plugins/python-ce/helpers/pydev",
#   "/home/rogermm/.local/share/JetBrains/Toolbox/apps/pycharm-professional/plugins/python-ce/helpers/jupyter_debug",
# ...

# %%
# !python -c "import sys; print(sys.path)"
# Out:
# ['', '/home/rogermm/git/monorepo-datahub-ops', '/home/rogermm/git/monorepo-datahub-ops/src-samples/rust/app-1/src', '/home/rogermm/git/monorepo-datahub-ops/src-samples/rust/app-2/src', '/home/rogermm/git/monorepo-datahub-ops/src-samples/rust/app-3/src', '/home/rogermm/git/monorepo-datahub-ops/src-samples/rust/app-4/src', '/home/rogermm/.local/share/JetBrains/Toolbox/apps/pycharm-professional/plugins/python-ce/helpers/pydev', '/home/rogermm/.local/share/JetBrains/Toolbox/apps/pycharm-professional/plugins/python-ce/helpers/jupyter_debug', '/home/rogermm/.local/share/mise/installs/python/3.12.10/lib/python312.zip', '/home/rogermm/.local/share/mise/installs/python/3.12.10/lib/python3.12', '/home/rogermm/.local/share/mise/installs/python/3.12.10/lib/python3.12/lib-dynload', '/home/rogermm/.local/share/mise/installs/python/3.12.10/lib/python3.12/site-packages']

# %% [markdown]
# Jupyter Python Packages

# %%
import pkg_resources
import sys

installed_packages = sorted(
    [(d.project_name, d.version) for d in pkg_resources.working_set]
)

print(f"Python version: {sys.version}")

for name, version in installed_packages:
    print(f"{name}=={version}")
# Out:
# Python version: 3.12.10 (main, May 22 2025, 01:59:14) [Clang 20.1.4 ]
# MarkupSafe==3.0.2
# PyYAML==6.0.2
# Send2Trash==1.8.3
# anyio==4.9.0
# argon2-cffi==23.1.0
# argon2-cffi-bindings==21.2.0
# arrow==1.3.0
# asttokens==3.0.0
# async-lru==2.0.5
# attrs==25.3.0
# autocommand==2.2.2
# babel==2.17.0
# backports.tarfile==1.2.0
# beautifulsoup4==4.13.4
# bleach==6.2.0
# certifi==2025.4.26
# cffi==1.17.1
# charset-normalizer==3.4.2
# comm==0.2.2
# debugpy==1.8.14
# decorator==5.2.1
# defusedxml==0.7.1
# executing==2.2.0
# fastjsonschema==2.21.1
# fqdn==1.5.1
# h11==0.16.0
# httpcore==1.0.9
# httpx==0.28.1
# idna==3.10
# importlib-metadata==8.0.0
# inflect==7.3.1
# ipykernel==6.29.5
# ipython==9.2.0
# ipython-pygments-lexers==1.1.1
# isoduration==20.11.0
# jaraco.collections==5.1.0
# jaraco.context==5.3.0
# jaraco.functools==4.0.1
# jaraco.text==3.12.1
# jedi==0.19.2
# jinja2==3.1.6
# json5==0.12.0
# jsonpointer==3.0.0
# jsonschema==4.24.0
# jsonschema-specifications==2025.4.1
# ...

# %%
# !$VIRTUAL_ENV/bin/ipython -c "import sys, json; print(json.dumps(sys.path, indent=2))"
# Out:
# [
#   "/home/rogermm/git/monorepo-datahub-ops/.venv/bin",
#   "/home/rogermm/git/monorepo-datahub-ops",
#   "/home/rogermm/git/monorepo-datahub-ops/src-samples/rust/app-1/src",
#   "/home/rogermm/git/monorepo-datahub-ops/src-samples/rust/app-2/src",
#   "/home/rogermm/git/monorepo-datahub-ops/src-samples/rust/app-3/src",
#   "/home/rogermm/git/monorepo-datahub-ops/src-samples/rust/app-4/src",
#   "/home/rogermm/.local/share/JetBrains/Toolbox/apps/pycharm-professional/plugins/python-ce/helpers/pydev",
#   "/home/rogermm/.local/share/JetBrains/Toolbox/apps/pycharm-professional/plugins/python-ce/helpers/jupyter_debug",
#   "/home/rogermm/.local/share/mise/installs/python/3.12.10/lib/python312.zip",
#   "/home/rogermm/.local/share/mise/installs/python/3.12.10/lib/python3.12",
#   "/home/rogermm/.local/share/mise/installs/python/3.12.10/lib/python3.12/lib-dynload",
#   "",
#   "/home/rogermm/git/monorepo-datahub-ops/.venv/lib/python3.12/site-packages"
# ]

# %%
# !source $VIRTUAL_ENV/bin/activate && which pip && which python && which ipython
# Out:
# /home/rogermm/git/monorepo-datahub-ops/.venv/bin/pip
# /home/rogermm/git/monorepo-datahub-ops/.venv/bin/python
# /home/rogermm/git/monorepo-datahub-ops/.venv/bin/ipython

# %%
# !which pip && which python && which ipython
# Out:
# /home/rogermm/.local/share/mise/installs/python/3.12.10/bin/pip
# /home/rogermm/.local/share/mise/installs/python/3.12.10/bin/python
# /home/rogermm/.local/share/mise/installs/python/3.12.10/bin/ipython

# %%
# !source $VIRTUAL_ENV/bin/activate && $VIRTUAL_ENV/bin/ipython -c "import sys, json; print(json.dumps(sys.path, indent=2))"
# Out:
# [
#   "/home/rogermm/git/monorepo-datahub-ops/.venv/bin",
#   "/home/rogermm/git/monorepo-datahub-ops",
#   "/home/rogermm/git/monorepo-datahub-ops/src-samples/rust/app-1/src",
#   "/home/rogermm/git/monorepo-datahub-ops/src-samples/rust/app-2/src",
#   "/home/rogermm/git/monorepo-datahub-ops/src-samples/rust/app-3/src",
#   "/home/rogermm/git/monorepo-datahub-ops/src-samples/rust/app-4/src",
#   "/home/rogermm/.local/share/JetBrains/Toolbox/apps/pycharm-professional/plugins/python-ce/helpers/pydev",
#   "/home/rogermm/.local/share/JetBrains/Toolbox/apps/pycharm-professional/plugins/python-ce/helpers/jupyter_debug",
#   "/home/rogermm/.local/share/mise/installs/python/3.12.10/lib/python312.zip",
#   "/home/rogermm/.local/share/mise/installs/python/3.12.10/lib/python3.12",
#   "/home/rogermm/.local/share/mise/installs/python/3.12.10/lib/python3.12/lib-dynload",
#   "",
#   "/home/rogermm/git/monorepo-datahub-ops/.venv/lib/python3.12/site-packages"
# ]

# %%
# !source $VIRTUAL_ENV/bin/activate && $VIRTUAL_ENV/bin/pip list | grep ipy
# Out:
# ipykernel                 6.29.5
# ipython                   9.2.0
# ipython_pygments_lexers   1.1.1
