# %%
import squid
#dbutils.library.restartPython()

# %%
import squid.databricks.postgres

squid.databricks.postgres.is_good()

# %%
squid.databricks.postgres.load()

# %%
squid.databricks.postgres.postgres_user

# %%
import databricks.sdk
