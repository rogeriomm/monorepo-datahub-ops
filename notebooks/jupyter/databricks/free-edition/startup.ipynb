# %% [markdown]
# # Start up

# %%
# %sql SHOW VOLUMES IN workspace.default;

# %%
# %sql DESCRIBE VOLUME workspace.default.on_premises_certificates;

# %%
# %sql DESCRIBE VOLUME workspace.default.on_premises_artifacts;

# %%
# !ls /Volumes/workspace/default/on_premises_artifacts/python-wheels/

# %%
#%uv pip install /Volumes/workspace/default/on_premises_artifacts/python-wheels/framework-0.1.0-py3-none-any.whl
