# %%
# %run ./lib

# %%
# !find /databricks

# %%
# !find /databricks -type d -not -path '*/__pycache__*'

# %%
# !echo $SPARK_HOME

# %%
# !find /databricks/spark/

# %%
# %%bash
# whoami
# ls -la $SPARK_HOME
# cat /etc/group | grep spark-users

# %%
# %%bash
# touch $SPARK_HOME/work/testing
# ls -la $SPARK_HOME/work
# ls -la $SPARK_HOME/python

# %%
# !pyenv global

# %%
# %run ./databricks-process
