# %% [markdown]
#  - https://docs.databricks.com/aws/en/release-notes/serverless/environment-version

# %%
# !hostname

# %%
print("test2")

# %%
# !hostname

# %%
# !ip a

# %%
# !netstat -an

# %%
# %ls /

# %%
# %cat /proc/cpuinfo

# %%
# %sh
cat /proc/1/cgroup

# %%
# %sh
curl https://www.google.com

# %%
# %sh free

# %%
# %sh ps -ef

# %%
# !file /local_disk0/.ephemeral_nfs/envs/pythonEnv-ac330b5f-7e2e-45a7-b936-89eb1429fa57/bin/python /databricks/python_shell/scripts/db_ipykernel_launcher.py

# %%
# !python --version

# %%
# !mount

# %%
# !ls /Workspace/

# %%
# !find /Workspace/

# %%
# !whoami

# %%
# !ls /Volumes

# %%
# !find /Volumes/prod_postgres_catalog

# %%
# !find /Volumes/system

# %%
# !find /Volumes/workspace

# %%
# !ls -la /Workspace/

# %%
import humanize

# %%
# !java --version
