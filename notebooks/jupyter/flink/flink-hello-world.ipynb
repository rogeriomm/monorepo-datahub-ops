# %% [markdown]
#  - [SeaweedFS filer](http://seaweedfs-filer.localhost:8080)

# %%
s3="AWS_ACCESS_KEY_ID=admin AWS_SECRET_ACCESS_KEY=secret2 AWS_CA_BUNDLE=/etc/seaweedfs/tls/ca.crt AWS_REGION=us-east-1 aws --endpoint-url https://seaweedfs:8333 s3"

# %%
# !{s3} ls
# Out:
# 2026-09-11 16:22:02 delta-lakehouse
# 2026-09-11 18:47:34 my-bucket
# 2026-09-09 12:27:26 trino-lakehouse

# %%
# !{s3} ls --recursive s3://delta-lakehouse
# Out:
# 2026-09-11 19:36:30       1059 flink-delta-smoke/0ef2fdc623a3274f7829f9e4b69c5a84-0-0/69c13963-4b39-402e-80e4-c2c9355cabff-000.parquet
# 2026-09-11 19:34:23          0 flink-delta-smoke/_delta_log/
# 2026-09-11 19:34:23       2197 flink-delta-smoke/_delta_log/00000000000000000000.crc
# 2026-09-11 19:34:23        926 flink-delta-smoke/_delta_log/00000000000000000000.json
# 2026-09-11 19:36:30       2275 flink-delta-smoke/_delta_log/00000000000000000001.crc
# 2026-09-11 19:36:30       1417 flink-delta-smoke/_delta_log/00000000000000000001.json
# 2026-09-11 19:34:23          0 flink-delta-smoke/_delta_log/_sidecars/
