# %%
# !aws --version
# Out:
# aws-cli/2.36.10 Python/3.14.6 Linux/7.1.5-200.fc44.x86_64 exe/x86_64.ubuntu.24

# %%
# !aws configure list-profiles
# Out:
# administrator

# %%
# !aws sts get-caller-identity --profile administrator
# Out:
# aws: [ERROR]: Invalid endpoint: https://sts..amazonaws.com

# %%
# !unset AWS_REGION AWS_DEFAULT_REGION AWS_ACCESS_KEY_ID AWS_SECRET_ACCESS_KEY AWS_SESSION_TOKEN && \
aws sts get-caller-identity --profile administrator | jq
# Out:
# {
#   "UserId": "AIDAYQ52O37GVJLANRMAQ",
#   "Account": "586117210061",
#   "Arn": "arn:aws:iam::586117210061:user/administrator"
# }
