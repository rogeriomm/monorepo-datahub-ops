# %%
# !aws --version
# Out:
# aws-cli/2.36.9 Python/3.14.6 Linux/7.1.5-200.fc44.x86_64 exe/x86_64.ubuntu.24

# %%
# !aws configure list-profiles

# %%
# !aws sts get-caller-identity --profile my-profile
# Out:
# aws: [ERROR]: The config profile (my-profile) could not be found
