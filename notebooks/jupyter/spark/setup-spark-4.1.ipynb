# %% [markdown]
#  - https://spark.apache.org/docs/4.1.2/api/python/getting_started/install.html

# %%
# !PYSPARK_HADOOP_VERSION=3 pip install "pyspark==4.1.2"
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 455.4/455.4 MB 19.2 MB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 203.0/203.0 kB 50.6 MB/s eta 0:00:00
# ...
#   Created wheel for pyspark: filename=pyspark-4.1.2-py2.py3-none-any.whl size=456079457 sha256=7d8d84f8687c4e90c3f04600d0d618b975da08a44f2d74a0a731c28c14e28275
#   Stored in directory: /home/jovyan/.cache/pip/wheels/aa/47/92/eb5b190144c2b3c17639bab37558bf35cda504b4ad70fe096e
# Successfully built pyspark
# ...
#   Attempting uninstall: pyspark
#     Found existing installation: pyspark 3.5.0
#     Can't uninstall 'pyspark'. No files were found to uninstall.
# ...
