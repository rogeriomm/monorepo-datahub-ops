# %%
import pyspark

# %%
def get_spark_major_minor_version() -> str:
    version_parts = pyspark.__version__.split(".")
    return ".".join(version_parts[:2])

# %%
get_spark_major_minor_version()
# Out:
# '3.5'

# %%
version_parts = pyspark.__version__.split(".")

# %%
version_parts
# Out:
# ['3', '5', '0']
