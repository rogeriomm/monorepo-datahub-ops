# %%
# !pip install pandas parquet-tools kagglehub contexttimer rich findspark humanize
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.2/137.2 kB 2.8 MB/s eta 0:00:00a 0:00:01
# ...

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("stefanoleone992/fifa-23-complete-player-dataset")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /home/jovyan/.cache/kagglehub/datasets/stefanoleone992/fifa-23-complete-player-dataset/versions/1

# %%
# !ls {path}
# Out:
#  female_coaches.csv	        female_teams.csv  'male_players (legacy).csv'
#  female_players.csv	        male_coaches.csv   male_teams.csv
# 'female_players (legacy).csv'   male_players.csv   parquet
