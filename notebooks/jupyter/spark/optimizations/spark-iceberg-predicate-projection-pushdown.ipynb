# %%
# %run ../start.ipynb --data-format iceberg
# Out:
# Spark version: 4.1.2, Driver memory: 16g, Executor memory: 8g, Data format: iceberg
# Spark packages: org.apache.iceberg:iceberg-spark-runtime-4.1_2.13:1.11.0
# Spark extensions: org.apache.iceberg.spark.extensions.IcebergSparkSessionExtensions
# Spark catalog configs: {'spark.sql.catalog.local': 'org.apache.iceberg.spark.SparkCatalog', 'spark.sql.catalog.local.type': 'hadoop', 'spark.sql.catalog.local.warehouse': 'file:///home/jovyan/datalake/iceberg-warehouse'}
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://127.0.0.1:4042">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v4.1.2</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[2]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>main</code></dd>
#             </dl>
#         </div>
#
#             </div>
# ...
