# %%
# %pip install sparkmonitor
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 7.0 MB/s  0:00:00 eta 0:00:01m
# ...
# Note: you may need to restart the kernel to use updated packages.
