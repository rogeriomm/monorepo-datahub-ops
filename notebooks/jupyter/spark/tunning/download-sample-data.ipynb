# %% [markdown]
#  - https://www.kaggle.com/datasets

# %%
def kaggle_download(dataset: str):
    import kagglehub
    
    output_dir = f"/home/jovyan/work/data/kaggle/datasets/{dataset}"
    
    # Download latest version
    path = kagglehub.dataset_download(dataset,
                                      output_dir=output_dir,
                                      force_download=False
                                      )

# %%
kaggle_download("stefanoleone992/fifa-23-complete-player-dataset")
# Out:
# Downloading to /home/jovyan/work/data/kaggle/datasets/stefanoleone992/fifa-23-complete-player-dataset/1.archive...
# 100%|██████████| 1.58G/1.58G [00:54<00:00, 30.9MB/s]
# Extracting files...
