# %% [markdown]
#  - https://docs.getdbt.com/docs/local/install-dbt

# %%
# !python -m pip install dbt
# Out:
# ...
#   Using cached dbt-1.0.0.40.18-py3-none-any.whl
# ...

# %%
# !dbt --version
# Out:
# dbt Cloud CLI - 0.40.18 (aa58f643af1725e279e559883b75cf9e26596d51 2026-06-18T20:34:06Z)

# %%
# !{sys.executable} --version
# Out:
# Python 3.13.14

# %%
# !which dbt
# Out:
# /home/jovyan/.local/share/mise/installs/python/latest/bin/dbt

# %%
# !dbt system install-drivers
# Out:
# Error: unknown command "system" for "dbt"
# Run 'dbt --help' for usage.

# %% [markdown]
# # Install DBT Spark driver
#  - https://docs.getdbt.com/docs/dbt-versions/compatible-track-changelog?utm_source=chatgpt.com&version=2.0&name=v2
#    - https://github.com/dbt-labs/dbt-adapters/tree/stable/dbt-spark
#      - dbt-spark now supports Spark 3.3.2

# %%
# !{sys.executable} -m pip install "dbt-core==1.10.*" "dbt-spark[PyHive]==1.9.*"
