# %%
# %tsql SELECT version()
# Out:
#   _col0
# 0   483

# %%
# %tsql SELECT * FROM system.runtime.queries
# Out:
#                        query_id     state          user               source  \
# 0   20260916_164444_00001_9kwgp  FINISHED  trino-client  trino-python-client
# 1   20260916_164618_00007_9kwgp  FINISHED  trino-client  trino-python-client
# 2   20260916_164446_00002_9kwgp  FINISHED  trino-client  trino-python-client
# 3   20260916_164448_00003_9kwgp  FINISHED  trino-client  trino-python-client
# 4   20260916_164556_00005_9kwgp  FINISHED  trino-client  trino-python-client
# 5   20260916_164441_00000_9kwgp  FINISHED  trino-client  trino-python-client
# 6   20260916_175738_00011_9kwgp   RUNNING  trino-client  trino-python-client
# 7   20260916_164611_00006_9kwgp  FINISHED  trino-client  trino-python-client
# 8   20260916_164625_00008_9kwgp  FINISHED  trino-client  trino-python-client
# 9   20260916_164536_00004_9kwgp  FINISHED  trino-client  trino-python-client
# 10  20260916_173219_00009_9kwgp  FINISHED  trino-client  trino-python-client
# ...

# %%
# %%tsql
# SELECT *
# FROM iceberg.system.iceberg_tables
# Out:
# Empty DataFrame
# Columns: [table_schema, table_name]
# Index: []

# %%
# %%tsql
# SELECT table_catalog, table_schema, table_name, table_type
# FROM iceberg.information_schema.tables
# ORDER BY table_schema, table_name
# Out:
#   table_catalog        table_schema        table_name  table_type
# 0       iceberg  information_schema  applicable_roles  BASE TABLE
# 1       iceberg  information_schema           columns  BASE TABLE
# 2       iceberg  information_schema     enabled_roles  BASE TABLE
# 3       iceberg  information_schema             roles  BASE TABLE
# 4       iceberg  information_schema          schemata  BASE TABLE
# 5       iceberg  information_schema  table_privileges  BASE TABLE
# 6       iceberg  information_schema            tables  BASE TABLE
# 7       iceberg  information_schema             views  BASE TABLE
# 8       iceberg              system    iceberg_tables  BASE TABLE

# %%
# %tsql SHOW CATALOGS;
# Out:
#    Catalog
# 0    delta
# 1  iceberg
# 2   system
