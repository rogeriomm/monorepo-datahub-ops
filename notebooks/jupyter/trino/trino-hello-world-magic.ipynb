# %%
# %tsql SELECT version()
# Out:
#   _col0
# 0   483

# %%
# %tsql SELECT * FROM system.runtime.queries
# Out:
#                       query_id     state          user               source  \
# 0  20260916_123809_00000_3jarb  FINISHED  trino-client  trino-python-client
# 1  20260916_123827_00001_3jarb   RUNNING  trino-client  trino-python-client
#
#                                   query resource_group_id  queued_time_ms  \
# 0                      SELECT version()          [global]               4
# 1  SELECT * FROM system.runtime.queries          [global]               0
#
#    analysis_time_ms  planning_time_ms                          created  \
# 0                28                79 2026-09-16 12:38:09.164000+00:00
# 1                 9                12 2026-09-16 12:38:27.654000+00:00
#
#                            started                   last_heartbeat  \
# 0 2026-09-16 12:38:09.195000+00:00 2026-09-16 12:38:09.420000+00:00
# 1 2026-09-16 12:38:27.663000+00:00 2026-09-16 12:38:27.688000+00:00
#
#                                end error_type error_code
# 0 2026-09-16 12:38:09.408000+00:00       None       None
# 1                              NaT       None       None

# %%
# %%tsql
# SELECT *
# FROM iceberg.system.iceberg_tables
# Out:
# Empty DataFrame
# Columns: [table_schema, table_name]
# Index: []

# %%
# %%tsql
# SELECT table_catalog, table_schema, table_name, table_type
# FROM iceberg.information_schema.tables
# ORDER BY table_schema, table_name
# Out:
#   table_catalog        table_schema        table_name  table_type
# 0       iceberg  information_schema  applicable_roles  BASE TABLE
# 1       iceberg  information_schema           columns  BASE TABLE
# 2       iceberg  information_schema     enabled_roles  BASE TABLE
# 3       iceberg  information_schema             roles  BASE TABLE
# 4       iceberg  information_schema          schemata  BASE TABLE
# 5       iceberg  information_schema  table_privileges  BASE TABLE
# 6       iceberg  information_schema            tables  BASE TABLE
# 7       iceberg  information_schema             views  BASE TABLE
# 8       iceberg              system    iceberg_tables  BASE TABLE
