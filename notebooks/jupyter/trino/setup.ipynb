# %%
# %pip install trino
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [trino]
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip list | grep trino
# Out:
# trino                     0.339.0
