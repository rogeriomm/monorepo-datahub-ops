# %%
# %load_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %reload_ext autoreload
# %autoreload 2
import squid 
from squid.resources.trino import get_trino

# %%
conn = get_trino()
conn

# %%
cursor = conn.cursor()
cursor

# %%
cursor.execute("SELECT version()")
rows = cursor.fetchall()
display(rows)
# Out:
# [['483']]

# %%
cursor.execute("SELECT * FROM system.runtime.queries")
rows = cursor.fetchall()
display(rows)
# Out:
# [['20260904_140305_00008_hjr2u',
#   'FINISHED',
#   'trino-client',
#   'trino-python-client',
#   'SELECT version()',
#   ['global'],
#   1,
#   1,
#   4,
#   datetime.datetime(2026, 9, 4, 14, 3, 5, 698000, tzinfo=zoneinfo.ZoneInfo(key='UTC')),
#   datetime.datetime(2026, 9, 4, 14, 3, 5, 700000, tzinfo=zoneinfo.ZoneInfo(key='UTC')),
#   datetime.datetime(2026, 9, 4, 14, 3, 5, 711000, tzinfo=zoneinfo.ZoneInfo(key='UTC')),
#   datetime.datetime(2026, 9, 4, 14, 3, 5, 711000, tzinfo=zoneinfo.ZoneInfo(key='UTC')),
#   None,
#   None],
#  ['20260904_141020_00012_hjr2u',
#   'FINISHED',
#   'trino-client',
#   'trino-python-client',
#   'SELECT * FROM system.runtime.queries',
#   ['global'],
#   0,
#   1,
#   2,
#   datetime.datetime(2026, 9, 4, 14, 10, 20, 920000, tzinfo=zoneinfo.ZoneInfo(key='UTC')),
#   datetime.datetime(2026, 9, 4, 14, 10, 20, 922000, tzinfo=zoneinfo.ZoneInfo(key='UTC')),
#   datetime.datetime(2026, 9, 4, 14, 10, 20, 933000, tzinfo=zoneinfo.ZoneInfo(key='UTC')),
#   datetime.datetime(2026, 9, 4, 14, 10, 20, 933000, tzinfo=zoneinfo.ZoneInfo(key='UTC')),
#   None,
#   None],
#  ['20260904_135911_00007_hjr2u',
#   'FINISHED',
#   'trino-client',
#   'trino-python-client',
#   'SELECT version()',
#   ['global'],
#   0,
#   1,
#   3,
#   datetime.datetime(2026, 9, 4, 13, 59, 11, 380000, tzinfo=zoneinfo.ZoneInfo(key='UTC')),
#   datetime.datetime(2026, 9, 4, 13, 59, 11, 381000, tzinfo=zoneinfo.ZoneInfo(key='UTC')),
#   datetime.datetime(2026, 9, 4, 13, 59, 11, 391000, tzinfo=zoneinfo.ZoneInfo(key='UTC')),
#   datetime.datetime(2026, 9, 4, 13, 59, 11, 391000, tzinfo=zoneinfo.ZoneInfo(key='UTC')),
#   None,
#   None],
#  ['20260904_140336_00009_hjr2u',
#   'FINISHED',
#   'trino-client',
#   'trino-python-client',
#   'SELECT version()',
#   ['global'],
#   0,
#   1,
#   4,
#   datetime.datetime(2026, 9, 4, 14, 3, 36, 346000, tzinfo=zoneinfo.ZoneInfo(key='UTC')),
#   datetime.datetime(2026, 9, 4, 14, 3, 36, 347000, tzinfo=zoneinfo.ZoneInfo(key='UTC')),
#   datetime.datetime(2026, 9, 4, 14, 3, 36, 361000, tzinfo=zoneinfo.ZoneInfo(key='UTC')),
#   datetime.datetime(2026, 9, 4, 14, 3, 36, 360000, tzinfo=zoneinfo.ZoneInfo(key='UTC')),
#   None,
#   None],
#  ['20260904_123256_00004_hjr2u',
#   'FINISHED',
#   'trino-client',
#   'Apache Superset',
#   'SELECT\n  *\nFROM information_schema.tables\nLIMIT 1001',
#   ['global'],
#   0,
#   1,
#   5,
#   datetime.datetime(2026, 9, 4, 12, 32, 56, 778000, tzinfo=zoneinfo.ZoneInfo(key='UTC')),
#   datetime.datetime(2026, 9, 4, 12, 32, 56, 779000, tzinfo=zoneinfo.ZoneInfo(key='UTC')),
#   datetime.datetime(2026, 9, 4, 12, 32, 56, 875000, tzinfo=zoneinfo.ZoneInfo(key='UTC')),
#   datetime.datetime(2026, 9, 4, 12, 32, 56, 875000, tzinfo=zoneinfo.ZoneInfo(key='UTC')),
#   None,
#   None],
#  ['20260904_123253_00002_hjr2u',
#   'FINISHED',
#   'trino-client',
#   'Apache Superset',
#   'SELECT\n  *\nFROM information_schema.tables\nLIMIT 1001',
#   ['global'],
#   0,
#   2,
#   8,
#   datetime.datetime(2026, 9, 4, 12, 32, 53, 618000, tzinfo=zoneinfo.ZoneInfo(key='UTC')),
#   datetime.datetime(2026, 9, 4, 12, 32, 53, 620000, tzinfo=zoneinfo.ZoneInfo(key='UTC')),
#   datetime.datetime(2026, 9, 4, 12, 32, 53, 717000, tzinfo=zoneinfo.ZoneInfo(key='UTC')),
#   datetime.datetime(2026, 9, 4, 12, 32, 53, 717000, tzinfo=zoneinfo.ZoneInfo(key='UTC')),
#   None,
#   None],
#  ['20260904_141106_00014_hjr2u',
#   'FINISHED',
#   'trino-client',
#   'trino-python-client',
#   'SELECT * FROM system.runtime.queries',
#   ['global'],
#   0,
#   2,
#   5,
#   datetime.datetime(2026, 9, 4, 14, 11, 6, 977000, tzinfo=zoneinfo.ZoneInfo(key='UTC')),
#   datetime.datetime(2026, 9, 4, 14, 11, 6, 979000, tzinfo=zoneinfo.ZoneInfo(key='UTC')),
#   datetime.datetime(2026, 9, 4, 14, 11, 6, 994000, tzinfo=zoneinfo.ZoneInfo(key='UTC')),
#   datetime.datetime(2026, 9, 4, 14, 11, 6, 994000, tzinfo=zoneinfo.ZoneInfo(key='UTC')),
#   None,
#   None],
#  ['20260904_140557_00010_hjr2u',
#   'FINISHED',
#   'trino-client',
#   'trino-python-client',
#   'SELECT * FROM system.runtime.queries',
#   ['global'],
#   0,
#   3,
#   7,
#   datetime.datetime(2026, 9, 4, 14, 5, 57, 937000, tzinfo=zoneinfo.ZoneInfo(key='UTC')),
#   datetime.datetime(2026, 9, 4, 14, 5, 57, 940000, tzinfo=zoneinfo.ZoneInfo(key='UTC')),
#   datetime.datetime(2026, 9, 4, 14, 5, 57, 972000, tzinfo=zoneinfo.ZoneInfo(key='UTC')),
#   datetime.datetime(2026, 9, 4, 14, 5, 57, 974000, tzinfo=zoneinfo.ZoneInfo(key='UTC')),
#   None,
#   None],
#  ['20260904_141207_00015_hjr2u',
#   'FINISHED',
#   'trino-client',
#   'trino-python-client',
#   'SELECT * FROM system.runtime.queries',
#   ['global'],
#   0,
#   2,
#   4,
#   datetime.datetime(2026, 9, 4, 14, 12, 7, 912000, tzinfo=zoneinfo.ZoneInfo(key='UTC')),
#   datetime.datetime(2026, 9, 4, 14, 12, 7, 914000, tzinfo=zoneinfo.ZoneInfo(key='UTC')),
#   datetime.datetime(2026, 9, 4, 14, 12, 7, 928000, tzinfo=zoneinfo.ZoneInfo(key='UTC')),
#   datetime.datetime(2026, 9, 4, 14, 12, 7, 928000, tzinfo=zoneinfo.ZoneInfo(key='UTC')),
#   None,
#   None],
#  ['20260904_141019_00011_hjr2u',
#   'FINISHED',
#   'trino-client',
#   'trino-python-client',
#   'SELECT version()',
#   ['global'],
#   1,
#   1,
#   4,
#   datetime.datetime(2026, 9, 4, 14, 10, 19, 710000, tzinfo=zoneinfo.ZoneInfo(key='UTC')),
#   datetime.datetime(2026, 9, 4, 14, 10, 19, 711000, tzinfo=zoneinfo.ZoneInfo(key='UTC')),
#   datetime.datetime(2026, 9, 4, 14, 10, 19, 722000, tzinfo=zoneinfo.ZoneInfo(key='UTC')),
#   datetime.datetime(2026, 9, 4, 14, 10, 19, 722000, tzinfo=zoneinfo.ZoneInfo(key='UTC')),
#   None,
#   None],
#  ['20260904_141211_00016_hjr2u',
#   'RUNNING',
#   'trino-client',
#   'trino-python-client',
#   'SELECT * FROM system.runtime.queries',
#   ['global'],
#   0,
#   2,
#   4,
#   datetime.datetime(2026, 9, 4, 14, 12, 11, 227000, tzinfo=zoneinfo.ZoneInfo(key='UTC')),
#   datetime.datetime(2026, 9, 4, 14, 12, 11, 229000, tzinfo=zoneinfo.ZoneInfo(key='UTC')),
#   datetime.datetime(2026, 9, 4, 14, 12, 11, 235000, tzinfo=zoneinfo.ZoneInfo(key='UTC')),
#   None,
#   None,
#   None],
#  ['20260904_123251_00000_hjr2u',
#   'FINISHED',
#   'trino-client',
#   'Apache Superset',
#   'SHOW FUNCTIONS',
#   ['global'],
#   5,
#   52,
#   759,
#   datetime.datetime(2026, 9, 4, 12, 32, 51, 574000, tzinfo=zoneinfo.ZoneInfo(key='UTC')),
#   datetime.datetime(2026, 9, 4, 12, 32, 51, 630000, tzinfo=zoneinfo.ZoneInfo(key='UTC')),
#   datetime.datetime(2026, 9, 4, 12, 32, 52, 484000, tzinfo=zoneinfo.ZoneInfo(key='UTC')),
#   datetime.datetime(2026, 9, 4, 12, 32, 52, 580000, tzinfo=zoneinfo.ZoneInfo(key='UTC')),
#   None,
#   None],
#  ['20260904_135859_00006_hjr2u',
#   'FINISHED',
#   'trino-client',
#   'trino-python-client',
#   'SELECT version()',
#   ['global'],
#   0,
#   1,
#   5,
#   datetime.datetime(2026, 9, 4, 13, 58, 59, 790000, tzinfo=zoneinfo.ZoneInfo(key='UTC')),
#   datetime.datetime(2026, 9, 4, 13, 58, 59, 791000, tzinfo=zoneinfo.ZoneInfo(key='UTC')),
#   datetime.datetime(2026, 9, 4, 13, 58, 59, 802000, tzinfo=zoneinfo.ZoneInfo(key='UTC')),
#   datetime.datetime(2026, 9, 4, 13, 58, 59, 802000, tzinfo=zoneinfo.ZoneInfo(key='UTC')),
#   None,
#   None],
#  ['20260904_141046_00013_hjr2u',
#   'FINISHED',
#   'trino-client',
#   'trino-python-client',
#   'SELECT * FROM system.runtime.queries',
#   ['global'],
#   0,
#   1,
#   4,
#   datetime.datetime(2026, 9, 4, 14, 10, 46, 623000, tzinfo=zoneinfo.ZoneInfo(key='UTC')),
#   datetime.datetime(2026, 9, 4, 14, 10, 46, 624000, tzinfo=zoneinfo.ZoneInfo(key='UTC')),
#   datetime.datetime(2026, 9, 4, 14, 10, 46, 639000, tzinfo=zoneinfo.ZoneInfo(key='UTC')),
#   datetime.datetime(2026, 9, 4, 14, 10, 46, 639000, tzinfo=zoneinfo.ZoneInfo(key='UTC')),
#   None,
#   None],
#  ['20260904_123251_00001_hjr2u',
#   'FINISHED',
#   'trino-client',
#   'Apache Superset',
#   'SELECT "schema_name"\nFROM "information_schema"."schemata"',
#   ['global'],
#   4,
#   25,
#   102,
#   datetime.datetime(2026, 9, 4, 12, 32, 51, 574000, tzinfo=zoneinfo.ZoneInfo(key='UTC')),
#   datetime.datetime(2026, 9, 4, 12, 32, 51, 604000, tzinfo=zoneinfo.ZoneInfo(key='UTC')),
#   datetime.datetime(2026, 9, 4, 12, 32, 51, 925000, tzinfo=zoneinfo.ZoneInfo(key='UTC')),
#   datetime.datetime(2026, 9, 4, 12, 32, 51, 909000, tzinfo=zoneinfo.ZoneInfo(key='UTC')),
#   None,
#   None],
#  ['20260904_135617_00005_hjr2u',
#   'FINISHED',
#   'trino-client',
#   'trino-python-client',
#   'SELECT version()',
#   ['global'],
#   1,
#   1,
#   9,
#   datetime.datetime(2026, 9, 4, 13, 56, 17, 192000, tzinfo=zoneinfo.ZoneInfo(key='UTC')),
#   datetime.datetime(2026, 9, 4, 13, 56, 17, 194000, tzinfo=zoneinfo.ZoneInfo(key='UTC')),
#   datetime.datetime(2026, 9, 4, 13, 56, 17, 213000, tzinfo=zoneinfo.ZoneInfo(key='UTC')),
#   datetime.datetime(2026, 9, 4, 13, 56, 17, 212000, tzinfo=zoneinfo.ZoneInfo(key='UTC')),
#   None,
#   None],
#  ['20260904_123255_00003_hjr2u',
#   'FINISHED',
#   'trino-client',
#   'Apache Superset',
#   'SELECT\n  *\nFROM information_schema.tables\nLIMIT 1001',
#   ['global'],
#   0,
#   1,
#   5,
#   datetime.datetime(2026, 9, 4, 12, 32, 55, 710000, tzinfo=zoneinfo.ZoneInfo(key='UTC')),
#   datetime.datetime(2026, 9, 4, 12, 32, 55, 711000, tzinfo=zoneinfo.ZoneInfo(key='UTC')),
#   datetime.datetime(2026, 9, 4, 12, 32, 55, 722000, tzinfo=zoneinfo.ZoneInfo(key='UTC')),
#   datetime.datetime(2026, 9, 4, 12, 32, 55, 782000, tzinfo=zoneinfo.ZoneInfo(key='UTC')),
#   None,
#   None]]

# %%
conn.close()
cursor.close()
