# %% [markdown]
# Copy the file from the at repository notebooks/jupyter/jupyter_notebook_config.py to ~/.jupyter

# %%
# !mise list
# Out:
# Tool           Version           Source                              Requested
# argocd         3.0.3             ~/git/monorepo-datahub-ops/mise...  latest
# aws            2.26.2            ~/git/monorepo-datahub-ops/mise...  latest
# bat            0.25.0            ~/git/monorepo-datahub-ops/mise...  latest
# cloudflared    2025.5.0          ~/git/monorepo-datahub-ops/mise...  latest
# eza            0.21.3            ~/git/monorepo-datahub-ops/mise...  latest
# fastfetch      2.44.0            ~/git/monorepo-datahub-ops/mise...  latest
# fzf            0.62.0            ~/git/monorepo-datahub-ops/mise...  latest
# gh             2.73.0            ~/git/monorepo-datahub-ops/mise...  latest
# go             1.24.3            ~/.config/mise/config.toml          latest
# gum            0.16.0            ~/git/monorepo-datahub-ops/mise...  latest
# helm           3.18.0            ~/git/monorepo-datahub-ops/mise...  latest
# ...

# %%
# !echo $PATH
# Out:
# /home/rogermm/.local/share/mise/installs/argocd/3.0.3:/home/rogermm/.local/share/mise/installs/aws/2.26.2/aws/dist:/home/rogermm/.local/share/mise/installs/bat/0.25.0:/home/rogermm/.local/share/mise/installs/cloudflared/2025.5.0:/home/rogermm/.local/share/mise/installs/eza/0.21.3:/home/rogermm/.local/share/mise/installs/fastfetch/2.44.0/fastfetch-linux-amd64/usr/bin:/home/rogermm/.local/share/mise/installs/fzf/0.62.0:/home/rogermm/.local/share/mise/installs/gh/2.73.0/gh_2.73.0_linux_amd64/bin:/home/rogermm/.local/share/mise/installs/gum/0.16.0/gum_0.16.0_Linux_x86_64:/home/rogermm/.local/share/mise/installs/helm/3.18.0/linux-amd64:/home/rogermm/.local/share/mise/installs/kubecolor/0.0.25:/home/rogermm/.local/share/mise/installs/kubectx/0.9.5:/home/rogermm/.local/share/mise/installs/kubie/0.25.2:/home/rogermm/.local/share/mise/installs/neovim/0.11.1/nvim-linux-x86_64/bin:/home/rogermm/.local/share/mise/installs/python/3.13.3/bin:/home/rogermm/.local/share/mise/installs/slsa-verifier/2
# ...

# %%
# !kubecolor get nodes
# Out:
# NAME                    STATUS   ROLES                  AGE   VERSION
# vm.worldl1.worldl.xpt   Ready    control-plane,master   15d   v1.33.0+k3s1
