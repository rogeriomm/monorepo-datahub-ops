# %%
# !mise use kafkactl --global
# Out:
# kafkactl@5.19.0                                                                ◜
# kafkactl@5.19.0                                                                ◜
# mise WARN  kafkactl is defined in ~/work/mise.toml which overrides the global config (~/.config/mise/config.toml)
# mise ~/.config/mise/config.toml tools: kafkactl@5.19.0

# %%
# !mise list | grep kafkactl
# Out:
# kafkactl          5.19.0                      ~/work/mise.toml            latest

# %%
import os

mise_shims = os.path.expanduser("~/.local/share/mise/shims")
os.environ["PATH"] = f"{mise_shims}:{os.environ['PATH']}"

# %%
# !kafkactl
# Out:
# A command-line interface the simplifies interaction with Kafka.
#
# Usage:
#   kafkactl [command]
#
# Available Commands:
#   alter       alter topics, partitions, brokers, users
#   attach      run kafkactl pod in kubernetes and attach to it
#   clone       clone topics, consumerGroups
#   completion  generate shell auto-completion file
#   config      show and edit configurations
#   consume     consume messages from a topic
#   create      create topics, consumerGroups, acls, users
#   delete      delete topics, consumerGroups, consumer-group-offset, acls, records, users
#   describe    describe topics, consumerGroups, brokers, users
#   get         get info about topics, consumerGroups, acls, brokers, users
#   help        Help about any command
#   produce     produce messages to a topic
#   reset       reset consumerGroupsOffset
#   version     print the version of kafkactl
#
# Flags:
#       --clear-keyring        clear stored credentials from keyring and re-prompt
# ...

# %%
# !sudo apt --yes install netcat-openbsd nmap
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# netcat-openbsd is already the newest version (1.226-1ubuntu2).
# The following additional packages will be installed:
#   ibverbs-providers libibverbs1 liblinear4 libnl-3-200 libnl-route-3-200
#   libpcap0.8t64 libssh2-1t64 nmap-common
# Suggested packages:
#   liblinear-tools liblinear-dev ncat ndiff zenmap
# The following NEW packages will be installed:
#   ibverbs-providers libibverbs1 liblinear4 libnl-3-200 libnl-route-3-200
#   libpcap0.8t64 libssh2-1t64 nmap nmap-common
# 0 upgraded, 9 newly installed, 0 to remove and 13 not upgraded.
# Need to get 6895 kB of archives.
# After this operation, 29.4 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libnl-3-200 amd64 3.7.0-0.3build1.1 [55.7 kB]
# Get:2 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libnl-route-3-200 amd64 3.7.0-0.3build1.1 [189 kB]
# ...
