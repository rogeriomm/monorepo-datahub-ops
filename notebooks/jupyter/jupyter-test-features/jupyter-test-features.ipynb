# %%
from IPython.display import display, Markdown

# %%
display(
    Markdown(
        f"""
# Spark Execution Report

## Job Summary

The Spark job completed successfully.

| Metric | Value |
|---|---:|
| Application | Customer Analytics |
| Execution mode | Local |
| Spark version | 4.1.0 |
| Input records | 1,250,000 |
| Output records | 48,320 |
| Input partitions | 24 |
| Shuffle partitions | 200 |
| Execution time | 18.7 seconds |

## Processing Stages

1. Read the source Parquet files.
2. Filter invalid records.
3. Join customer and transaction datasets.
4. Aggregate transactions by customer.
5. Write the result as an Iceberg table.

## Configuration
"""
    )
)
# Out:
# # Spark Execution Report
#
# ## Job Summary
#
# The Spark job completed successfully.
#
# | Metric | Value |
# |---|---:|
# | Application | Customer Analytics |
# | Execution mode | Local |
# | Spark version | 4.1.0 |
# | Input records | 1,250,000 |
# | Output records | 48,320 |
# | Input partitions | 24 |
# | Shuffle partitions | 200 |
# | Execution time | 18.7 seconds |
#
# ## Processing Stages
#
# 1. Read the source Parquet files.
# 2. Filter invalid records.
# 3. Join customer and transaction datasets.
# 4. Aggregate transactions by customer.
# 5. Write the result as an Iceberg table.
#
# ## Configuration

# %%
display(
    Markdown(
        f"""
```mermaid
sequenceDiagram
    participant U as User
    participant J as Jupyter
    participant S as Spark

    U->>J: Execute cell
    J->>S: Submit Spark job
    S-->>J: Return result
    J-->>U: Display output
"""
    )
)
# Out:
# ```mermaid
# sequenceDiagram
#     participant U as User
#     participant J as Jupyter
#     participant S as Spark
#
#     U->>J: Execute cell
#     J->>S: Submit Spark job
#     S-->>J: Return result
#     J-->>U: Display output
