# %%
# %run_nb squid

# %%
# %%tsql
# SHOW CATALOGS;
#
# SELECT table_catalog, table_schema, table_name, table_type
# FROM iceberg.information_schema.tables
# ORDER BY table_schema, table_name;
# Out:
#    Catalog
# 0    delta
# 1  iceberg
# 2   system
#    table_catalog        table_schema                     table_name  \
# 0        iceberg  information_schema               applicable_roles
# 1        iceberg  information_schema                        columns
# 2        iceberg  information_schema                  enabled_roles
# 3        iceberg  information_schema                          roles
# 4        iceberg  information_schema                       schemata
# 5        iceberg  information_schema               table_privileges
# 6        iceberg  information_schema                         tables
# 7        iceberg  information_schema                          views
# 8        iceberg             nyc_gov                  country_codes
# 9        iceberg             nyc_gov           given_name_frequency
# 10       iceberg             nyc_gov               name_equivalence
# 11       iceberg             nyc_gov  popular_names_by_country_2026
# ...

# %%
# %%tsql
# SELECT catalog_name, connector_name
# FROM system.metadata.catalogs
# ORDER BY catalog_name;
# Out:
#   catalog_name connector_name
# 0        delta     delta_lake
# 1      iceberg        iceberg
# 2       system         system

# %%
# %tsql SHOW SCHEMAS FROM iceberg;
# Out:
#                Schema
# 0             default
# 1  information_schema
# 2             nyc_gov
# 3              system
# 4                test

# %%
# %tsql  --max-colwidth 200 SHOW CREATE SCHEMA iceberg.nyc_gov;
# Out:
#                                                                                                                    Create Schema
# 0  CREATE SCHEMA iceberg.nyc_gov\nAUTHORIZATION USER "trino-client"\nWITH (\n   location = 's3a://trino-lakehouse/nyc_gov.db'\n)

# %%
# %%tsql
# SHOW CREATE SCHEMA iceberg.nyc_gov;
# Out:
#                                        Create Schema
# 0  CREATE SCHEMA iceberg.nyc_gov\nAUTHORIZATION U...

# %%
# %%tsql
# SHOW CREATE SCHEMA iceberg.nyc_gov;
# Out:
#                                        Create Schema
# 0  CREATE SCHEMA iceberg.nyc_gov\nAUTHORIZATION U...

# %%
# %%tsql  --max-colwidth 200
# SHOW CREATE SCHEMA iceberg.nyc_gov;
# Out:
#                                                                                                                    Create Schema
# 0  CREATE SCHEMA iceberg.nyc_gov\nAUTHORIZATION USER "trino-client"\nWITH (\n   location = 's3a://trino-lakehouse/nyc_gov.db'\n)

# %%
# %%tsql
# SELECT *
# FROM iceberg.nyc_gov.country_codes
# LIMIT 4
# Out:
#      country_code country_name
# 0     Afghanistan           AF
# 1         Albania           AL
# 2         Algeria           DZ
# 3  American Samoa           AS
