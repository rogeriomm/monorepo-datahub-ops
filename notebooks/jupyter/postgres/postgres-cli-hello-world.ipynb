# %%
# %%bash
# PGSSLMODE=require \
# PGPASSWORD='postgres' \
# psql \
#   --host=postgres \
#   --username=postgres \
#   --dbname=postgres \
#   --command='SELECT datname FROM pg_database ORDER BY datname;'
# Out:
#   datname
# -----------
#  postgres
#  template0
#  template1
# (3 rows)

# %%
# %%bash
# PGSSLMODE=require \
# PGPASSWORD='postgres' \
# psql \
#   --host=postgres \
#   --username=postgres \
#   --dbname=postgres \
#   --command='SELECT current_database(), current_user;'
# Out:
#  current_database | current_user
# ------------------+--------------
#  postgres         | postgres
# (1 row)

# %%
# !uv pip list
# Out:
# Using Python 3.12.3 environment at: /home/jovyan/work/notebooks/jupyter/.venv
