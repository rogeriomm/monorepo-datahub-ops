# %%
from pathlib import Path
repo_path = Path("/var/rogerm")
path = Path("")
path = repo_path / "on-premises/docker" 

print(repo_path)
print(path)
# Out:
# /var/rogerm
# /var/rogerm/on-premises/docker
