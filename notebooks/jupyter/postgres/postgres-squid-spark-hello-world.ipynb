# %%
# %run_nb spark-start
# Out:
# SparkMonitor frontend is not connected.
# Reload the JupyterLab page with Ctrl+Shift+R.
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# /opt/conda/lib/python3.13/site-packages/IPython/core/interactiveshell.py:3783: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit

# %%
# !tree /Volumes/workspace/default/on_premises_certificates
# !tree /Volumes/workspace/default/on_premises_artifacts/python-wheels
# Out:
# /Volumes/workspace/default/on_premises_certificates
# ├── kafka-4
# │   └── ca.crt
# ├── postgres
# │   ├── ca.crt
# │   ├── client.crt
# │   ├── client.key
# │   ├── postgres-client.p12
# │   ├── secret-client-password
# │   └── secret-postgres-password
# ├── seaweedfs
# │   └── ca.crt
# └── trino
#     ├── ca.crt
#     ├── secret-client-password
#     └── trino-client.p12
#
# 5 directories, 11 files
# /Volumes/workspace/default/on_premises_artifacts/python-wheels
# ├── squid_databricks-0.1.0-py312-none-any.whl
# ├── squid_on_premises-0.1.0-py311-none-any.whl
# ├── squid_on_premises-0.1.0-py312-none-any.whl
# └── squid_on_premises-0.1.0-py313-none-any.whl
#
# 1 directory, 4 files

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
#%pip install /Volumes/workspace/default/on_premises_artifacts/python-wheels/squid_local-0.1.0-py313-none-any.whl

# %%
import sys
from pathlib import Path

src_path = Path("~/work/on-premises/squid-test/src").expanduser().resolve()

if str(src_path) not in sys.path:
    sys.path.insert(0, str(src_path))

# %%
import squid.core.main
squid.core.main.env
spark
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import squid.core.main
#       2 squid.core.main.env
#       3 spark
#
# ModuleNotFoundError: No module named 'squid'

# %%
def query(sql: str):
    df = (
        spark.read
        .format("postgresql")

        .option("host",      postgres_host)
        .option("port",      postgres_port)
        .option("database",  postgres_database)
        .option("user",      postgres_user)
        .option("password",  postgres_password)
        .option("sslmode",   "require")
        .option("connectTimeout", 10)            
            
        .option("query",     sql)
        .option("numPartitions", 1)

        .load()
    )
    return df

# %%
df = query("select version()")
display(df)
