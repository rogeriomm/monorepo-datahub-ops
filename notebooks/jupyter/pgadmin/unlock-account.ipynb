# %%
# %%bash
# cd ~/work/on-premises/docker
# docker exec pgadmin /venv/bin/python3 -c \
# "import os, sqlite3; db=sqlite3.connect('/var/lib/pgadmin/pgadmin4.db'); user=os.environ['PGADMIN_DEFAULT_EMAIL']; cur=db.execute('UPDATE \"user\" SET locked=0, login_attempts=0 WHERE username=?', (user,)); db.commit(); print(f'Unlocked {cur.rowcount} account(s): {user}')"
# Out:
# Unlocked 1 account(s): admin@example.com
