# %%
# !tree ~/work/on-premises/squid/src
# Out:
# /home/jovyan/work/on-premises/squid/src
# ├── squid
# │   ├── __init__.py
# │   ├── __pycache__
# │   │   ├── __init__.cpython-312.pyc
# │   │   ├── __init__.cpython-313.pyc
# │   │   └── __init__.cpython-314.pyc
# │   ├── core
# │   │   ├── __init__.py
# │   │   ├── __pycache__
# │   │   │   ├── __init__.cpython-312.pyc
# │   │   │   ├── __init__.cpython-313.pyc
# │   │   │   ├── main.cpython-312.pyc
# │   │   │   └── main.cpython-313.pyc
# │   │   └── main.py
# │   ├── on-premises
# │   │   ├── __init__.py
# │   │   └── __pycache__
# │   │       ├── __init__.cpython-312.pyc
# │   │       └── __init__.cpython-314.pyc
# │   └── resources
# │       ├── __init__.py
# │       ├── __pycache__
# │       │   ├── __init__.cpython-312.pyc
# │       │   ├── __init__.cpython-313.pyc
# │       │   ├── __init__.cpython-314.pyc
# │       │   ├── base.cpython-312.pyc
# │       │   ├── base.cpython-314.pyc
# │       │   ├── kafka.cpython-312.pyc
# │       │   ├── kafka.cpython-314.pyc
# │       │   ├── postgres.cpython-312.pyc
# │       │   ├── postgres.cpython-313.pyc
# │       │   ├── s3.cpython-312.pyc
# │       │   ├── s3.cpython-314.pyc
# │       │   ├── trino.cpython-312.pyc
# │       │   └── trino.cpython-314.pyc
# │       ├── base.py
# │       ├── kafka.py
# │       ├── postgres.py
# │       ├── s3.py
# │       └── trino.py
# ├── squid_databricks.egg-info
# │   ├── PKG-INFO
# │   ├── SOURCES.txt
# │   ├── dependency_links.txt
# │   ├── requires.txt
# │   └── top_level.txt
# └── squid_local.egg-info
#     ├── PKG-INFO
#     ├── SOURCES.txt
#     ├── dependency_links.txt
#     ├── requires.txt
#     └── top_level.txt
#
# 11 directories, 42 files

# %%
import sys
from pathlib import Path

src_path = Path("~/work/on-premises/squid-test/src").expanduser().resolve()

if str(src_path) not in sys.path:
    sys.path.insert(0, str(src_path))

# %%
from squid.resources.postgres import get_cursor
