# %% [markdown]
# # TLS certificates

# %%
# !ls -la /etc/seaweedfs/tls
# Out:
# total 20
# drwxr-xr-x. 1 jovyan 1000   84 Aug  5 12:52 .
# drwxr-xr-x. 1 root   root    6 Aug  5 20:16 ..
# -rw-r--r--. 1 jovyan 1000   14 Aug  5 12:51 .gitignore
# -rw-r--r--. 1 jovyan 1000 1180 Aug  5 12:52 ca.crt
# -rw-------. 1 jovyan 1000 1704 Aug  5 12:52 ca.key
# -rw-r--r--. 1 jovyan 1000 1269 Aug  5 12:52 server.crt
# -rw-------. 1 jovyan 1000 1704 Aug  5 12:52 server.key

# %%
# !cat /etc/seaweedfs/tls/ca.crt
# Out:
# -----BEGIN CERTIFICATE-----
# MIIDOTCCAiGgAwIBAgIUf38ZJ+caw5ZMmb5oR0GMe4NwnqwwDQYJKoZIhvcNAQEL
# BQAwJDEiMCAGA1UEAwwZZGV2Y29udGFpbmVyLXNlYXdlZWRmcy1jYTAeFw0yNjA4
# MDUxMjUyMDRaFw0zNjA4MDIxMjUyMDRaMCQxIjAgBgNVBAMMGWRldmNvbnRhaW5l
# ci1zZWF3ZWVkZnMtY2EwggEiMA0GCSqGSIb3DQEBAQUAA4IBDwAwggEKAoIBAQDT
# Dn2GUuW9ZnVHl6wDgRx0ApDeR4mLPd12PqkvYIQhklMxEPxbjGj3+bcZh+Gz+6i2
# OA72Ghvz79t4+J/HsPB+L4i9w6xqDad+wysBDKVQs05VMiR9HZ4wXhszekB4vky6
# bNqBbftFkq3HU7u7IECAatYvgBwyX/0B5E2d8XjZTHdB+su6B5H/q5BqKAnhEfRN
# IK4pcSx5NIcDd7ldb4jx/X0sPlg4IsWDruUPO0kf2aeKUzO0VoRbuRbD8CTNzqPw
# Fa/ki/eSrMx6egotmeJI+CIHEiQhZ4Iv60xfH8RMA0dOR09eJcOtWCP/3IVWLsQv
# 7rfhZPQCdVhgAcphv5EhAgMBAAGjYzBhMB0GA1UdDgQWBBSo5XeH9PG0ekKwhGo4
# OqVvhde4ejAfBgNVHSMEGDAWgBSo5XeH9PG0ekKwhGo4OqVvhde4ejAPBgNVHRMB
# Af8EBTADAQH/MA4GA1UdDwEB/wQEAwIBBjANBgkqhkiG9w0BAQsFAAOCAQEAOGXr
# A8YCgotpX88irIFS2WhaUFs3BXK0muPJ+fsyV57y4K+G+lXlIuJ5bU3cX3g+gPf7
# kQ0YYNfu0hn07niqEF4dCAjaaTiD9NrZfwcqhmtH/YIUJvrJJUDWn1EKrA3qsoFI
# ...

# %% [markdown]
# # TCP port

# %%
# !nc -vz seaweedfs 8333
# Out:
# Connection to seaweedfs (172.27.0.8) 8333 port [tcp/*] succeeded!

# %%
s3="AWS_ACCESS_KEY_ID=admin AWS_SECRET_ACCESS_KEY=secret AWS_CA_BUNDLE=/etc/seaweedfs/tls/ca.crt AWS_REGION=us-east-1 aws --endpoint-url https://seaweedfs:8333 s3"

# %%
# !{s3} ls

# %%
# !{s3} mb s3://my-bucket
# Out:
# make_bucket: my-bucket

# %%
# !{s3} ls
# Out:
# 2026-08-05 20:21:34 my-bucket

# %%
# !{s3} rm s3://my-bucket

# %%
# !{s3} ls
# Out:
# 2026-08-05 20:21:34 my-bucket
