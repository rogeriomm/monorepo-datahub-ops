# %% [markdown]
# # TLS certificates

# %%
# !ls -la /etc/seaweedfs/tls
# Out:
# total 20
# drwxr-xr-x. 1 jovyan 1000   84 Aug  6 19:57 .
# drwxr-xr-x. 1 root   root    6 Aug 10 16:47 ..
# -rw-r--r--. 1 jovyan 1000   13 Aug  6 19:57 .gitignore
# -rw-r--r--. 1 jovyan 1000 1180 Aug  6 17:13 ca.crt
# -rw-------. 1 jovyan 1000 1704 Aug  6 17:13 ca.key
# -rw-r--r--. 1 jovyan 1000 1269 Aug  6 17:13 server.crt
# -rw-------. 1 jovyan 1000 1704 Aug  6 17:13 server.key

# %%
# !cat /etc/seaweedfs/tls/ca.crt
# Out:
# -----BEGIN CERTIFICATE-----
# MIIDOTCCAiGgAwIBAgIUH9n8eWpLMFoC9LQQqjdgOzM+TB4wDQYJKoZIhvcNAQEL
# BQAwJDEiMCAGA1UEAwwZZGV2Y29udGFpbmVyLXNlYXdlZWRmcy1jYTAeFw0yNjA4
# MDYxNzEzMTZaFw0zNjA4MDMxNzEzMTZaMCQxIjAgBgNVBAMMGWRldmNvbnRhaW5l
# ci1zZWF3ZWVkZnMtY2EwggEiMA0GCSqGSIb3DQEBAQUAA4IBDwAwggEKAoIBAQC3
# WCdtAFMo6hUYjuCCwS6qKsS9LeXgQbcE28V/SlRDylHdytSwIbCIcA6p3ICrGXwA
# E/qRFhT7VBMuDibbFX3VOF9zJcmS8qELE5F7jW4GBS76B2gK+5E5+wJBsg76QatG
# zQt+1Ds9ckGVOXEwZBD/QVt4yjz/uHM0HeRo5UyoiTjUujxEN4Y6KXsZyaGA1SXk
# k5L8RScwTt4KjlR3dKLBhFZ13TPZqD9R49FcpjfDKOCyD3nIkU0W9NVZODhgVvYg
# 930eJJjgFctw905NH8q0mRwf9Fl1xnKLacX1FYD8Adja2nNNi3QlNjyRgJce5Rlm
# uvvSjBhHRKUmihzFTHEjAgMBAAGjYzBhMB0GA1UdDgQWBBSVfIdHt1HuS05cjjEL
# aX86AdnikTAfBgNVHSMEGDAWgBSVfIdHt1HuS05cjjELaX86AdnikTAPBgNVHRMB
# Af8EBTADAQH/MA4GA1UdDwEB/wQEAwIBBjANBgkqhkiG9w0BAQsFAAOCAQEAAziB
# O4th6rv6y+Dkz5Em3c5wVv+x88FQPhRAoyTWPbijyFhATlJc9Za9P8DIPNsWOaeY
# 2qik7GHgbkgDiKXijYj8HVgqrEehWofVco64zWw/bd0OMFxzCD6ctA4VnkvRlcTx
# EeHFL3mwcr561BJQnyA8+cie63194bb3f6wDtaspdTBIPrxFYYekpIxpKAx9Jpsa
# dZhAFFM6yih832sdFtpW1jrOm4mgaa5X7YkuXihn0ze5NxTNz4Bu7lW3jHm3aFXx
# XjxKff4A4pnkiCYzVOuB1z88yNVlyBWk/wjHvYqTF83GW78ETYvn58OTtcVcu7Wo
# po1YggqPu5fwjDDOdQ==
# -----END CERTIFICATE-----

# %% [markdown]
# # TCP port

# %%
# !nc -vz seaweedfs 8333
# Out:
# Connection to seaweedfs (172.28.0.5) 8333 port [tcp/*] succeeded!

# %%
s3="AWS_ACCESS_KEY_ID=admin AWS_SECRET_ACCESS_KEY=secret2 AWS_CA_BUNDLE=/etc/seaweedfs/tls/ca.crt AWS_REGION=us-east-1 aws --endpoint-url https://seaweedfs:8333 s3"

# %%
# !{s3} ls
# Out:
# 2026-08-05 20:21:34 my-bucket

# %%
# !{s3} mb s3://my-bucket
# Out:
# make_bucket failed: s3://my-bucket An error occurred (BucketAlreadyOwnedByYou) when calling the CreateBucket operation: Your previous request to create the named bucket succeeded and you already own it.

# %%
# !{s3} ls
# Out:
# 2026-08-05 20:21:34 my-bucket

# %%
# !{s3} rm s3://my-bucket

# %%
# !{s3} ls
# Out:
# 2026-08-05 20:21:34 my-bucket
