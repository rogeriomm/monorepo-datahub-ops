# %% [markdown]
# # TLS certificates

# %%
# !ls -la /etc/seaweedfs/tls
# Out:
# total 20
# drwxr-xr-x. 1 jovyan 1000   84 Aug 11 13:33 .
# drwxr-xr-x. 1 root   root    6 Sep  3 19:28 ..
# -rw-r--r--. 1 jovyan 1000   13 Aug  6 19:57 .gitignore
# -rw-r--r--. 1 jovyan 1000 1180 Aug 11 13:33 ca.crt
# -rw-------. 1 jovyan 1000 1708 Aug 11 13:33 ca.key
# -rw-r--r--. 1 jovyan 1000 1269 Aug 11 13:33 server.crt
# -rw-------. 1 jovyan 1000 1704 Aug 11 13:33 server.key

# %%
# !cat /etc/seaweedfs/tls/ca.crt
# Out:
# -----BEGIN CERTIFICATE-----
# MIIDOTCCAiGgAwIBAgIUEj+Kiu2H9A+wupLYE178jV9UV2EwDQYJKoZIhvcNAQEL
# BQAwJDEiMCAGA1UEAwwZZGV2Y29udGFpbmVyLXNlYXdlZWRmcy1jYTAeFw0yNjA4
# MTExMzMzMzZaFw0zNjA4MDgxMzMzMzZaMCQxIjAgBgNVBAMMGWRldmNvbnRhaW5l
# ci1zZWF3ZWVkZnMtY2EwggEiMA0GCSqGSIb3DQEBAQUAA4IBDwAwggEKAoIBAQCp
# HJyyLqMGglSHJPhDj9pK78rQUd35a276RUmNH8TopvpvAjn49KleOGUMCGyB+esD
# 7/8icgGIvKpa0VvpwSx6ttw5/DZeOGry7pmFwI64MBefCmZjosj1NcdW+8lzG9Ms
# U0VhHm3jYZoV1sH2cjsikSK9HR5rAyEdB9AXZm3Pcbm+PLPfQOVmM/NJfRAbSg1v
# yFC0Y3HMH4BhMlunajwgOTy+f7XJSyB0ViEx8xqNecH6mt+c4vpU6KNLvEn9AkKr
# fH7tZf2CpwrXMoim/Nh4jO+Uc3eECQiluhn3SkfFp2DimEMWidsKJQhTyOGoFqHM
# QPxaCewkUOZvGz6bGtRHAgMBAAGjYzBhMB0GA1UdDgQWBBRATwIoYTBCqaFYGhWU
# p+EiwnGroTAfBgNVHSMEGDAWgBRATwIoYTBCqaFYGhWUp+EiwnGroTAPBgNVHRMB
# Af8EBTADAQH/MA4GA1UdDwEB/wQEAwIBBjANBgkqhkiG9w0BAQsFAAOCAQEAYiUy
# kKZmmuBKxXmrUa9V3kz+hJOrFzRvuPSs7Jvp/+mBEXsS4+7VuLqsZlHaxtIVv66z
# EyLZ+BTmfgiWrXEcVOj8axJXjDJG2pvcBjRrkP+Sygczj6gobphITGk6weMLNy0L
# BWH07Dj6A4dm5WtrnR+KNJq7WJyrDNfAdMW37xrbrKv3ejcpLZB3oqdCKUdKkA1Q
# 06OoOnWxQr3W8czqvWsbMkyrHG4D2/gWdglkJ6nqNugLaKyR/7q8qeCywNu2LYUu
# ZRr5Elcfk9wptpsPPH7ah06evFh50FLEG5cPEd8Mdoo1SLhKE7q67CMVF5miptZO
# URULUVLT9R7kVMlgmA==
# -----END CERTIFICATE-----

# %% [markdown]
# # TCP port

# %%
# !nc -vz seaweedfs 8333
# Out:
# Connection to seaweedfs (172.27.0.9) 8333 port [tcp/*] succeeded!

# %%
s3="AWS_ACCESS_KEY_ID=admin AWS_SECRET_ACCESS_KEY=secret2 AWS_CA_BUNDLE=/etc/seaweedfs/tls/ca.crt AWS_REGION=us-east-1 aws --endpoint-url https://seaweedfs:8333 s3"

# %%
# !{s3} ls
# Out:
# 2026-08-05 20:21:34 my-bucket
# 2026-09-03 18:43:24 trino-lakehouse

# %%
# !{s3} mb s3://my-bucket
# Out:
# make_bucket failed: s3://my-bucket An error occurred (BucketAlreadyOwnedByYou) when calling the CreateBucket operation: Your previous request to create the named bucket succeeded and you already own it.

# %%
# !{s3} ls
# Out:
# 2026-08-05 20:21:34 my-bucket
# 2026-09-03 18:43:24 trino-lakehouse

# %%
# !{s3} rm s3://my-bucket

# %%
# !{s3} ls
# Out:
# 2026-08-05 20:21:34 my-bucket
# 2026-09-03 18:43:24 trino-lakehouse

# %%
# !{s3} ls --recursive s3://trino-lakehouse
# Out:
# 2026-09-03 18:44:02          0 delta-codex-smoke/
# 2026-09-03 18:44:02        345 delta-codex-smoke/format_test-ef9867f15a4940a2bb49365399878dd5/20260903_184402_00011_2iesm_f150eb3d-d403-4bf1-821f-d810e12a7105
# 2026-09-03 18:44:03       1143 delta-codex-smoke/format_test-ef9867f15a4940a2bb49365399878dd5/_delta_log/00000000000000000000.json
# 2026-09-03 18:44:03        202 delta-codex-smoke/format_test-ef9867f15a4940a2bb49365399878dd5/_delta_log/_trino_meta/extended_stats.json
# 2026-09-04 14:33:27          0 test.db/
# 2026-09-04 14:43:03        698 test.db/my_table-83f43e1c9ed94e1996981c7a9501f9c7/data/20260904_144303_00037_hjr2u-c43a1a1a-1120-432a-97d1-316295d5a673.parquet
# 2026-09-04 14:33:39       1775 test.db/my_table-83f43e1c9ed94e1996981c7a9501f9c7/metadata/00000-678b87c0-d50a-499d-baa6-5543667891db.metadata.json
# 2026-09-04 14:43:03       3708 test.db/my_table-83f43e1c9ed94e1996981c7a9501f9c7/metadata/00001-733583f7-ff48-42b9-8581-d62b8b319081.metadata.json
# 2026-09-04 14:43:03        975 test.db/my_table-83f43e1c9ed94e1996981c7a9501f9c7/metadata/20260904_144303_00037_hjr2u-e81b9ef1-31e3-4be9-9329-3add9c5aaf8f.stats
# 2026-09-04 14:43:03       7237 test.db/my_table-83f43e1c9ed94e1996981c7a9501f9c7/metadata/c7383691-4225-479e-bbab-393dc18ded22-m0.avro
# 2026-09-04 14:33:39       4313 test.db/my_table-83f43e1c9ed94e1996981c7a9501f9c7/metadata/snap-4685570501889062570-1-8f270116-2834-48ee-a7e6-354f32f1720a.avro
# 2026-09-04 14:43:03       4488 test.db/my_table-83f43e1c9ed94e1996981c7a9501f9c7/metadata/snap-5945606171819030736-1-c7383691-4225-479e-bbab-393dc18ded22.avro

# %%
# !{s3} ls --recursive s3://my-bucket
