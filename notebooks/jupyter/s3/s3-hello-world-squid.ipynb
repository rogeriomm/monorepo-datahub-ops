# %%
import pandas as pd

from squid.resources.s3 import get_s3

s3 = get_s3()

# %%
bucket_response = s3.list_buckets()

buckets = pd.DataFrame(
    [
        {
            'Name': bucket['Name'],
            'CreationDate': bucket['CreationDate'],
        }
        for bucket in bucket_response.get('Buckets', [])
    ],
    columns=['Name', 'CreationDate'],
)

display(buckets)
# Out:
#               Name              CreationDate
# 0        my-bucket 2026-08-05 20:21:34+00:00
# 1  trino-lakehouse 2026-09-03 18:43:24+00:00

# %%
bucket_name = 'trino-lakehouse'
objects = []

for page in s3.get_paginator('list_objects_v2').paginate(Bucket=bucket_name):
    objects.extend(
        {
            'Key': item['Key'],
            'Size': item['Size'],
            'LastModified': item['LastModified'],
        }
        for item in page.get('Contents', [])
    )

bucket_objects = pd.DataFrame(
    objects,
    columns=['Key', 'Size', 'LastModified'],
).sort_values('Key', ignore_index=True)

display(bucket_objects)
# Out:
#                                                   Key  Size  \
# 0                                  delta-codex-smoke/     0
# 1   delta-codex-smoke/format_test-ef9867f15a4940a2...   345
# 2   delta-codex-smoke/format_test-ef9867f15a4940a2...  1143
# 3   delta-codex-smoke/format_test-ef9867f15a4940a2...   202
# 4                                            test.db/     0
# 5   test.db/my_table-83f43e1c9ed94e1996981c7a9501f...   698
# 6   test.db/my_table-83f43e1c9ed94e1996981c7a9501f...  1775
# 7   test.db/my_table-83f43e1c9ed94e1996981c7a9501f...  3708
# 8   test.db/my_table-83f43e1c9ed94e1996981c7a9501f...   975
# 9   test.db/my_table-83f43e1c9ed94e1996981c7a9501f...  7237
# 10  test.db/my_table-83f43e1c9ed94e1996981c7a9501f...  4313
# 11  test.db/my_table-83f43e1c9ed94e1996981c7a9501f...  4488
#
#                 LastModified
# 0  2026-09-03 18:44:02+00:00
# 1  2026-09-03 18:44:02+00:00
# 2  2026-09-03 18:44:03+00:00
# 3  2026-09-03 18:44:03+00:00
# 4  2026-09-04 14:33:27+00:00
# 5  2026-09-04 14:43:03+00:00
# 6  2026-09-04 14:33:39+00:00
# 7  2026-09-04 14:43:03+00:00
# 8  2026-09-04 14:43:03+00:00
# 9  2026-09-04 14:43:03+00:00
# 10 2026-09-04 14:33:39+00:00
# 11 2026-09-04 14:43:03+00:00
