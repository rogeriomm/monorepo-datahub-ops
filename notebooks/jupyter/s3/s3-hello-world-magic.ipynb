# %%
# %s3 ls
# Out:
# 2026-09-11 16:22:02 delta-lakehouse
# 2026-09-14 14:22:36 my-bucket
# 2026-09-09 12:27:26 trino-lakehouse

# %%
# %s3 ls s3://trino-lakehouse/
# Out:
#                            PRE nyc_gov.db/
#                            PRE test.db/

# %%
# %s3 rm s3://trino-lakehouse/my-bucket
# Out:
# delete: s3://trino-lakehouse/my-bucket

# %%
# %s3 ls s3://trino-lakehouse/nyc_gov.db/
# Out:
#                            PRE country_codes-9a177fe4c3ba4674ba94c599d18f2dee/
#                            PRE given_name_frequency-5ff20512f56e4490afaebd20cadceae0/
#                            PRE name_equivalence-3802ce524d854adab957ac4f027e7998/
#                            PRE popular_names_by_country_2026-d2189a769d4c4a1fb70e0dd01fe31da5/
#                            PRE surname_frequency-1d0faf92bf7d41eba5ae3eb05a594d57/
# 2026-09-09 14:54:27          0
