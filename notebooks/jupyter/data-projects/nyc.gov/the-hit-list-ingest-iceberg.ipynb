# %%
# %run_nb spark-start --data-format iceberg
# Out:
# Args: Namespace(data_format='iceberg') - unknown_args: []
# Spark version: 4.1.3, Driver memory: 16g, Executor memory: 8g, Service: jupyter-spark-4.1, Data format: iceberg
# Port offset: 3
# Spark packages: org.postgresql:postgresql:42.7.7,org.apache.hadoop:hadoop-aws:3.4.2,org.apache.spark:spark-avro_2.13:4.1.3,org.apache.spark:spark-sql-kafka-0-10_2.13:4.1.3,org.apache.iceberg:iceberg-spark-runtime-4.1_2.13:1.11.0
# Spark extensions: org.apache.iceberg.spark.extensions.IcebergSparkSessionExtensions
# Spark catalog configs: {'spark.sql.catalog.local': 'org.apache.iceberg.spark.SparkCatalog', 'spark.sql.catalog.local.type': 'hadoop', 'spark.sql.catalog.local.warehouse': 'file:///home/jovyan/work/data/datalake/jupyter-spark-4.1/spark-4.1/iceberg/warehouse'}
# <!--| quarto-html-table-processing: none -->
# <table id="itables_70cf852c_a37a_4b53_b1f4_0f971b7c4fc2" hidden="hidden">
#   <tbody>
#     <tr>
#       <td style="vertical-align:middle; text-align:left"><a href=https://itables.org/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:var(--itables-logo-paper,#d9d7fc)">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:var(--itables-logo-ink,#1a1366);stroke:var(--itables-logo-ink,#1a1366);">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#         Loading ITables v2.9.1 from the internet...
#         (need <a href=https://itables.org/troubleshooting.html>help</a>?)
#       </td>
#     </tr>
#   </tbody>
# </table>
# <div id="itables_70cf852c_a37a_4b53_b1f4_0f971b7c4fc2_fallback"><table style="border-collapse:collapse"><thead>    <tr style="text-align: right;">
#       <th style="border:1px solid #ddd;padding:8px"><sup><noscript><span title="JavaScript not allowed. Please trust this notebook to get interactive tables.">🔒</span></noscript><a href=https://itables.org/fallbacks/static_preview.html title="ITables v2.9.1 static preview">ⓘ</a></sup>catalog</th>
#     </tr></thead><tbody>
# <tr><td style="border:1px solid #ddd;padding:8px">spark_catalog</td></tr>
# </tbody></table></div><script>document.getElementById("itables_70cf852c_a37a_4b53_b1f4_0f971b7c4fc2")?.removeAttribute("hidden");document.getElementById("itables_70cf852c_a37a_4b53_b1f4_0f971b7c4fc2_fallback")?.setAttribute("hidden", "hidden");</script>
# <link href="https://www.unpkg.com/dt_for_itables@2.5.8/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import { ITable, jQuery as $ } from 'https://www.unpkg.com/dt_for_itables@2.5.8/dt_bundle.js';
#
#     document.querySelectorAll("#itables_70cf852c_a37a_4b53_b1f4_0f971b7c4fc2:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         let dt_args = {
#           "classes": ["display", "nowrap", "compact"],
#           "data_json": "[[\"spark_catalog\"]]",
#           "layout": {"bottomEnd": null, "bottomStart": null, "topEnd": null, "topStart": null},
#           "lengthMenu": [10, 25, 50, 100],
#           "order": [],
#           "pageLength": 25,
#           "scrollCollapse": true,
#           "scrollX": true,
#           "scrollY": "500px",
#           "style": {"caption-side": "bottom", "margin": "0", "table-layout": "auto", "width": "auto"},
#           "table_html": "<table><thead>\n    <tr style=\"text-align: right;\">\n      \n      <th>catalog</th>\n    </tr>\n  </thead></table>",
#           "text_in_header_can_be_selected": true
#         };
#         new ITable(table, dt_args);
#     });
# </script>
# <!--| quarto-html-table-processing: none -->
# <table id="itables_45c47d54_314e_4ef7_b925_4f47599b58e9" hidden="hidden">
#   <tbody>
#     <tr>
#       <td style="vertical-align:middle; text-align:left"><a href=https://itables.org/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:var(--itables-logo-paper,#d9d7fc)">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:var(--itables-logo-ink,#1a1366);stroke:var(--itables-logo-ink,#1a1366);">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#         Loading ITables v2.9.1 from the internet...
#         (need <a href=https://itables.org/troubleshooting.html>help</a>?)
#       </td>
#     </tr>
#   </tbody>
# </table>
# <div id="itables_45c47d54_314e_4ef7_b925_4f47599b58e9_fallback"><table style="border-collapse:collapse"><thead>    <tr style="text-align: right;">
#       <th style="border:1px solid #ddd;padding:8px"><sup><noscript><span title="JavaScript not allowed. Please trust this notebook to get interactive tables.">🔒</span></noscript><a href=https://itables.org/fallbacks/static_preview.html title="ITables v2.9.1 static preview">ⓘ</a></sup>namespace</th>
#     </tr></thead><tbody>
# <tr><td style="border:1px solid #ddd;padding:8px">default</td></tr>
# </tbody></table></div><script>document.getElementById("itables_45c47d54_314e_4ef7_b925_4f47599b58e9")?.removeAttribute("hidden");document.getElementById("itables_45c47d54_314e_4ef7_b925_4f47599b58e9_fallback")?.setAttribute("hidden", "hidden");</script>
# <link href="https://www.unpkg.com/dt_for_itables@2.5.8/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import { ITable, jQuery as $ } from 'https://www.unpkg.com/dt_for_itables@2.5.8/dt_bundle.js';
#
#     document.querySelectorAll("#itables_45c47d54_314e_4ef7_b925_4f47599b58e9:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         let dt_args = {
#           "classes": ["display", "nowrap", "compact"],
#           "data_json": "[[\"default\"]]",
#           "layout": {"bottomEnd": null, "bottomStart": null, "topEnd": null, "topStart": null},
#           "lengthMenu": [10, 25, 50, 100],
#           "order": [],
#           "pageLength": 25,
#           "scrollCollapse": true,
#           "scrollX": true,
#           "scrollY": "500px",
#           "style": {"caption-side": "bottom", "margin": "0", "table-layout": "auto", "width": "auto"},
#           "table_html": "<table><thead>\n    <tr style=\"text-align: right;\">\n      \n      <th>namespace</th>\n    </tr>\n  </thead></table>",
#           "text_in_header_can_be_selected": true
#         };
#         new ITable(table, dt_args);
#     });
# </script>
# Catalog local: org.apache.iceberg.spark.SparkCatalog. Current:
# org.apache.spark.sql.execution.datasources.v2.V2SessionCatalog
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
# <div>
#   <div style="font-weight: 600; margin-bottom: 0.5rem;">SparkContext</div>
#   <div style="margin-bottom: 0.75rem;">
#     <a href="http://jupyter-spark-4-1.localhost:8080/webui/" target="_blank" rel="noopener noreferrer">Spark UI</a>
#   </div>
#   <table>
#     <tr><th align="left">Version</th><td>4.1.3</td></tr>
#     <tr><th align="left">Master</th><td>local[12]</td></tr>
#     <tr><th align="left">AppName</th><td>main</td></tr>
#   </table>
# </div>
#
#             </div>
#                total        used        free      shared  buff/cache   available
# Mem:            62Gi        27Gi        12Gi       8.3Gi        31Gi        35Gi
# Swap:          8.0Gi          0B       8.0Gi

# %%
from pyspark.sql import SparkSession
from pyspark.sql import functions as F
from pyspark.sql.types import (
    ByteType,
    DateType,
    DecimalType,
    IntegerType,
    LongType,
    ShortType,
    StringType,
    StructField,
    StructType,
)

# (field name, field size, Spark data type)
fields = [
    ("PARID", 30, StringType()),
    ("BORO", 1, ByteType()),
    ("BLOCK", 5, StringType()),
    ("LOT", 4, StringType()),
    ("EASE", 1, StringType()),
    ("SUBIDENT_REUC", 10, StringType()),
    ("RECTYPE", 1, ByteType()),
    ("TAXYR", 4, ShortType()),
    ("IDENT", 10, StringType()),
    ("SUBIDENT", 10, StringType()),
    ("ROLL_SECTION", 1, ByteType()),
    ("SECVOL", 5, StringType()),

    ("PYMKTLAND", 12, LongType()),
    ("PYMKTTOT", 12, LongType()),
    ("PYACTLAND", 12, LongType()),
    ("PYACTTOT", 12, LongType()),
    ("PYACTEXTOT", 12, LongType()),
    ("PYTRNLAND", 12, LongType()),
    ("PYTRNTOT", 12, LongType()),
    ("PYTRNEXTOT", 12, LongType()),
    ("PYTXBTOT", 12, LongType()),
    ("PYTXBEXTOT", 12, LongType()),
    ("PYTAXCLASS", 2, StringType()),

    ("TENMKTLAND", 12, LongType()),
    ("TENMKTTOT", 12, LongType()),
    ("TENACTLAND", 12, LongType()),
    ("TENACTTOT", 12, LongType()),
    ("TENACTEXTOT", 12, LongType()),
    ("TENTRNLAND", 12, LongType()),
    ("TENTRNTOT", 12, LongType()),
    ("TENTRNEXTOT", 12, LongType()),
    ("TENTXBTOT", 12, LongType()),
    ("TENTXBEXTOT", 12, LongType()),
    ("TENTAXCLASS", 2, StringType()),

    ("CBNMKTLAND", 12, LongType()),
    ("CBNMKTTOT", 12, LongType()),
    ("CBNACTLAND", 12, LongType()),
    ("CBNACTTOT", 12, LongType()),
    ("CBNACTEXTOT", 12, LongType()),
    ("CBNTRNLAND", 12, LongType()),
    ("CBNTRNTOT", 12, LongType()),
    ("CBNTRNEXTOT", 12, LongType()),
    ("CBNTXBTOT", 12, LongType()),
    ("CBNTXBEXTOT", 12, LongType()),
    ("CBNTAXCLASS", 2, StringType()),

    ("FINMKTLAND", 12, LongType()),
    ("FINMKTTOT", 12, LongType()),
    ("FINACTLAND", 12, LongType()),
    ("FINACTTOT", 12, LongType()),
    ("FINACTEXTOT", 12, LongType()),
    ("FINTRNLAND", 12, LongType()),
    ("FINTRNTOT", 12, LongType()),
    ("FINTRNEXTOT", 12, LongType()),
    ("FINTXBTOT", 12, LongType()),
    ("FINTXBEXTOT", 12, LongType()),
    ("FINTAXCLASS", 2, StringType()),

    ("CURMKTLAND", 12, LongType()),
    ("CURMKTTOT", 12, LongType()),
    ("CURACTLAND", 12, LongType()),
    ("CURACTTOT", 12, LongType()),
    ("CURACTEXTOT", 12, LongType()),
    ("CURTRNLAND", 12, LongType()),
    ("CURTRNTOT", 12, LongType()),
    ("CURTRNEXTOT", 12, LongType()),
    ("CURTXBTOT", 12, LongType()),
    ("CURTXBEXTOT", 12, LongType()),
    ("CURTAXCLASS", 2, StringType()),

    ("PERIOD", 1, ByteType()),
    ("NEWDROP", 1, ByteType()),
    ("NOAV", 1, StringType()),
    ("VALREF", 1, StringType()),
    ("BLDG_CLASS", 2, StringType()),

    ("OWNER", 80, StringType()),
    ("ZONING", 10, StringType()),
    ("HOUSENUM_LO", 12, StringType()),
    ("HOUSENUM_HI", 12, StringType()),
    ("STREET_NAME", 30, StringType()),
    ("ZIP_CODE", 10, StringType()),
    ("GEOSUPPORT_RC", 2, StringType()),
    ("STCODE", 12, StringType()),

    ("LOT_FRT", 8, DecimalType(7, 2)),
    ("LOT_DEP", 8, DecimalType(7, 2)),
    ("LOT_IRREG", 1, StringType()),
    ("BLD_FRT", 8, DecimalType(7, 2)),
    ("BLD_DEP", 8, DecimalType(7, 2)),
    ("BLD_EXT", 2, StringType()),
    ("BLD_STORY", 7, DecimalType(6, 2)),
    ("CORNER", 2, StringType()),

    ("LAND_AREA", 10, LongType()),
    ("NUM_BLDGS", 6, IntegerType()),

    ("YRBUILT", 4, ShortType()),
    ("YRBUILT_RANGE", 4, ShortType()),
    ("YRBUILT_FLAG", 1, StringType()),
    ("YRALT1", 4, ShortType()),
    ("YRALT1_RANGE", 4, ShortType()),
    ("YRALT2", 4, ShortType()),
    ("YRALT2_RANGE", 4, ShortType()),

    ("COOP_APTS", 6, IntegerType()),
    ("UNITS", 6, IntegerType()),

    ("REUC_REF", 20, StringType()),
    ("APTNO", 10, StringType()),
    ("COOP_NUM", 7, StringType()),

    ("CPB_BORO", 1, ByteType()),
    ("CPB_DIST", 2, ByteType()),
    ("APPT_DATE", 8, StringType()),
    ("APPT_BORO", 1, ByteType()),
    ("APPT_BLOCK", 5, StringType()),
    ("APPT_LOT", 4, StringType()),
    ("APPT_EASE", 1, StringType()),

    ("CONDO_NUMBER", 6, StringType()),
    ("CONDO_SFX1", 1, StringType()),
    ("CONDO_SFX2", 1, StringType()),
    ("CONDO_SFX3", 1, StringType()),

    ("UAF_LAND", 12, DecimalType(10, 7)),
    ("UAF_BLDG", 12, DecimalType(10, 7)),

    ("PROTEST_1", 3, StringType()),
    ("PROTEST_2", 3, StringType()),
    ("PROTEST_OLD", 3, StringType()),

    ("ATTORNEY_GROUP1", 4, StringType()),
    ("ATTORNEY_GROUP2", 4, StringType()),
    ("ATTORNEY_GROUP_OLD", 4, StringType()),

    ("GROSS_SQFT", 10, LongType()),
    ("HOTEL_AREA_GROSS", 9, LongType()),
    ("OFFICE_AREA_GROSS", 9, LongType()),
    ("RESIDENTIAL_AREA_GROSS", 9, LongType()),
    ("RETAIL_AREA_GROSS", 9, LongType()),
    ("LOFT_AREA_GROSS", 9, LongType()),
    ("FACTORY_AREA_GROSS", 9, LongType()),
    ("WAREHOUSE_AREA_GROSS", 9, LongType()),
    ("STORAGE_AREA_GROSS", 9, LongType()),
    ("GARAGE_AREA", 9, LongType()),
    ("OTHER_AREA_GROSS", 9, LongType()),

    ("REUC_DESCRIPTION", 500, StringType()),

    ("EXTRACTDT", 8, DateType()),

    # Read T/F fields as strings first.
    ("PYTAXFLAG", 1, StringType()),
    ("TENTAXFLAG", 1, StringType()),
    ("CBNTAXFLAG", 1, StringType()),
    ("FINTAXFLAG", 1, StringType()),
    ("CURTAXFLAG", 1, StringType()),
]


schema = StructType(
    [
        StructField(name, data_type, True)
        for name, size, data_type in fields
    ]
    + [
        StructField("_TRAILING", StringType(), True)
    ]
)


path = "/home/jovyan/work/data/nyc.gov/PROPMAST_ORE_2027_FIN.txt"


df = (
    spark.read
    .option("sep", "\t")
    .option("header", False)
    .option("mode", "FAILFAST")
    .option("ignoreLeadingWhiteSpace", True)
    .option("ignoreTrailingWhiteSpace", True)
    .option("dateFormat", "yyyyMMdd")
    .schema(schema)
    .csv(path)
    .drop("_TRAILING")
)


# Convert T/F columns to Boolean.
boolean_columns = [
    "PYTAXFLAG",
    "TENTAXFLAG",
    "CBNTAXFLAG",
    "FINTAXFLAG",
    "CURTAXFLAG",
]

for column in boolean_columns:
    df = df.withColumn(
        column,
        F.when(F.col(column) == "T", F.lit(True))
        .when(F.col(column) == "A", F.lit(False))
        .when(F.col(column).isNull(), F.lit(None).cast("boolean"))
        .otherwise(
            F.raise_error(
                F.concat(
                    F.lit(f"Invalid boolean value in {column}: "),
                    F.col(column),
                )
            )
        ),
    )


# Convert T/F columns to Boolean.
boolean_columns = [
    "NOAV",
]

for column in boolean_columns:
    df = df.withColumn(
        column,
        F.when(F.col(column) == "Y", F.lit(True))
        .when(F.col(column) == "0", F.lit(False))
        .when(F.col(column).isNull(), F.lit(None).cast("boolean"))
        .otherwise(
            F.raise_error(
                F.concat(
                    F.lit(f"Invalid boolean value in {column}: "),
                    F.col(column),
                )
            )
        ),
    )        


# Validate.
print(f"Records: {df.count():,}")
print(f"Columns: {len(df.columns)}")

#df.createOrReplaceTempView("property_master_temp")
df.printSchema()
# Out:
# Records: 1,167,963
# Columns: 139
# root
#  |-- PARID: string (nullable = true)
#  |-- BORO: byte (nullable = true)
#  |-- BLOCK: string (nullable = true)
#  |-- LOT: string (nullable = true)
#  |-- EASE: string (nullable = true)
#  |-- SUBIDENT_REUC: string (nullable = true)
#  |-- RECTYPE: byte (nullable = true)
#  |-- TAXYR: short (nullable = true)
#  |-- IDENT: string (nullable = true)
#  |-- SUBIDENT: string (nullable = true)
#  |-- ROLL_SECTION: byte (nullable = true)
#  |-- SECVOL: string (nullable = true)
#  |-- PYMKTLAND: long (nullable = true)
#  |-- PYMKTTOT: long (nullable = true)
#  |-- PYACTLAND: long (nullable = true)
#  |-- PYACTTOT: long (nullable = true)
#  |-- PYACTEXTOT: long (nullable = true)
#  |-- PYTRNLAND: long (nullable = true)
#  |-- PYTRNTOT: long (nullable = true)
#  |-- PYTRNEXTOT: long (nullable = true)
#  |-- PYTXBTOT: long (nullable = true)
#  |-- PYTXBEXTOT: long (nullable = true)
#  |-- PYTAXCLASS: string (nullable = true)
#  |-- TENMKTLAND: long (nullable = true)
#  |-- TENMKTTOT: long (nullable = true)
#  |-- TENACTLAND: long (nullable = true)
#  |-- TENACTTOT: long (nullable = true)
#  |-- TENACTEXTOT: long (nullable = true)
#  |-- TENTRNLAND: long (nullable = true)
#  |-- TENTRNTOT: long (nullable = true)
#  |-- TENTRNEXTOT: long (nullable = true)
#  |-- TENTXBTOT: long (nullable = true)
#  |-- TENTXBEXTOT: long (nullable = true)
#  |-- TENTAXCLASS: string (nullable = true)
#  |-- CBNMKTLAND: long (nullable = true)
#  |-- CBNMKTTOT: long (nullable = true)
#  |-- CBNACTLAND: long (nullable = true)
#  |-- CBNACTTOT: long (nullable = true)
#  |-- CBNACTEXTOT: long (nullable = true)
#  |-- CBNTRNLAND: long (nullable = true)
#  |-- CBNTRNTOT: long (nullable = true)
#  |-- CBNTRNEXTOT: long (nullable = true)
#  |-- CBNTXBTOT: long (nullable = true)
#  |-- CBNTXBEXTOT: long (nullable = true)
#  |-- CBNTAXCLASS: string (nullable = true)
#  |-- FINMKTLAND: long (nullable = true)
#  |-- FINMKTTOT: long (nullable = true)
#  |-- FINACTLAND: long (nullable = true)
#  |-- FINACTTOT: long (nullable = true)
#  |-- FINACTEXTOT: long (nullable = true)
#  |-- FINTRNLAND: long (nullable = true)
#  |-- FINTRNTOT: long (nullable = true)
#  |-- FINTRNEXTOT: long (nullable = true)
#  |-- FINTXBTOT: long (nullable = true)
#  |-- FINTXBEXTOT: long (nullable = true)
#  |-- FINTAXCLASS: string (nullable = true)
#  |-- CURMKTLAND: long (nullable = true)
#  |-- CURMKTTOT: long (nullable = true)
#  |-- CURACTLAND: long (nullable = true)
#  |-- CURACTTOT: long (nullable = true)
#  |-- CURACTEXTOT: long (nullable = true)
#  |-- CURTRNLAND: long (nullable = true)
#  |-- CURTRNTOT: long (nullable = true)
#  |-- CURTRNEXTOT: long (nullable = true)
#  |-- CURTXBTOT: long (nullable = true)
#  |-- CURTXBEXTOT: long (nullable = true)
#  |-- CURTAXCLASS: string (nullable = true)
#  |-- PERIOD: byte (nullable = true)
#  |-- NEWDROP: byte (nullable = true)
#  |-- NOAV: boolean (nullable = true)
#  |-- VALREF: string (nullable = true)
#  |-- BLDG_CLASS: string (nullable = true)
#  |-- OWNER: string (nullable = true)
#  |-- ZONING: string (nullable = true)
#  |-- HOUSENUM_LO: string (nullable = true)
#  |-- HOUSENUM_HI: string (nullable = true)
#  |-- STREET_NAME: string (nullable = true)
#  |-- ZIP_CODE: string (nullable = true)
#  |-- GEOSUPPORT_RC: string (nullable = true)
#  |-- STCODE: string (nullable = true)
#  |-- LOT_FRT: decimal(7,2) (nullable = true)
#  |-- LOT_DEP: decimal(7,2) (nullable = true)
#  |-- LOT_IRREG: string (nullable = true)
#  |-- BLD_FRT: decimal(7,2) (nullable = true)
#  |-- BLD_DEP: decimal(7,2) (nullable = true)
#  |-- BLD_EXT: string (nullable = true)
#  |-- BLD_STORY: decimal(6,2) (nullable = true)
#  |-- CORNER: string (nullable = true)
#  |-- LAND_AREA: long (nullable = true)
#  |-- NUM_BLDGS: integer (nullable = true)
#  |-- YRBUILT: short (nullable = true)
#  |-- YRBUILT_RANGE: short (nullable = true)
#  |-- YRBUILT_FLAG: string (nullable = true)
#  |-- YRALT1: short (nullable = true)
#  |-- YRALT1_RANGE: short (nullable = true)
#  |-- YRALT2: short (nullable = true)
#  |-- YRALT2_RANGE: short (nullable = true)
#  |-- COOP_APTS: integer (nullable = true)
#  |-- UNITS: integer (nullable = true)
#  |-- REUC_REF: string (nullable = true)
#  |-- APTNO: string (nullable = true)
#  |-- COOP_NUM: string (nullable = true)
#  |-- CPB_BORO: byte (nullable = true)
#  |-- CPB_DIST: byte (nullable = true)
#  |-- APPT_DATE: string (nullable = true)
#  |-- APPT_BORO: byte (nullable = true)
#  |-- APPT_BLOCK: string (nullable = true)
#  |-- APPT_LOT: string (nullable = true)
#  |-- APPT_EASE: string (nullable = true)
#  |-- CONDO_NUMBER: string (nullable = true)
#  |-- CONDO_SFX1: string (nullable = true)
#  |-- CONDO_SFX2: string (nullable = true)
#  |-- CONDO_SFX3: string (nullable = true)
#  |-- UAF_LAND: decimal(10,7) (nullable = true)
#  |-- UAF_BLDG: decimal(10,7) (nullable = true)
#  |-- PROTEST_1: string (nullable = true)
#  |-- PROTEST_2: string (nullable = true)
#  |-- PROTEST_OLD: string (nullable = true)
#  |-- ATTORNEY_GROUP1: string (nullable = true)
#  |-- ATTORNEY_GROUP2: string (nullable = true)
#  |-- ATTORNEY_GROUP_OLD: string (nullable = true)
#  |-- GROSS_SQFT: long (nullable = true)
#  |-- HOTEL_AREA_GROSS: long (nullable = true)
#  |-- OFFICE_AREA_GROSS: long (nullable = true)
#  |-- RESIDENTIAL_AREA_GROSS: long (nullable = true)
#  |-- RETAIL_AREA_GROSS: long (nullable = true)
#  |-- LOFT_AREA_GROSS: long (nullable = true)
#  |-- FACTORY_AREA_GROSS: long (nullable = true)
#  |-- WAREHOUSE_AREA_GROSS: long (nullable = true)
#  |-- STORAGE_AREA_GROSS: long (nullable = true)
#  |-- GARAGE_AREA: long (nullable = true)
#  |-- OTHER_AREA_GROSS: long (nullable = true)
#  |-- REUC_DESCRIPTION: string (nullable = true)
#  |-- EXTRACTDT: date (nullable = true)
#  |-- PYTAXFLAG: boolean (nullable = true)
#  |-- TENTAXFLAG: boolean (nullable = true)
#  |-- CBNTAXFLAG: boolean (nullable = true)
#  |-- FINTAXFLAG: boolean (nullable = true)
#  |-- CURTAXFLAG: boolean (nullable = true)

# %%
df.cache()
# Out:
# DataFrame[PARID: string, BORO: tinyint, BLOCK: string, LOT: string, EASE: string, SUBIDENT_REUC: string, RECTYPE: tinyint, TAXYR: smallint, IDENT: string, SUBIDENT: string, ROLL_SECTION: tinyint, SECVOL: string, PYMKTLAND: bigint, PYMKTTOT: bigint, PYACTLAND: bigint, PYACTTOT: bigint, PYACTEXTOT: bigint, PYTRNLAND: bigint, PYTRNTOT: bigint, PYTRNEXTOT: bigint, PYTXBTOT: bigint, PYTXBEXTOT: bigint, PYTAXCLASS: string, TENMKTLAND: bigint, TENMKTTOT: bigint, TENACTLAND: bigint, TENACTTOT: bigint, TENACTEXTOT: bigint, TENTRNLAND: bigint, TENTRNTOT: bigint, TENTRNEXTOT: bigint, TENTXBTOT: bigint, TENTXBEXTOT: bigint, TENTAXCLASS: string, CBNMKTLAND: bigint, CBNMKTTOT: bigint, CBNACTLAND: bigint, CBNACTTOT: bigint, CBNACTEXTOT: bigint, CBNTRNLAND: bigint, CBNTRNTOT: bigint, CBNTRNEXTOT: bigint, CBNTXBTOT: bigint, CBNTXBEXTOT: bigint, CBNTAXCLASS: string, FINMKTLAND: bigint, FINMKTTOT: bigint, FINACTLAND: bigint, FINACTTOT: bigint, FINACTEXTOT: bigint, FINTRNLAND: bigint, FINTRNTOT: bigint, FINTRNEXTOT: bigint, FINTXBTOT: bigint, FINTXBEXTOT: bigint, FINTAXCLASS: string, CURMKTLAND: bigint, CURMKTTOT: bigint, CURACTLAND: bigint, CURACTTOT: bigint, CURACTEXTOT: bigint, CURTRNLAND: bigint, CURTRNTOT: bigint, CURTRNEXTOT: bigint, CURTXBTOT: bigint, CURTXBEXTOT: bigint, CURTAXCLASS: string, PERIOD: tinyint, NEWDROP: tinyint, NOAV: boolean, VALREF: string, BLDG_CLASS: string, OWNER: string, ZONING: string, HOUSENUM_LO: string, HOUSENUM_HI: string, STREET_NAME: string, ZIP_CODE: string, GEOSUPPORT_RC: string, STCODE: string, LOT_FRT: decimal(7,2), LOT_DEP: decimal(7,2), LOT_IRREG: string, BLD_FRT: decimal(7,2), BLD_DEP: decimal(7,2), BLD_EXT: string, BLD_STORY: decimal(6,2), CORNER: string, LAND_AREA: bigint, NUM_BLDGS: int, YRBUILT: smallint, YRBUILT_RANGE: smallint, YRBUILT_FLAG: string, YRALT1: smallint, YRALT1_RANGE: smallint, YRALT2: smallint, YRALT2_RANGE: smallint, COOP_APTS: int, UNITS: int, REUC_REF: string, APTNO: string, COOP_NUM: string, CPB_BORO: tinyint, CPB_DIST: tinyint, APPT_DATE: string, APPT_BORO: tinyint, APPT_BLOCK: string, APPT_LOT: string, APPT_EASE: string, CONDO_NUMBER: string, CONDO_SFX1: string, CONDO_SFX2: string, CONDO_SFX3: string, UAF_LAND: decimal(10,7), UAF_BLDG: decimal(10,7), PROTEST_1: string, PROTEST_2: string, PROTEST_OLD: string, ATTORNEY_GROUP1: string, ATTORNEY_GROUP2: string, ATTORNEY_GROUP_OLD: string, GROSS_SQFT: bigint, HOTEL_AREA_GROSS: bigint, OFFICE_AREA_GROSS: bigint, RESIDENTIAL_AREA_GROSS: bigint, RETAIL_AREA_GROSS: bigint, LOFT_AREA_GROSS: bigint, FACTORY_AREA_GROSS: bigint, WAREHOUSE_AREA_GROSS: bigint, STORAGE_AREA_GROSS: bigint, GARAGE_AREA: bigint, OTHER_AREA_GROSS: bigint, REUC_DESCRIPTION: string, EXTRACTDT: date, PYTAXFLAG: boolean, TENTAXFLAG: boolean, CBNTAXFLAG: boolean, FINTAXFLAG: boolean, CURTAXFLAG: boolean]

# %%
record_count = df.count()
print(record_count)
# Out:
# 1167963

# %%
viewdf(df)
# Out:
# <!--| quarto-html-table-processing: none -->
# <table id="itables_4179af69_4a9a_437b_a1a8_6fbe54343ed6" hidden="hidden">
#   <tbody>
#     <tr>
#       <td style="vertical-align:middle; text-align:left"><a href=https://itables.org/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:var(--itables-logo-paper,#d9d7fc)">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:var(--itables-logo-ink,#1a1366);stroke:var(--itables-logo-ink,#1a1366);">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#         Loading ITables v2.9.1 from the internet...
#         (need <a href=https://itables.org/troubleshooting.html>help</a>?)
#       </td>
#     </tr>
#   </tbody>
# </table>
# <div id="itables_4179af69_4a9a_437b_a1a8_6fbe54343ed6_fallback"><table style="border-collapse:collapse"><thead>    <tr style="text-align: right;">
#       <th style="border:1px solid #ddd;padding:8px"><sup><noscript><span title="JavaScript not allowed. Please trust this notebook to get interactive tables.">🔒</span></noscript><a href=https://itables.org/fallbacks/static_preview.html title="ITables v2.9.1 static preview">ⓘ</a></sup>PARID</th>
#       <th style="border:1px solid #ddd;padding:8px">BORO</th>
#       <th style="border:1px solid #ddd;padding:8px">BLOCK</th>
#       <th style="border:1px solid #ddd;padding:8px">LOT</th>
#       <th style="border:1px solid #ddd;padding:8px">EASE</th>
#       <th style="border:1px solid #ddd;padding:8px">SUBIDENT_REUC</th>
#       <th style="border:1px solid #ddd;padding:8px">RECTYPE</th>
#       <th style="border:1px solid #ddd;padding:8px">TAXYR</th>
#       <th style="border:1px solid #ddd;padding:8px">IDENT</th>
#       <th style="border:1px solid #ddd;padding:8px">SUBIDENT</th>
#       <th style="border:1px solid #ddd;padding:8px">ROLL_SECTION</th>
#       <th style="border:1px solid #ddd;padding:8px">SECVOL</th>
#       <th style="border:1px solid #ddd;padding:8px">PYMKTLAND</th>
#       <th style="border:1px solid #ddd;padding:8px">PYMKTTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">PYACTLAND</th>
#       <th style="border:1px solid #ddd;padding:8px">PYACTTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">PYACTEXTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">PYTRNLAND</th>
#       <th style="border:1px solid #ddd;padding:8px">PYTRNTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">PYTRNEXTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">PYTXBTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">PYTXBEXTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">PYTAXCLASS</th>
#       <th style="border:1px solid #ddd;padding:8px">TENMKTLAND</th>
#       <th style="border:1px solid #ddd;padding:8px">TENMKTTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">TENACTLAND</th>
#       <th style="border:1px solid #ddd;padding:8px">TENACTTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">TENACTEXTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">TENTRNLAND</th>
#       <th style="border:1px solid #ddd;padding:8px">TENTRNTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">TENTRNEXTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">TENTXBTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">TENTXBEXTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">TENTAXCLASS</th>
#       <th style="border:1px solid #ddd;padding:8px">CBNMKTLAND</th>
#       <th style="border:1px solid #ddd;padding:8px">CBNMKTTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">CBNACTLAND</th>
#       <th style="border:1px solid #ddd;padding:8px">CBNACTTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">CBNACTEXTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">CBNTRNLAND</th>
#       <th style="border:1px solid #ddd;padding:8px">CBNTRNTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">CBNTRNEXTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">CBNTXBTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">CBNTXBEXTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">CBNTAXCLASS</th>
#       <th style="border:1px solid #ddd;padding:8px">FINMKTLAND</th>
#       <th style="border:1px solid #ddd;padding:8px">FINMKTTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">FINACTLAND</th>
#       <th style="border:1px solid #ddd;padding:8px">YRBUILT_RANGE</th>
#       <th style="border:1px solid #ddd;padding:8px">YRBUILT_FLAG</th>
#       <th style="border:1px solid #ddd;padding:8px">YRALT1</th>
#       <th style="border:1px solid #ddd;padding:8px">YRALT1_RANGE</th>
#       <th style="border:1px solid #ddd;padding:8px">YRALT2</th>
#       <th style="border:1px solid #ddd;padding:8px">YRALT2_RANGE</th>
#       <th style="border:1px solid #ddd;padding:8px">COOP_APTS</th>
#       <th style="border:1px solid #ddd;padding:8px">UNITS</th>
#       <th style="border:1px solid #ddd;padding:8px">REUC_REF</th>
#       <th style="border:1px solid #ddd;padding:8px">APTNO</th>
#       <th style="border:1px solid #ddd;padding:8px">COOP_NUM</th>
#       <th style="border:1px solid #ddd;padding:8px">CPB_BORO</th>
#       <th style="border:1px solid #ddd;padding:8px">CPB_DIST</th>
#       <th style="border:1px solid #ddd;padding:8px">APPT_DATE</th>
#       <th style="border:1px solid #ddd;padding:8px">APPT_BORO</th>
#       <th style="border:1px solid #ddd;padding:8px">APPT_BLOCK</th>
#       <th style="border:1px solid #ddd;padding:8px">APPT_LOT</th>
#       <th

# %%
# Save as a managed Iceberg table.
table_name = "nyc_property_master"

spark.sql("CREATE NAMESPACE IF NOT EXISTS local.default")
spark.sql("USE local.default")

(
    df.writeTo(table_name)
    .using("iceberg")
    .createOrReplace()
)

# %%
# %sql SHOW TABLES
# Out:
# <!--| quarto-html-table-processing: none -->
# <table id="itables_7e1b0afa_1389_4b8f_a854_846609c60cb6" hidden="hidden">
#   <tbody>
#     <tr>
#       <td style="vertical-align:middle; text-align:left"><a href=https://itables.org/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:var(--itables-logo-paper,#d9d7fc)">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:var(--itables-logo-ink,#1a1366);stroke:var(--itables-logo-ink,#1a1366);">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#         Loading ITables v2.9.1 from the internet...
#         (need <a href=https://itables.org/troubleshooting.html>help</a>?)
#       </td>
#     </tr>
#   </tbody>
# </table>
# <div id="itables_7e1b0afa_1389_4b8f_a854_846609c60cb6_fallback"><table style="border-collapse:collapse"><thead>    <tr style="text-align: right;">
#       <th style="border:1px solid #ddd;padding:8px"><sup><noscript><span title="JavaScript not allowed. Please trust this notebook to get interactive tables.">🔒</span></noscript><a href=https://itables.org/fallbacks/static_preview.html title="ITables v2.9.1 static preview">ⓘ</a></sup>namespace</th>
#       <th style="border:1px solid #ddd;padding:8px">tableName</th>
#       <th style="border:1px solid #ddd;padding:8px">isTemporary</th>
#     </tr></thead><tbody>
# <tr><td style="border:1px solid #ddd;padding:8px">default</td><td style="border:1px solid #ddd;padding:8px">nyc_property_master</td><td style="border:1px solid #ddd;padding:8px">False</td></tr>
# </tbody></table></div><script>document.getElementById("itables_7e1b0afa_1389_4b8f_a854_846609c60cb6")?.removeAttribute("hidden");document.getElementById("itables_7e1b0afa_1389_4b8f_a854_846609c60cb6_fallback")?.setAttribute("hidden", "hidden");</script>
# <link href="https://www.unpkg.com/dt_for_itables@2.5.8/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import { ITable, jQuery as $ } from 'https://www.unpkg.com/dt_for_itables@2.5.8/dt_bundle.js';
#
#     document.querySelectorAll("#itables_7e1b0afa_1389_4b8f_a854_846609c60cb6:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         let dt_args = {
#           "classes": ["display", "nowrap", "compact"],
#           "data_json": "[[\"default\", \"nyc_property_master\", false]]",
#           "layout": {"bottomEnd": null, "bottomStart": null, "topEnd": null, "topStart": null},
#           "lengthMenu": [10, 25, 50, 100],
#           "order": [],
#           "pageLength": 25,
#           "scrollCollapse": true,
#           "scrollX": true,
#           "scrollY": "500px",
#           "style": {"caption-side": "bottom", "margin": "0", "table-layout": "auto", "width": "auto"},
#           "table_html": "<table><thead>\n    <tr style=\"text-align: right;\">\n      \n      <th>namespace</th>\n      <th>tableName</th>\n      <th>isTemporary</th>\n    </tr>\n  </thead></table>",
#           "text_in_header_can_be_selected": true
#         };
#         new ITable(table, dt_args);
#     });
# </script>

# %%
# %%sql
# SELECT count(*)
# FROM nyc_property_master;
# Out:
# <!--| quarto-html-table-processing: none -->
# <table id="itables_15a146a4_366d_41c7_aff3_1f45628ca670" hidden="hidden">
#   <tbody>
#     <tr>
#       <td style="vertical-align:middle; text-align:left"><a href=https://itables.org/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:var(--itables-logo-paper,#d9d7fc)">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:var(--itables-logo-ink,#1a1366);stroke:var(--itables-logo-ink,#1a1366);">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#         Loading ITables v2.9.1 from the internet...
#         (need <a href=https://itables.org/troubleshooting.html>help</a>?)
#       </td>
#     </tr>
#   </tbody>
# </table>
# <div id="itables_15a146a4_366d_41c7_aff3_1f45628ca670_fallback"><table style="border-collapse:collapse"><thead>    <tr style="text-align: right;">
#       <th style="border:1px solid #ddd;padding:8px"><sup><noscript><span title="JavaScript not allowed. Please trust this notebook to get interactive tables.">🔒</span></noscript><a href=https://itables.org/fallbacks/static_preview.html title="ITables v2.9.1 static preview">ⓘ</a></sup>count(1)</th>
#     </tr></thead><tbody>
# <tr><td style="border:1px solid #ddd;padding:8px">1167963</td></tr>
# </tbody></table></div><script>document.getElementById("itables_15a146a4_366d_41c7_aff3_1f45628ca670")?.removeAttribute("hidden");document.getElementById("itables_15a146a4_366d_41c7_aff3_1f45628ca670_fallback")?.setAttribute("hidden", "hidden");</script>
# <link href="https://www.unpkg.com/dt_for_itables@2.5.8/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import { ITable, jQuery as $ } from 'https://www.unpkg.com/dt_for_itables@2.5.8/dt_bundle.js';
#
#     document.querySelectorAll("#itables_15a146a4_366d_41c7_aff3_1f45628ca670:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         let dt_args = {
#           "classes": ["display", "nowrap", "compact"],
#           "data_json": "[[1167963]]",
#           "layout": {"bottomEnd": null, "bottomStart": null, "topEnd": null, "topStart": null},
#           "lengthMenu": [10, 25, 50, 100],
#           "order": [],
#           "pageLength": 25,
#           "scrollCollapse": true,
#           "scrollX": true,
#           "scrollY": "500px",
#           "style": {"caption-side": "bottom", "margin": "0", "table-layout": "auto", "width": "auto"},
#           "table_html": "<table><thead>\n    <tr style=\"text-align: right;\">\n      \n      <th>count(1)</th>\n    </tr>\n  </thead></table>",
#           "text_in_header_can_be_selected": true
#         };
#         new ITable(table, dt_args);
#     });
# </script>

# %%
# %sql DESCRIBE TABLE EXTENDED nyc_property_master
# Out:
# <!--| quarto-html-table-processing: none -->
# <table id="itables_afaf5fa3_d418_4fc6_9f86_4be44d0580b7" hidden="hidden">
#   <tbody>
#     <tr>
#       <td style="vertical-align:middle; text-align:left"><a href=https://itables.org/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:var(--itables-logo-paper,#d9d7fc)">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:var(--itables-logo-ink,#1a1366);stroke:var(--itables-logo-ink,#1a1366);">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#         Loading ITables v2.9.1 from the internet...
#         (need <a href=https://itables.org/troubleshooting.html>help</a>?)
#       </td>
#     </tr>
#   </tbody>
# </table>
# <div id="itables_afaf5fa3_d418_4fc6_9f86_4be44d0580b7_fallback"><table style="border-collapse:collapse"><thead>    <tr style="text-align: right;">
#       <th style="border:1px solid #ddd;padding:8px"><sup><noscript><span title="JavaScript not allowed. Please trust this notebook to get interactive tables.">🔒</span></noscript><a href=https://itables.org/fallbacks/static_preview.html title="ITables v2.9.1 static preview">ⓘ</a></sup>col_name</th>
#       <th style="border:1px solid #ddd;padding:8px">data_type</th>
#       <th style="border:1px solid #ddd;padding:8px">comment</th>
#     </tr></thead><tbody>
# <tr><td style="border:1px solid #ddd;padding:8px">PARID</td><td style="border:1px solid #ddd;padding:8px">string</td><td style="border:1px solid #ddd;padding:8px">None</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">BORO</td><td style="border:1px solid #ddd;padding:8px">int</td><td style="border:1px solid #ddd;padding:8px">None</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">BLOCK</td><td style="border:1px solid #ddd;padding:8px">string</td><td style="border:1px solid #ddd;padding:8px">None</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">LOT</td><td style="border:1px solid #ddd;padding:8px">string</td><td style="border:1px solid #ddd;padding:8px">None</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">EASE</td><td style="border:1px solid #ddd;padding:8px">string</td><td style="border:1px solid #ddd;padding:8px">None</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">SUBIDENT_REUC</td><td style="border:1px solid #ddd;padding:8px">string</td><td style="border:1px solid #ddd;padding:8px">None</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">RECTYPE</td><td style="border:1px solid #ddd;padding:8px">int</td><td style="border:1px solid #ddd;padding:8px">None</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">TAXYR</td><td style="border:1px solid #ddd;padding:8px">int</td><td style="border:1px solid #ddd;padding:8px">None</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">IDENT</td><td style="border:1px solid #ddd;padding:8px">string</td><td style="border:1px solid #ddd;padding:8px">None</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">SUBIDENT</td><td style="border:1px solid #ddd;padding:8px">string</td><td style="border:1px solid #ddd;padding:8px">None</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">ROLL_SECTION</td><td style="border:1px solid #ddd;padding:8px">int</td><td style="border:1px solid #ddd;padding:8px">None</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">SECVOL</td><td style="border:1px solid #ddd;padding:8px">string</td><td style="border:1px solid #ddd;padding:8px">None</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">PYMKTLAND</td><td style="border:1px solid #ddd;padding:8px">bigint</td><td style="border:1px solid #ddd;padding:8px">None</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">PYMKTTOT</td><td style="border:1px solid #ddd;padding:8px">bigint</td><td style="border:1px solid #ddd;padding:8px">None</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">PYACTLAND</td><td style="border:1px solid #ddd;padding:8px">bigint</td><td style="border:1px solid #ddd;padding:8px">None</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">PYACTTOT</td><td style="border:1px solid #ddd;padding:8px">bigint</td><td style="border:1px solid #ddd;padding:8px">None</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">PYACTEXTOT</td><td style="border:1px solid #ddd;padding:8px">bigint</td><td style="border:1px solid #ddd;padding:8px">None</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">PYTRNLAND</td><td style="border:1px solid #ddd;padding:8px">bigint</td><td style="border:1px solid #ddd;padding:8px">None</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">PYTRNTOT</td><td style="border:1px solid #ddd;padding:8px">bigint</td><td style="border:1px solid #ddd;padding:8px">None</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">PYTRNEXTOT</td><td style="border:1px solid #ddd;padding:8px">bigint</td><td style="border:1px solid #ddd;padding:8px">None</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">PYTXBTOT</td><td style="border:1px solid #ddd;padding:8px">bigint</td><td style="border:1px solid #ddd;padding:8px">None</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">PYTXBEXTOT</td><td style="border:1px solid #ddd;padding:8px">bigint</td><td style="border:1px solid #ddd;padding:8px">None</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">PYTAXCLASS</td><td style="border:1px solid #ddd;padding:8px">string</td><td style="border:1px solid #ddd;padding:8px">No

# %%
# Verify the Parquet table.
df_parquet = spark.sql(f"""
    SELECT
        PARID,
        BLOCK,
        LOT,
        OWNER,
        ZONING,
        STREET_NAME,
        GROSS_SQFT,
        EXTRACTDT,
        CURTAXFLAG
    FROM {table_name}
    LIMIT 20
""")
viewdf(df_parquet)
# Out:
# <!--| quarto-html-table-processing: none -->
# <table id="itables_0d02f41c_d1c9_40e0_ba83_b376b0009265" hidden="hidden">
#   <tbody>
#     <tr>
#       <td style="vertical-align:middle; text-align:left"><a href=https://itables.org/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:var(--itables-logo-paper,#d9d7fc)">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:var(--itables-logo-ink,#1a1366);stroke:var(--itables-logo-ink,#1a1366);">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#         Loading ITables v2.9.1 from the internet...
#         (need <a href=https://itables.org/troubleshooting.html>help</a>?)
#       </td>
#     </tr>
#   </tbody>
# </table>
# <div id="itables_0d02f41c_d1c9_40e0_ba83_b376b0009265_fallback"><table style="border-collapse:collapse"><thead>    <tr style="text-align: right;">
#       <th style="border:1px solid #ddd;padding:8px"><sup><noscript><span title="JavaScript not allowed. Please trust this notebook to get interactive tables.">🔒</span></noscript><a href=https://itables.org/fallbacks/static_preview.html title="ITables v2.9.1 static preview">ⓘ</a></sup>PARID</th>
#       <th style="border:1px solid #ddd;padding:8px">BLOCK</th>
#       <th style="border:1px solid #ddd;padding:8px">LOT</th>
#       <th style="border:1px solid #ddd;padding:8px">OWNER</th>
#       <th style="border:1px solid #ddd;padding:8px">ZONING</th>
#       <th style="border:1px solid #ddd;padding:8px">STREET_NAME</th>
#       <th style="border:1px solid #ddd;padding:8px">GROSS_SQFT</th>
#       <th style="border:1px solid #ddd;padding:8px">EXTRACTDT</th>
#       <th style="border:1px solid #ddd;padding:8px">CURTAXFLAG</th>
#     </tr></thead><tbody>
# <tr><td style="border:1px solid #ddd;padding:8px">1009362140</td><td style="border:1px solid #ddd;padding:8px">00936</td><td style="border:1px solid #ddd;padding:8px">2140</td><td style="border:1px solid #ddd;padding:8px">PFEFFER CYNTHIA R</td><td style="border:1px solid #ddd;padding:8px">R8</td><td style="border:1px solid #ddd;padding:8px">EAST 30 STREET</td><td style="border:1px solid #ddd;padding:8px">718</td><td style="border:1px solid #ddd;padding:8px">2026-05-15</td><td style="border:1px solid #ddd;padding:8px">True</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">1009362141</td><td style="border:1px solid #ddd;padding:8px">00936</td><td style="border:1px solid #ddd;padding:8px">2141</td><td style="border:1px solid #ddd;padding:8px">OKAMURA  REIKO</td><td style="border:1px solid #ddd;padding:8px">R8</td><td style="border:1px solid #ddd;padding:8px">EAST 30 STREET</td><td style="border:1px solid #ddd;padding:8px">1206</td><td style="border:1px solid #ddd;padding:8px">2026-05-15</td><td style="border:1px solid #ddd;padding:8px">True</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">1009362145</td><td style="border:1px solid #ddd;padding:8px">00936</td><td style="border:1px solid #ddd;padding:8px">2145</td><td style="border:1px solid #ddd;padding:8px">WHEELER KIPS BAY HOLDINGS, LLC</td><td style="border:1px solid #ddd;padding:8px">R8</td><td style="border:1px solid #ddd;padding:8px">EAST 30 STREET</td><td style="border:1px solid #ddd;padding:8px">555</td><td style="border:1px solid #ddd;padding:8px">2026-05-15</td><td style="border:1px solid #ddd;padding:8px">True</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">1009363088</td><td style="border:1px solid #ddd;padding:8px">00936</td><td style="border:1px solid #ddd;padding:8px">3088</td><td style="border:1px solid #ddd;padding:8px">FARRELL WILLIAM R</td><td style="border:1px solid #ddd;padding:8px">R8</td><td style="border:1px solid #ddd;padding:8px">EAST 33 STREET</td><td style="border:1px solid #ddd;padding:8px">550</td><td style="border:1px solid #ddd;padding:8px">2026-05-15</td><td style="border:1px solid #ddd;padding:8px">True</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">1009363089</td><td style="border:1px solid #ddd;padding:8px">00936</td><td style="border:1px solid #ddd;padding:8px">3089</td><td style="border:1px solid #ddd;padding:8px">KAPSOU ELLIE</td><td style="border:1px solid #ddd;padding:8px">R8</td><td style="border:1px solid #ddd;padding:8px">EAST 33 STREET</td><td style="border:1px solid #ddd;padding:8px">469</td><td style="border:1px solid #ddd;padding:8px">2026-05-15</td><td style="border:1px solid #ddd;padding:8px">True</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">1009363090</td><td style="border:1px solid #ddd;padding:8px">00936</td><td style="border:1px solid #ddd;padding:8px">3090</td><td style="border:1px solid #ddd;padding:8px">ZEUREN CHARLES E</td><td style="border:1px solid #ddd;padding:8px">R8</td><td style="border:1px solid #ddd;padding:8px">EAST 33 STREET</td><td style="border:1px solid #ddd;padding:8px">480</td><td style="border:1px solid #ddd;padding:8px">2026-05-15</td><td style="border:1px solid #ddd;padding:8px">True</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">1009363091</td><td style="border:1px solid #ddd;padding:8px">00936</td><td style="border:1px solid #ddd;padding:8px">3091</td><td style="border:1px solid #ddd;padding:8px">AMBROSINO, BARBARA J</td><td style="border:1px solid #ddd;padding:8px">R8</td><td style="border:1px solid #ddd;padding:8px">EAST 33 STREET</td><td style="border:1px solid #ddd;padding:8px">480</td><td style="border:1px solid #ddd;padding:8px">2026-05-15</td><td style="border:1px solid #

# %%
# %sql SELECT * FROM {table_name}
# Out:
# <!--| quarto-html-table-processing: none -->
# <table id="itables_c8b8283a_3356_43be_aa5a_ee4bba54194a" hidden="hidden">
#   <tbody>
#     <tr>
#       <td style="vertical-align:middle; text-align:left"><a href=https://itables.org/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:var(--itables-logo-paper,#d9d7fc)">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:var(--itables-logo-ink,#1a1366);stroke:var(--itables-logo-ink,#1a1366);">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#         Loading ITables v2.9.1 from the internet...
#         (need <a href=https://itables.org/troubleshooting.html>help</a>?)
#       </td>
#     </tr>
#   </tbody>
# </table>
# <div id="itables_c8b8283a_3356_43be_aa5a_ee4bba54194a_fallback"><table style="border-collapse:collapse"><thead>    <tr style="text-align: right;">
#       <th style="border:1px solid #ddd;padding:8px"><sup><noscript><span title="JavaScript not allowed. Please trust this notebook to get interactive tables.">🔒</span></noscript><a href=https://itables.org/fallbacks/static_preview.html title="ITables v2.9.1 static preview">ⓘ</a></sup>PARID</th>
#       <th style="border:1px solid #ddd;padding:8px">BORO</th>
#       <th style="border:1px solid #ddd;padding:8px">BLOCK</th>
#       <th style="border:1px solid #ddd;padding:8px">LOT</th>
#       <th style="border:1px solid #ddd;padding:8px">EASE</th>
#       <th style="border:1px solid #ddd;padding:8px">SUBIDENT_REUC</th>
#       <th style="border:1px solid #ddd;padding:8px">RECTYPE</th>
#       <th style="border:1px solid #ddd;padding:8px">TAXYR</th>
#       <th style="border:1px solid #ddd;padding:8px">IDENT</th>
#       <th style="border:1px solid #ddd;padding:8px">SUBIDENT</th>
#       <th style="border:1px solid #ddd;padding:8px">ROLL_SECTION</th>
#       <th style="border:1px solid #ddd;padding:8px">SECVOL</th>
#       <th style="border:1px solid #ddd;padding:8px">PYMKTLAND</th>
#       <th style="border:1px solid #ddd;padding:8px">PYMKTTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">PYACTLAND</th>
#       <th style="border:1px solid #ddd;padding:8px">PYACTTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">PYACTEXTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">PYTRNLAND</th>
#       <th style="border:1px solid #ddd;padding:8px">PYTRNTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">PYTRNEXTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">PYTXBTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">PYTXBEXTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">PYTAXCLASS</th>
#       <th style="border:1px solid #ddd;padding:8px">TENMKTLAND</th>
#       <th style="border:1px solid #ddd;padding:8px">TENMKTTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">TENACTLAND</th>
#       <th style="border:1px solid #ddd;padding:8px">TENACTTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">TENACTEXTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">TENTRNLAND</th>
#       <th style="border:1px solid #ddd;padding:8px">TENTRNTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">TENTRNEXTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">TENTXBTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">TENTXBEXTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">TENTAXCLASS</th>
#       <th style="border:1px solid #ddd;padding:8px">CBNMKTLAND</th>
#       <th style="border:1px solid #ddd;padding:8px">CBNMKTTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">CBNACTLAND</th>
#       <th style="border:1px solid #ddd;padding:8px">CBNACTTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">CBNACTEXTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">CBNTRNLAND</th>
#       <th style="border:1px solid #ddd;padding:8px">CBNTRNTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">CBNTRNEXTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">CBNTXBTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">CBNTXBEXTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">CBNTAXCLASS</th>
#       <th style="border:1px solid #ddd;padding:8px">FINMKTLAND</th>
#       <th style="border:1px solid #ddd;padding:8px">FINMKTTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">YRBUILT_FLAG</th>
#       <th style="border:1px solid #ddd;padding:8px">YRALT1</th>
#       <th style="border:1px solid #ddd;padding:8px">YRALT1_RANGE</th>
#       <th style="border:1px solid #ddd;padding:8px">YRALT2</th>
#       <th style="border:1px solid #ddd;padding:8px">YRALT2_RANGE</th>
#       <th style="border:1px solid #ddd;padding:8px">COOP_APTS</th>
#       <th style="border:1px solid #ddd;padding:8px">UNITS</th>
#       <th style="border:1px solid #ddd;padding:8px">REUC_REF</th>
#       <th style="border:1px solid #ddd;padding:8px">APTNO</th>
#       <th style="border:1px solid #ddd;padding:8px">COOP_NUM</th>
#       <th style="border:1px solid #ddd;padding:8px">CPB_BORO</th>
#       <th style="border:1px solid #ddd;padding:8px">CPB_DIST</th>
#       <th style="border:1px solid #ddd;padding:8px">APPT_DATE</th>
#       <th style="border:1px solid #ddd;padding:8px">APPT_BORO</th>
#       <th style="border:1px solid #ddd;padding:8px">APPT_BLOCK</th>
#       <th style="border:1px solid #ddd;padding:8px">APPT_LOT</th>
#       <th style="border:1px solid #ddd;padding:8px">APPT_EASE</th>
#       <th style="border:1px solid #ddd;padding:8px">CONDO_NUMBER</th>
#       <th st

# %%
# %%sql
# SELECT *
# FROM nyc_property_master
# Out:
# <!--| quarto-html-table-processing: none -->
# <table id="itables_0a1f6648_1bb0_4fe8_941c_402511e1c420" hidden="hidden">
#   <tbody>
#     <tr>
#       <td style="vertical-align:middle; text-align:left"><a href=https://itables.org/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:var(--itables-logo-paper,#d9d7fc)">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:var(--itables-logo-ink,#1a1366);stroke:var(--itables-logo-ink,#1a1366);">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#         Loading ITables v2.9.1 from the internet...
#         (need <a href=https://itables.org/troubleshooting.html>help</a>?)
#       </td>
#     </tr>
#   </tbody>
# </table>
# <div id="itables_0a1f6648_1bb0_4fe8_941c_402511e1c420_fallback"><table style="border-collapse:collapse"><thead>    <tr style="text-align: right;">
#       <th style="border:1px solid #ddd;padding:8px"><sup><noscript><span title="JavaScript not allowed. Please trust this notebook to get interactive tables.">🔒</span></noscript><a href=https://itables.org/fallbacks/static_preview.html title="ITables v2.9.1 static preview">ⓘ</a></sup>PARID</th>
#       <th style="border:1px solid #ddd;padding:8px">BORO</th>
#       <th style="border:1px solid #ddd;padding:8px">BLOCK</th>
#       <th style="border:1px solid #ddd;padding:8px">LOT</th>
#       <th style="border:1px solid #ddd;padding:8px">EASE</th>
#       <th style="border:1px solid #ddd;padding:8px">SUBIDENT_REUC</th>
#       <th style="border:1px solid #ddd;padding:8px">RECTYPE</th>
#       <th style="border:1px solid #ddd;padding:8px">TAXYR</th>
#       <th style="border:1px solid #ddd;padding:8px">IDENT</th>
#       <th style="border:1px solid #ddd;padding:8px">SUBIDENT</th>
#       <th style="border:1px solid #ddd;padding:8px">ROLL_SECTION</th>
#       <th style="border:1px solid #ddd;padding:8px">SECVOL</th>
#       <th style="border:1px solid #ddd;padding:8px">PYMKTLAND</th>
#       <th style="border:1px solid #ddd;padding:8px">PYMKTTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">PYACTLAND</th>
#       <th style="border:1px solid #ddd;padding:8px">PYACTTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">PYACTEXTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">PYTRNLAND</th>
#       <th style="border:1px solid #ddd;padding:8px">PYTRNTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">PYTRNEXTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">PYTXBTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">PYTXBEXTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">PYTAXCLASS</th>
#       <th style="border:1px solid #ddd;padding:8px">TENMKTLAND</th>
#       <th style="border:1px solid #ddd;padding:8px">TENMKTTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">TENACTLAND</th>
#       <th style="border:1px solid #ddd;padding:8px">TENACTTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">TENACTEXTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">TENTRNLAND</th>
#       <th style="border:1px solid #ddd;padding:8px">TENTRNTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">TENTRNEXTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">TENTXBTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">TENTXBEXTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">TENTAXCLASS</th>
#       <th style="border:1px solid #ddd;padding:8px">CBNMKTLAND</th>
#       <th style="border:1px solid #ddd;padding:8px">CBNMKTTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">CBNACTLAND</th>
#       <th style="border:1px solid #ddd;padding:8px">CBNACTTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">CBNACTEXTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">CBNTRNLAND</th>
#       <th style="border:1px solid #ddd;padding:8px">CBNTRNTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">CBNTRNEXTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">CBNTXBTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">CBNTXBEXTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">CBNTAXCLASS</th>
#       <th style="border:1px solid #ddd;padding:8px">FINMKTLAND</th>
#       <th style="border:1px solid #ddd;padding:8px">FINMKTTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">YRBUILT_FLAG</th>
#       <th style="border:1px solid #ddd;padding:8px">YRALT1</th>
#       <th style="border:1px solid #ddd;padding:8px">YRALT1_RANGE</th>
#       <th style="border:1px solid #ddd;padding:8px">YRALT2</th>
#       <th style="border:1px solid #ddd;padding:8px">YRALT2_RANGE</th>
#       <th style="border:1px solid #ddd;padding:8px">COOP_APTS</th>
#       <th style="border:1px solid #ddd;padding:8px">UNITS</th>
#       <th style="border:1px solid #ddd;padding:8px">REUC_REF</th>
#       <th style="border:1px solid #ddd;padding:8px">APTNO</th>
#       <th style="border:1px solid #ddd;padding:8px">COOP_NUM</th>
#       <th style="border:1px solid #ddd;padding:8px">CPB_BORO</th>
#       <th style="border:1px solid #ddd;padding:8px">CPB_DIST</th>
#       <th style="border:1px solid #ddd;padding:8px">APPT_DATE</th>
#       <th style="border:1px solid #ddd;padding:8px">APPT_BORO</th>
#       <th style="border:1px solid #ddd;padding:8px">APPT_BLOCK</th>
#       <th style="border:1px solid #ddd;padding:8px">APPT_LOT</th>
#       <th style="border:1px solid #ddd;padding:8px">APPT_EASE</th>
#       <th style="border:1px solid #ddd;padding:8px">CONDO_NUMBER</th>
#       <th st

# %%
df = spark.sql("DESCRIBE TABLE EXTENDED nyc_property_master")
viewdf(df)
# Out:
# <!--| quarto-html-table-processing: none -->
# <table id="itables_ba27b999_11b2_4b1b_8923_fbdd22a84091" hidden="hidden">
#   <tbody>
#     <tr>
#       <td style="vertical-align:middle; text-align:left"><a href=https://itables.org/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:var(--itables-logo-paper,#d9d7fc)">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:var(--itables-logo-ink,#1a1366);stroke:var(--itables-logo-ink,#1a1366);">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#         Loading ITables v2.9.1 from the internet...
#         (need <a href=https://itables.org/troubleshooting.html>help</a>?)
#       </td>
#     </tr>
#   </tbody>
# </table>
# <div id="itables_ba27b999_11b2_4b1b_8923_fbdd22a84091_fallback"><table style="border-collapse:collapse"><thead>    <tr style="text-align: right;">
#       <th style="border:1px solid #ddd;padding:8px"><sup><noscript><span title="JavaScript not allowed. Please trust this notebook to get interactive tables.">🔒</span></noscript><a href=https://itables.org/fallbacks/static_preview.html title="ITables v2.9.1 static preview">ⓘ</a></sup>col_name</th>
#       <th style="border:1px solid #ddd;padding:8px">data_type</th>
#       <th style="border:1px solid #ddd;padding:8px">comment</th>
#     </tr></thead><tbody>
# <tr><td style="border:1px solid #ddd;padding:8px">PARID</td><td style="border:1px solid #ddd;padding:8px">string</td><td style="border:1px solid #ddd;padding:8px">None</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">BORO</td><td style="border:1px solid #ddd;padding:8px">int</td><td style="border:1px solid #ddd;padding:8px">None</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">BLOCK</td><td style="border:1px solid #ddd;padding:8px">string</td><td style="border:1px solid #ddd;padding:8px">None</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">LOT</td><td style="border:1px solid #ddd;padding:8px">string</td><td style="border:1px solid #ddd;padding:8px">None</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">EASE</td><td style="border:1px solid #ddd;padding:8px">string</td><td style="border:1px solid #ddd;padding:8px">None</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">SUBIDENT_REUC</td><td style="border:1px solid #ddd;padding:8px">string</td><td style="border:1px solid #ddd;padding:8px">None</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">RECTYPE</td><td style="border:1px solid #ddd;padding:8px">int</td><td style="border:1px solid #ddd;padding:8px">None</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">TAXYR</td><td style="border:1px solid #ddd;padding:8px">int</td><td style="border:1px solid #ddd;padding:8px">None</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">IDENT</td><td style="border:1px solid #ddd;padding:8px">string</td><td style="border:1px solid #ddd;padding:8px">None</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">SUBIDENT</td><td style="border:1px solid #ddd;padding:8px">string</td><td style="border:1px solid #ddd;padding:8px">None</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">ROLL_SECTION</td><td style="border:1px solid #ddd;padding:8px">int</td><td style="border:1px solid #ddd;padding:8px">None</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">SECVOL</td><td style="border:1px solid #ddd;padding:8px">string</td><td style="border:1px solid #ddd;padding:8px">None</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">PYMKTLAND</td><td style="border:1px solid #ddd;padding:8px">bigint</td><td style="border:1px solid #ddd;padding:8px">None</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">PYMKTTOT</td><td style="border:1px solid #ddd;padding:8px">bigint</td><td style="border:1px solid #ddd;padding:8px">None</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">PYACTLAND</td><td style="border:1px solid #ddd;padding:8px">bigint</td><td style="border:1px solid #ddd;padding:8px">None</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">PYACTTOT</td><td style="border:1px solid #ddd;padding:8px">bigint</td><td style="border:1px solid #ddd;padding:8px">None</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">PYACTEXTOT</td><td style="border:1px solid #ddd;padding:8px">bigint</td><td style="border:1px solid #ddd;padding:8px">None</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">PYTRNLAND</td><td style="border:1px solid #ddd;padding:8px">bigint</td><td style="border:1px solid #ddd;padding:8px">None</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">PYTRNTOT</td><td style="border:1px solid #ddd;padding:8px">bigint</td><td style="border:1px solid #ddd;padding:8px">None</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">PYTRNEXTOT</td><td style="border:1px solid #ddd;padding:8px">bigint</td><td style="border:1px solid #ddd;padding:8px">None</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">PYTXBTOT</td><td style="border:1px solid #ddd;padding:8px">bigint</td><td style="border:1px solid #ddd;padding:8px">None</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">PYTXBEXTOT</td><td style="border:1px solid #ddd;padding:8px">bigint</td><td style="border:1px solid #ddd;padding:8px">None</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">PYTAXCLASS</td><td style="border:1px solid #ddd;padding:8px">string</td><td style="border:1px solid #ddd;padding:8px">No

# %%
table_name = "nyc_property_master"

location = (
    spark.sql(f"DESCRIBE TABLE EXTENDED {table_name}")
    .filter("col_name = 'Location'")
    .select("data_type")
    .first()[0]
)

print(location)
# Out:
# file:///home/jovyan/work/data/datalake/jupyter-spark-4.1/spark-4.1/iceberg/wareh
# ouse/default/nyc_property_master

# %%
# %%sql
# SELECT *
# --   | Catalog | Namespace table | Iceberg metadata table |
# FROM local.default.nyc_property_master.files;
# Out:
# <!--| quarto-html-table-processing: none -->
# <table id="itables_ed24e89f_dfa0_4ecc_b5ce_9b972e9557e4" hidden="hidden">
#   <tbody>
#     <tr>
#       <td style="vertical-align:middle; text-align:left"><a href=https://itables.org/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:var(--itables-logo-paper,#d9d7fc)">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:var(--itables-logo-ink,#1a1366);stroke:var(--itables-logo-ink,#1a1366);">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#         Loading ITables v2.9.1 from the internet...
#         (need <a href=https://itables.org/troubleshooting.html>help</a>?)
#       </td>
#     </tr>
#   </tbody>
# </table>
# <div id="itables_ed24e89f_dfa0_4ecc_b5ce_9b972e9557e4_fallback"><table style="border-collapse:collapse"><thead>    <tr style="text-align: right;">
#       <th style="border:1px solid #ddd;padding:8px"><sup><noscript><span title="JavaScript not allowed. Please trust this notebook to get interactive tables.">🔒</span></noscript><a href=https://itables.org/fallbacks/static_preview.html title="ITables v2.9.1 static preview">ⓘ</a></sup>content</th>
#       <th style="border:1px solid #ddd;padding:8px">file_path</th>
#       <th style="border:1px solid #ddd;padding:8px">file_format</th>
#       <th style="border:1px solid #ddd;padding:8px">spec_id</th>
#       <th style="border:1px solid #ddd;padding:8px">record_count</th>
#       <th style="border:1px solid #ddd;padding:8px">file_size_in_bytes</th>
#       <th style="border:1px solid #ddd;padding:8px">column_sizes</th>
#       <th style="border:1px solid #ddd;padding:8px">value_counts</th>
#       <th style="border:1px solid #ddd;padding:8px">null_value_counts</th>
#       <th style="border:1px solid #ddd;padding:8px">nan_value_counts</th>
#       <th style="border:1px solid #ddd;padding:8px">lower_bounds</th>
#       <th style="border:1px solid #ddd;padding:8px">upper_bounds</th>
#       <th style="border:1px solid #ddd;padding:8px">key_metadata</th>
#       <th style="border:1px solid #ddd;padding:8px">split_offsets</th>
#       <th style="border:1px solid #ddd;padding:8px">equality_ids</th>
#       <th style="border:1px solid #ddd;padding:8px">sort_order_id</th>
#       <th style="border:1px solid #ddd;padding:8px">first_row_id</th>
#       <th style="border:1px solid #ddd;padding:8px">referenced_data_file</th>
#       <th style="border:1px solid #ddd;padding:8px">content_offset</th>
#       <th style="border:1px solid #ddd;padding:8px">content_size_in_bytes</th>
#       <th style="border:1px solid #ddd;padding:8px">readable_metrics</th>
#     </tr></thead><tbody>
# <tr><td style="border:1px solid #ddd;padding:8px">0</td><td style="border:1px solid #ddd;padding:8px">file:/home/jovyan/work/data/datalake/jupyter-spark-4.1/spark-4.1/iceberg/warehouse/default/nyc_property_master/data/00000-51-3cbc3f0d-3935-49e3-be40-2c081d629d56-0-00001.parquet</td><td style="border:1px solid #ddd;padding:8px">PARQUET</td><td style="border:1px solid #ddd;padding:8px">0</td><td style="border:1px solid #ddd;padding:8px">73344</td><td style="border:1px solid #ddd;padding:8px">13032945</td><td style="border:1px solid #ddd;padding:8px">{1: 154980, 2: 231, 3: 31181, 4: 85568, 5: 694, 6: 180, 7: 231, 8: 231, 9: 180, 10: 180, 11: 180, 12: 5713, 13: 242928, 14: 291619, 15: 227164, 16: 284155, 17: 42849, 18: 237401, 19: 294886, 20: 42881, 21: 294718, 22: 42746, 23: 12009, 24: 243828, 25: 294233, 26: 227759, 27: 286316, 28: 40661, 29: 238489, 30: 296530, 31: 40728, 32: 296102, 33: 40606, 34: 11756, 35: 245241, 36: 295720, 37: 229035, 38: 287746, 39: 41394, 40: 239715, 41: 298025, 42: 41470, 43: 297346, 44: 41393, 45: 11539, 46: 244903, 47: 295676, 48: 229032, 49: 287747, 50: 41401, 51: 239716, 52: 297850, 53: 41473, 54: 297317, 55: 41416, 56: 11539, 57: 244903, 58: 295676, 59: 229032, 60: 287747, 61: 41401, 62: 239716, 63: 297850, 64: 41473, 65: 297317, 66: 41416, 67: 11539, 68: 231, 69: 637, 70: 238, 71: 413, 72: 23726, 73: 703488, 74: 25112, 75: 58443, 76: 55734, 77: 41172, 78: 9548, 79: 1639, 80: 36734, 81: 39425, 82: 35827, 83: 10129, 84: 32840, 85: 32659, 86: 9281, 87: 33897, 88: 9850, 89: 63552, 90: 6178, 91: 29047, 92: 231, 93: 180, 94: 17976, 95: 8548, 96: 6236, 97: 4223, 98: 22577, 99: 21328, 100: 1503}</td><td style="border:1px solid #ddd;padding:8px">{1: 73344, 2: 73344, 3: 73344, 4: 73344, 5: 73344, 6: 73344, 7: 73344, 8: 73344, 9: 73344, 10: 73344, 11: 73344, 12: 73344, 13: 73344, 14: 73344, 15: 73344, 16: 73344, 17: 73344, 18: 73344, 19: 73344, 20: 73344, 21: 73344, 22: 73344, 23: 73344, 24: 73344, 25: 73344, 26: 73344, 27: 73344, 28: 73344, 29: 73344, 30: 73344, 31: 73344, 32: 73344, 33: 73344, 34: 73344, 35: 73344, 36: 73344, 37: 73344, 38: 73344, 39: 73344, 40: 73344, 41: 73344, 42: 73344, 43: 73344, 44: 73344, 45: 73344, 46: 73344, 47: 73344, 48: 73344, 49: 73344, 50: 73344, 51: 73344, 52: 73344, 53: 73344, 54: 73344, 55: 73344, 56: 73344, 57: 73344, 58: 73344, 59: 73344, 60: 73344, 61: 73344, 62: 73344, 63: 73344, 64: 73344, 65: 73344, 66: 73344, 67: 73344, 68: 73344, 69: 73344, 70: 73344, 71: 73344, 72: 73344, 73: 73344, 74: 73344, 75: 73344, 76: 73344, 77: 73344, 78: 73344, 79: 73344, 80: 73344, 81: 73344, 82: 73344, 83: 73344, 84: 73344, 85: 73344, 86: 73344, 87: 73344, 88: 73344, 89: 73344, 90: 73344, 91: 73344, 92: 73344, 93: 73344, 94: 73344, 95: 73344, 96: 73344, 97: 73344, 98: 73344, 99: 73344, 100: 73344}</td><td style="border:1px solid #ddd;paddi

# %%
table_name = "nyc_property_master"

files_df = spark.sql(f"""
    SELECT file_size_in_bytes
    FROM local.default.{table_name}.files
""")

size_in_bytes = files_df.agg(
    {"file_size_in_bytes": "sum"}
).first()[0]

location = location.removeprefix("file:")

print(f"{location} ({size_in_bytes} bytes)")
# Out:
# ///home/jovyan/work/data/datalake/jupyter-spark-4.1/spark-4.1/iceberg/warehouse/
# default/nyc_property_master (154971588 bytes)

# %%
# !echo "≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡"
# !ls -lahS {location}
# !echo "≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡"
# !ls -lahS {location}/data
# !echo "≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡"
# !ls -lahS {location}/metadata
# !echo "≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡"
# Out:
# ≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡
# total 0
# drwxr-xr-x. 1 jovyan users 4.0K Aug 28 14:32 data
# drwxr-xr-x. 1 jovyan users  620 Aug 28 14:32 metadata
# drwxr-xr-x. 1 jovyan users   38 Aug 28 14:32 ..
# drwxr-xr-x. 1 jovyan users   24 Aug 28 14:32 .
# ≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡
# total 150M
# -rw-r--r--. 1 jovyan users  13M Aug 28 14:32 00000-51-3cbc3f0d-3935-49e3-be40-2c081d629d56-0-00001.parquet
# -rw-r--r--. 1 jovyan users  13M Aug 28 14:32 00001-52-3cbc3f0d-3935-49e3-be40-2c081d629d56-0-00001.parquet
# -rw-r--r--. 1 jovyan users  12M Aug 28 14:32 00002-53-3cbc3f0d-3935-49e3-be40-2c081d629d56-0-00001.parquet
# -rw-r--r--. 1 jovyan users 9.9M Aug 28 14:32 00005-56-3cbc3f0d-3935-49e3-be40-2c081d629d56-0-00001.parquet
# -rw-r--r--. 1 jovyan users 9.8M Aug 28 14:32 00006-57-3cbc3f0d-3935-49e3-be40-2c081d629d56-0-00001.parquet
# -rw-r--r--. 1 jovyan users 9.6M Aug 28 14:32 00004-55-3cbc3f0d-3935-49e3-be40-2c081d629d56-0-00001.parquet
# -rw-r--r--. 1 jovyan users 9.4M Aug 28 14:32 00009-60-3cbc3f0d-3935-49e3-be40-2c081d629d56-0-00001.parquet
# -rw-r--r--. 1 jovyan users 8.9M Aug 28 14:32 00007-58-3cbc3f0d-3935-49e3-be40-2c081d629d56-0-00001.parquet
# -rw-r--r--. 1 jovyan users 8.8M Aug 28 14:32 00010-61-3cbc3f0d-3935-49e3-be40-2c081d629d56-0-00001.parquet
# -rw-r--r--. 1 jovyan users 8.8M Aug 28 14:32 00003-54-3cbc3f0d-3935-49e3-be40-2c081d629d56-0-00001.parquet
# -rw-r--r--. 1 jovyan users 8.5M Aug 28 14:32 00011-62-3cbc3f0d-3935-49e3-be40-2c081d629d56-0-00001.parquet
# -rw-r--r--. 1 jovyan users 8.3M Aug 28 14:32 00014-65-3cbc3f0d-3935-49e3-be40-2c081d629d56-0-00001.parquet
# -rw-r--r--. 1 jovyan users 8.2M Aug 28 14:32 00008-59-3cbc3f0d-3935-49e3-be40-2c081d629d56-0-00001.parquet
# -rw-r--r--. 1 jovyan users 7.6M Aug 28 14:32 00012-63-3cbc3f0d-3935-49e3-be40-2c081d629d56-0-00001.parquet
# -rw-r--r--. 1 jovyan users 7.4M Aug 28 14:32 00013-64-3cbc3f0d-3935-49e3-be40-2c081d629d56-0-00001.parquet
# -rw-r--r--. 1 jovyan users 7.1M Aug 28 14:32 00015-66-3cbc3f0d-3935-49e3-be40-2c081d629d56-0-00001.parquet
# -rw-r--r--. 1 jovyan users 100K Aug 28 14:32 .00000-51-3cbc3f0d-3935-49e3-be40-2c081d629d56-0-00001.parquet.crc
# -rw-r--r--. 1 jovyan users 100K Aug 28 14:32 .00001-52-3cbc3f0d-3935-49e3-be40-2c081d629d56-0-00001.parquet.crc
# -rw-r--r--. 1 jovyan users  90K Aug 28 14:32 .00002-53-3cbc3f0d-3935-49e3-be40-2c081d629d56-0-00001.parquet.crc
# -rw-r--r--. 1 jovyan users  79K Aug 28 14:32 .00005-56-3cbc3f0d-3935-49e3-be40-2c081d629d56-0-00001.parquet.crc
# -rw-r--r--. 1 jovyan users  79K Aug 28 14:32 .00006-57-3cbc3f0d-3935-49e3-be40-2c081d629d56-0-00001.parquet.crc
# -rw-r--r--. 1 jovyan users  77K Aug 28 14:32 .00004-55-3cbc3f0d-3935-49e3-be40-2c081d629d56-0-00001.parquet.crc
# -rw-r--r--. 1 jovyan users  75K Aug 28 14:32 .00009-60-3cbc3f0d-3935-49e3-be40-2c081d629d56-0-00001.parquet.crc
# -rw-r--r--. 1 jovyan users  71K Aug 28 14:32 .00007-58-3cbc3f0d-3935-49e3-be40-2c081d629d56-0-00001.parquet.crc
# -rw-r--r--. 1 jovyan users  71K Aug 28 14:32 .00010-61-3cbc3f0d-3935-49e3-be40-2c081d629d56-0-00001.parquet.crc
# -rw-r--r--. 1 jovyan users  71K Aug 28 14:32 .00003-54-3cbc3f0d-3935-49e3-be40-2c081d629d56-0-00001.parquet.crc
# -rw-r--r--. 1 jovyan users  68K Aug 28 14:32 .00011-62-3cbc3f0d-3935-49e3-be40-2c081d629d56-0-00001.parquet.crc
# -rw-r--r--. 1 jovyan users  66K Aug 28 14:32 .00014-65-3cbc3f0d-3935-49e3-be40-2c081d629d56-0-00001.parquet.crc
# -rw-r--r--. 1 jovyan users  66K Aug 28 14:32 .00008-59-3cbc3f0d-3935-49e3-be40-2c081d629d56-0-00001.parquet.crc
# -rw-r--r--. 1 jovyan users  61K Aug 28 14:32 .00012-63-3cbc3f0d-3935-49e3-be40-2c081d629d56-0-00001.parquet.crc
# -rw-r--r--. 1 jovyan users  60K Aug 28 14:32 .00013-64-3cbc3f0d-3935-49e3-be40-2c081d629d56-0-00001.parquet.crc
# -rw-r--r--. 1 jovyan users  57K Aug 28 14:32 .00015-66-3cbc3f0d-3935-49e3-be40-2c081d629d56-0-00001.parquet.crc
# drwxr-xr-x. 1 jovyan users 4.0K Aug 28 14:32 .
# drwxr-xr-x. 1 jovyan users   24 Aug 28 14:32 ..
# ≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡
# total 72K
# -rw-r--r--. 1 jovyan users  29K Aug 28 14:32 2c776b09-e7df-4349-a188-b984e5dd4119-m0.avro
# -rw-r--r--. 1 jovyan users  11K Aug 28 14:32 v1.metadata.json
# -rw-r--r--. 1 jovyan users 4.5K Aug 28 14:32 snap-7990601077313688582-1-2c776b09-e7df-4349-a188-b984e5dd4119.avro
# drwxr-xr-x. 1 jovyan users  620 Aug 28 14:32 .
# -rw-r--r--. 1 jovyan users  236 Aug 28 14:32 .2c776b09-e7df-4349-a188-b984e5dd4119-m0.avro.crc
# -rw-r--r--. 1 jovyan users   92 Aug 28 14:32 .v1.metadata.json.crc
# -rw-r--r--. 1 jovyan users   44 Aug 28 14:32 .snap-7990601077313688582-1-2c776b09-e7df-4349-a188-b984e5dd4119.avro.crc
# drwxr-xr-x. 1 jovyan users   24 Aug 28 14:32 ..
# -rw-r--r--. 1 jovyan users   12 Aug 28 14:32 .version-hint.text.crc
# -rw-r--r--. 1 jovyan users    1 Aug 28 14:32 version-hint.text
# ≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡

# %%
print(spark.version)
print(spark.conf.get("spark.sql.catalogImplementation"))

spark.sql("SELECT current_catalog(), current_database()").show()
# Out:
# 4.1.3
# hive
# +-----------------+----------------+
# |current_catalog()|current_schema()|
# +-----------------+----------------+
# |            local|         default|
# +-----------------+----------------+

# %%
# %sql SHOW NAMESPACES;
# Out:
# <!--| quarto-html-table-processing: none -->
# <table id="itables_985acf0a_7953_41d4_a126_176e082a1121" hidden="hidden">
#   <tbody>
#     <tr>
#       <td style="vertical-align:middle; text-align:left"><a href=https://itables.org/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:var(--itables-logo-paper,#d9d7fc)">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:var(--itables-logo-ink,#1a1366);stroke:var(--itables-logo-ink,#1a1366);">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#         Loading ITables v2.9.1 from the internet...
#         (need <a href=https://itables.org/troubleshooting.html>help</a>?)
#       </td>
#     </tr>
#   </tbody>
# </table>
# <div id="itables_985acf0a_7953_41d4_a126_176e082a1121_fallback"><table style="border-collapse:collapse"><thead>    <tr style="text-align: right;">
#       <th style="border:1px solid #ddd;padding:8px"><sup><noscript><span title="JavaScript not allowed. Please trust this notebook to get interactive tables.">🔒</span></noscript><a href=https://itables.org/fallbacks/static_preview.html title="ITables v2.9.1 static preview">ⓘ</a></sup>namespace</th>
#     </tr></thead><tbody>
# <tr><td style="border:1px solid #ddd;padding:8px">default</td></tr>
# </tbody></table></div><script>document.getElementById("itables_985acf0a_7953_41d4_a126_176e082a1121")?.removeAttribute("hidden");document.getElementById("itables_985acf0a_7953_41d4_a126_176e082a1121_fallback")?.setAttribute("hidden", "hidden");</script>
# <link href="https://www.unpkg.com/dt_for_itables@2.5.8/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import { ITable, jQuery as $ } from 'https://www.unpkg.com/dt_for_itables@2.5.8/dt_bundle.js';
#
#     document.querySelectorAll("#itables_985acf0a_7953_41d4_a126_176e082a1121:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         let dt_args = {
#           "classes": ["display", "nowrap", "compact"],
#           "data_json": "[[\"default\"]]",
#           "layout": {"bottomEnd": null, "bottomStart": null, "topEnd": null, "topStart": null},
#           "lengthMenu": [10, 25, 50, 100],
#           "order": [],
#           "pageLength": 25,
#           "scrollCollapse": true,
#           "scrollX": true,
#           "scrollY": "500px",
#           "style": {"caption-side": "bottom", "margin": "0", "table-layout": "auto", "width": "auto"},
#           "table_html": "<table><thead>\n    <tr style=\"text-align: right;\">\n      \n      <th>namespace</th>\n    </tr>\n  </thead></table>",
#           "text_in_header_can_be_selected": true
#         };
#         new ITable(table, dt_args);
#     });
# </script>

# %%
# %sql SHOW CATALOGS
# Out:
# <!--| quarto-html-table-processing: none -->
# <table id="itables_7a37a857_f1a5_456a_8b84_3ef26ea3606e" hidden="hidden">
#   <tbody>
#     <tr>
#       <td style="vertical-align:middle; text-align:left"><a href=https://itables.org/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:var(--itables-logo-paper,#d9d7fc)">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:var(--itables-logo-ink,#1a1366);stroke:var(--itables-logo-ink,#1a1366);">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#         Loading ITables v2.9.1 from the internet...
#         (need <a href=https://itables.org/troubleshooting.html>help</a>?)
#       </td>
#     </tr>
#   </tbody>
# </table>
# <div id="itables_7a37a857_f1a5_456a_8b84_3ef26ea3606e_fallback"><table style="border-collapse:collapse"><thead>    <tr style="text-align: right;">
#       <th style="border:1px solid #ddd;padding:8px"><sup><noscript><span title="JavaScript not allowed. Please trust this notebook to get interactive tables.">🔒</span></noscript><a href=https://itables.org/fallbacks/static_preview.html title="ITables v2.9.1 static preview">ⓘ</a></sup>catalog</th>
#     </tr></thead><tbody>
# <tr><td style="border:1px solid #ddd;padding:8px">local</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">spark_catalog</td></tr>
# </tbody></table></div><script>document.getElementById("itables_7a37a857_f1a5_456a_8b84_3ef26ea3606e")?.removeAttribute("hidden");document.getElementById("itables_7a37a857_f1a5_456a_8b84_3ef26ea3606e_fallback")?.setAttribute("hidden", "hidden");</script>
# <link href="https://www.unpkg.com/dt_for_itables@2.5.8/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import { ITable, jQuery as $ } from 'https://www.unpkg.com/dt_for_itables@2.5.8/dt_bundle.js';
#
#     document.querySelectorAll("#itables_7a37a857_f1a5_456a_8b84_3ef26ea3606e:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         let dt_args = {
#           "classes": ["display", "nowrap", "compact"],
#           "data_json": "[[\"local\"], [\"spark_catalog\"]]",
#           "layout": {"bottomEnd": null, "bottomStart": null, "topEnd": null, "topStart": null},
#           "lengthMenu": [10, 25, 50, 100],
#           "order": [],
#           "pageLength": 25,
#           "scrollCollapse": true,
#           "scrollX": true,
#           "scrollY": "500px",
#           "style": {"caption-side": "bottom", "margin": "0", "table-layout": "auto", "width": "auto"},
#           "table_html": "<table><thead>\n    <tr style=\"text-align: right;\">\n      \n      <th>catalog</th>\n    </tr>\n  </thead></table>",
#           "text_in_header_can_be_selected": true
#         };
#         new ITable(table, dt_args);
#     });
# </script>

# %%
# %sql SHOW NAMESPACES IN spark_catalog
# Out:
# <!--| quarto-html-table-processing: none -->
# <table id="itables_62db6a45_9af9_49db_bc8a_0f666ef1acc5" hidden="hidden">
#   <tbody>
#     <tr>
#       <td style="vertical-align:middle; text-align:left"><a href=https://itables.org/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:var(--itables-logo-paper,#d9d7fc)">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:var(--itables-logo-ink,#1a1366);stroke:var(--itables-logo-ink,#1a1366);">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#         Loading ITables v2.9.1 from the internet...
#         (need <a href=https://itables.org/troubleshooting.html>help</a>?)
#       </td>
#     </tr>
#   </tbody>
# </table>
# <div id="itables_62db6a45_9af9_49db_bc8a_0f666ef1acc5_fallback"><table style="border-collapse:collapse"><thead>    <tr style="text-align: right;">
#       <th style="border:1px solid #ddd;padding:8px"><sup><noscript><span title="JavaScript not allowed. Please trust this notebook to get interactive tables.">🔒</span></noscript><a href=https://itables.org/fallbacks/static_preview.html title="ITables v2.9.1 static preview">ⓘ</a></sup>namespace</th>
#     </tr></thead><tbody>
# <tr><td style="border:1px solid #ddd;padding:8px">default</td></tr>
# </tbody></table></div><script>document.getElementById("itables_62db6a45_9af9_49db_bc8a_0f666ef1acc5")?.removeAttribute("hidden");document.getElementById("itables_62db6a45_9af9_49db_bc8a_0f666ef1acc5_fallback")?.setAttribute("hidden", "hidden");</script>
# <link href="https://www.unpkg.com/dt_for_itables@2.5.8/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import { ITable, jQuery as $ } from 'https://www.unpkg.com/dt_for_itables@2.5.8/dt_bundle.js';
#
#     document.querySelectorAll("#itables_62db6a45_9af9_49db_bc8a_0f666ef1acc5:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         let dt_args = {
#           "classes": ["display", "nowrap", "compact"],
#           "data_json": "[[\"default\"]]",
#           "layout": {"bottomEnd": null, "bottomStart": null, "topEnd": null, "topStart": null},
#           "lengthMenu": [10, 25, 50, 100],
#           "order": [],
#           "pageLength": 25,
#           "scrollCollapse": true,
#           "scrollX": true,
#           "scrollY": "500px",
#           "style": {"caption-side": "bottom", "margin": "0", "table-layout": "auto", "width": "auto"},
#           "table_html": "<table><thead>\n    <tr style=\"text-align: right;\">\n      \n      <th>namespace</th>\n    </tr>\n  </thead></table>",
#           "text_in_header_can_be_selected": true
#         };
#         new ITable(table, dt_args);
#     });
# </script>

# %%
# %sql USE default;
# Out:
# <!--| quarto-html-table-processing: none -->
# <table id="itables_9b873767_8fe2_42b5_b262_589bd1ac14cb" hidden="hidden">
#   <tbody>
#     <tr>
#       <td style="vertical-align:middle; text-align:left"><a href=https://itables.org/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:var(--itables-logo-paper,#d9d7fc)">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:var(--itables-logo-ink,#1a1366);stroke:var(--itables-logo-ink,#1a1366);">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#         Loading ITables v2.9.1 from the internet...
#         (need <a href=https://itables.org/troubleshooting.html>help</a>?)
#       </td>
#     </tr>
#   </tbody>
# </table>
# <div id="itables_9b873767_8fe2_42b5_b262_589bd1ac14cb_fallback"><table style="border-collapse:collapse"><thead>    <tr style="text-align: right;">
#       <th style="border:1px solid #ddd;padding:8px"><sup><noscript><span title="JavaScript not allowed. Please trust this notebook to get interactive tables.">🔒</span></noscript><a href=https://itables.org/fallbacks/static_preview.html title="ITables v2.9.1 static preview">ⓘ</a></sup></th>
#     </tr></thead><tbody>
#
# </tbody></table></div><script>document.getElementById("itables_9b873767_8fe2_42b5_b262_589bd1ac14cb")?.removeAttribute("hidden");document.getElementById("itables_9b873767_8fe2_42b5_b262_589bd1ac14cb_fallback")?.setAttribute("hidden", "hidden");</script>
# <link href="https://www.unpkg.com/dt_for_itables@2.5.8/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import { ITable, jQuery as $ } from 'https://www.unpkg.com/dt_for_itables@2.5.8/dt_bundle.js';
#
#     document.querySelectorAll("#itables_9b873767_8fe2_42b5_b262_589bd1ac14cb:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         let dt_args = {
#           "classes": ["display", "nowrap", "compact"],
#           "data_json": "[]",
#           "layout": {"bottomEnd": null, "bottomStart": null, "topEnd": null, "topStart": null},
#           "lengthMenu": [10, 25, 50, 100],
#           "order": [],
#           "pageLength": 25,
#           "scrollCollapse": true,
#           "scrollX": true,
#           "scrollY": "500px",
#           "style": {"caption-side": "bottom", "margin": "0", "table-layout": "auto", "width": "auto"},
#           "table_html": "<table><thead>\n    <tr style=\"text-align: right;\">\n      <th></th>\n    </tr>\n  </thead></table>",
#           "text_in_header_can_be_selected": true
#         };
#         new ITable(table, dt_args);
#     });
# </script>

# %%
# %%sql
# SELECT record_count, file_size_in_bytes, content_size_in_bytes, file_format
# --   | Catalog | Namespace | Table | Iceberg metadata table |
# FROM local.default.nyc_property_master.files;
# Out:
# <!--| quarto-html-table-processing: none -->
# <table id="itables_3de6f486_2f7c_4b0c_ad0d_c3643e3e5157" hidden="hidden">
#   <tbody>
#     <tr>
#       <td style="vertical-align:middle; text-align:left"><a href=https://itables.org/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:var(--itables-logo-paper,#d9d7fc)">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:var(--itables-logo-ink,#1a1366);stroke:var(--itables-logo-ink,#1a1366);">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#         Loading ITables v2.9.1 from the internet...
#         (need <a href=https://itables.org/troubleshooting.html>help</a>?)
#       </td>
#     </tr>
#   </tbody>
# </table>
# <div id="itables_3de6f486_2f7c_4b0c_ad0d_c3643e3e5157_fallback"><table style="border-collapse:collapse"><thead>    <tr style="text-align: right;">
#       <th style="border:1px solid #ddd;padding:8px"><sup><noscript><span title="JavaScript not allowed. Please trust this notebook to get interactive tables.">🔒</span></noscript><a href=https://itables.org/fallbacks/static_preview.html title="ITables v2.9.1 static preview">ⓘ</a></sup>record_count</th>
#       <th style="border:1px solid #ddd;padding:8px">file_size_in_bytes</th>
#       <th style="border:1px solid #ddd;padding:8px">content_size_in_bytes</th>
#       <th style="border:1px solid #ddd;padding:8px">file_format</th>
#     </tr></thead><tbody>
# <tr><td style="border:1px solid #ddd;padding:8px">73344</td><td style="border:1px solid #ddd;padding:8px">13032945</td><td style="border:1px solid #ddd;padding:8px">NaN</td><td style="border:1px solid #ddd;padding:8px">PARQUET</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">73343</td><td style="border:1px solid #ddd;padding:8px">12992007</td><td style="border:1px solid #ddd;padding:8px">NaN</td><td style="border:1px solid #ddd;padding:8px">PARQUET</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">73343</td><td style="border:1px solid #ddd;padding:8px">11789486</td><td style="border:1px solid #ddd;padding:8px">NaN</td><td style="border:1px solid #ddd;padding:8px">PARQUET</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">73343</td><td style="border:1px solid #ddd;padding:8px">9181698</td><td style="border:1px solid #ddd;padding:8px">NaN</td><td style="border:1px solid #ddd;padding:8px">PARQUET</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">73343</td><td style="border:1px solid #ddd;padding:8px">10039748</td><td style="border:1px solid #ddd;padding:8px">NaN</td><td style="border:1px solid #ddd;padding:8px">PARQUET</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">73343</td><td style="border:1px solid #ddd;padding:8px">10348090</td><td style="border:1px solid #ddd;padding:8px">NaN</td><td style="border:1px solid #ddd;padding:8px">PARQUET</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">73343</td><td style="border:1px solid #ddd;padding:8px">10228608</td><td style="border:1px solid #ddd;padding:8px">NaN</td><td style="border:1px solid #ddd;padding:8px">PARQUET</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">73343</td><td style="border:1px solid #ddd;padding:8px">9233437</td><td style="border:1px solid #ddd;padding:8px">NaN</td><td style="border:1px solid #ddd;padding:8px">PARQUET</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">73343</td><td style="border:1px solid #ddd;padding:8px">8531755</td><td style="border:1px solid #ddd;padding:8px">NaN</td><td style="border:1px solid #ddd;padding:8px">PARQUET</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">73343</td><td style="border:1px solid #ddd;padding:8px">9785410</td><td style="border:1px solid #ddd;padding:8px">NaN</td><td style="border:1px solid #ddd;padding:8px">PARQUET</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">73343</td><td style="border:1px solid #ddd;padding:8px">9192624</td><td style="border:1px solid #ddd;padding:8px">NaN</td><td style="border:1px solid #ddd;padding:8px">PARQUET</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">73343</td><td style="border:1px solid #ddd;padding:8px">8883170</td><td style="border:1px solid #ddd;padding:8px">NaN</td><td style="border:1px solid #ddd;padding:8px">PARQUET</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">73343</td><td style="border:1px solid #ddd;padding:8px">7965457</td><td style="border:1px solid #ddd;padding:8px">NaN</td><td style="border:1px solid #ddd;padding:8px">PARQUET</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">73343</td><td style="border:1px solid #ddd;padding:8px">7755006</td><td style="border:1px solid #ddd;padding:8px">NaN</td><td style="border:1px solid #ddd;padding:8px">PARQUET</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">73343</td><td style="border:1px solid #ddd;padding:8px">8628221</td><td style="border:1px solid #ddd;padding:8px">NaN</td><td style="border:1px solid #ddd;padding:8px">PARQUET</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">67817</td><td style="border:1px solid #ddd;padding:8px">7383926</td><td style="border:1px solid #ddd;padding:8px">NaN</td><td style="border:1px solid #ddd;padding:8px">PARQUET</td></tr>
# </tbody></table></div><script>document.getElementById("itables_3de6f486_2f7c_4b0c_ad0d_c3643e3e5157")?.removeAttribute("hidden");document.getElementById("itables_3de6f486_2f7c_4b0c_ad0d_c3643e3e5157_fallback")?.setAttribute("hidden", "hidden");</script

# %%
catalog = spark._jsparkSession.sessionState().catalogManager().catalog("local")

print(f"Catalog: {catalog.getClass().getName()}")
# Out:
# Catalog: org.apache.iceberg.spark.SparkCatalog

# %%
catalog_manager = spark._jsparkSession.sessionState().catalogManager()

current_catalog = catalog_manager.currentCatalog()

print(current_catalog.name())
print(current_catalog.getClass().getName())
# Out:
# local
# org.apache.iceberg.spark.SparkCatalog

# %%
show_spark_config([
    "spark.sql.extensions",          
    "spark.sql.shuffle.partitions",
    "spark.sql.catalog.local.warehouse",
])
# Out:
# spark.sql.extensions:
# org.apache.iceberg.spark.extensions.IcebergSparkSessionExtensions
# spark.sql.shuffle.partitions: 200
# spark.sql.catalog.local.warehouse:
# file:///home/jovyan/work/data/datalake/jupyter-spark-4.1/spark-4.1/iceberg/wareh
# ouse
