# %%
# %run_nb spark-start --data-format delta
# Out:
# Args: Namespace(data_format='delta') - unknown_args: []
# Spark version: 4.1.3, Driver memory: 16g, Executor memory: 8g, Service: jupyter-spark-4.1, Data format: delta
# Port offset: 2
# Spark packages: org.postgresql:postgresql:42.7.7,org.apache.hadoop:hadoop-aws:3.4.2,org.apache.spark:spark-avro_2.13:4.1.3,org.apache.spark:spark-sql-kafka-0-10_2.13:4.1.3,io.delta:delta-spark_4.1_2.13:4.1.0
# Spark extensions: io.delta.sql.DeltaSparkSessionExtension
# Spark catalog configs: {'spark.sql.catalog.spark_catalog': 'org.apache.spark.sql.delta.catalog.DeltaCatalog', 'spark.sql.catalog.local.warehouse': 'file:///home/jovyan/work/data/datalake/jupyter-spark-4.1/spark-4.1/delta/warehouse'}
# <!--| quarto-html-table-processing: none -->
# <table id="itables_4f89f258_38a9_4124_98cd_763dfeff3af4" hidden="hidden">
#   <tbody>
#     <tr>
#       <td style="vertical-align:middle; text-align:left"><a href=https://itables.org/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:var(--itables-logo-paper,#d9d7fc)">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:var(--itables-logo-ink,#1a1366);stroke:var(--itables-logo-ink,#1a1366);">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#         Loading ITables v2.9.1 from the internet...
#         (need <a href=https://itables.org/troubleshooting.html>help</a>?)
#       </td>
#     </tr>
#   </tbody>
# </table>
# <div id="itables_4f89f258_38a9_4124_98cd_763dfeff3af4_fallback"><table style="border-collapse:collapse"><thead>    <tr style="text-align: right;">
#       <th style="border:1px solid #ddd;padding:8px"><sup><noscript><span title="JavaScript not allowed. Please trust this notebook to get interactive tables.">🔒</span></noscript><a href=https://itables.org/fallbacks/static_preview.html title="ITables v2.9.1 static preview">ⓘ</a></sup>catalog</th>
#     </tr></thead><tbody>
# <tr><td style="border:1px solid #ddd;padding:8px">spark_catalog</td></tr>
# </tbody></table></div><script>document.getElementById("itables_4f89f258_38a9_4124_98cd_763dfeff3af4")?.removeAttribute("hidden");document.getElementById("itables_4f89f258_38a9_4124_98cd_763dfeff3af4_fallback")?.setAttribute("hidden", "hidden");</script>
# <link href="https://www.unpkg.com/dt_for_itables@2.5.8/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import { ITable, jQuery as $ } from 'https://www.unpkg.com/dt_for_itables@2.5.8/dt_bundle.js';
#
#     document.querySelectorAll("#itables_4f89f258_38a9_4124_98cd_763dfeff3af4:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         let dt_args = {
#           "classes": ["display", "nowrap", "compact"],
#           "data_json": "[[\"spark_catalog\"]]",
#           "layout": {"bottomEnd": null, "bottomStart": null, "topEnd": null, "topStart": null},
#           "lengthMenu": [10, 25, 50, 100],
#           "order": [],
#           "pageLength": 25,
#           "scrollCollapse": true,
#           "scrollX": true,
#           "scrollY": "500px",
#           "style": {"caption-side": "bottom", "margin": "0", "table-layout": "auto", "width": "auto"},
#           "table_html": "<table><thead>\n    <tr style=\"text-align: right;\">\n      \n      <th>catalog</th>\n    </tr>\n  </thead></table>",
#           "text_in_header_can_be_selected": true
#         };
#         new ITable(table, dt_args);
#     });
# </script>
# <!--| quarto-html-table-processing: none -->
# <table id="itables_109a5690_e679_4c9f_85b5_93fb60189b16" hidden="hidden">
#   <tbody>
#     <tr>
#       <td style="vertical-align:middle; text-align:left"><a href=https://itables.org/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:var(--itables-logo-paper,#d9d7fc)">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:var(--itables-logo-ink,#1a1366);stroke:var(--itables-logo-ink,#1a1366);">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#         Loading ITables v2.9.1 from the internet...
#         (need <a href=https://itables.org/troubleshooting.html>help</a>?)
#       </td>
#     </tr>
#   </tbody>
# </table>
# <div id="itables_109a5690_e679_4c9f_85b5_93fb60189b16_fallback"><table style="border-collapse:collapse"><thead>    <tr style="text-align: right;">
#       <th style="border:1px solid #ddd;padding:8px"><sup><noscript><span title="JavaScript not allowed. Please trust this notebook to get interactive tables.">🔒</span></noscript><a href=https://itables.org/fallbacks/static_preview.html title="ITables v2.9.1 static preview">ⓘ</a></sup>namespace</th>
#     </tr></thead><tbody>
# <tr><td style="border:1px solid #ddd;padding:8px">default</td></tr>
# </tbody></table></div><script>document.getElementById("itables_109a5690_e679_4c9f_85b5_93fb60189b16")?.removeAttribute("hidden");document.getElementById("itables_109a5690_e679_4c9f_85b5_93fb60189b16_fallback")?.setAttribute("hidden", "hidden");</script>
# <link href="https://www.unpkg.com/dt_for_itables@2.5.8/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import { ITable, jQuery as $ } from 'https://www.unpkg.com/dt_for_itables@2.5.8/dt_bundle.js';
#
#     document.querySelectorAll("#itables_109a5690_e679_4c9f_85b5_93fb60189b16:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         let dt_args = {
#           "classes": ["display", "nowrap", "compact"],
#           "data_json": "[[\"default\"]]",
#           "layout": {"bottomEnd": null, "bottomStart": null, "topEnd": null, "topStart": null},
#           "lengthMenu": [10, 25, 50, 100],
#           "order": [],
#           "pageLength": 25,
#           "scrollCollapse": true,
#           "scrollX": true,
#           "scrollY": "500px",
#           "style": {"caption-side": "bottom", "margin": "0", "table-layout": "auto", "width": "auto"},
#           "table_html": "<table><thead>\n    <tr style=\"text-align: right;\">\n      \n      <th>namespace</th>\n    </tr>\n  </thead></table>",
#           "text_in_header_can_be_selected": true
#         };
#         new ITable(table, dt_args);
#     });
# </script>
# Catalog spark_catalog: org.apache.spark.sql.delta.catalog.DeltaCatalog. Current:
# org.apache.spark.sql.delta.catalog.DeltaCatalog
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
# <div>
#   <div style="font-weight: 600; margin-bottom: 0.5rem;">SparkContext</div>
#   <div style="margin-bottom: 0.75rem;">
#     <a href="http://jupyter-spark-4-1.localhost:8080/webui/" target="_blank" rel="noopener noreferrer">Spark UI</a>
#   </div>
#   <table>
#     <tr><th align="left">Version</th><td>4.1.3</td></tr>
#     <tr><th align="left">Master</th><td>local[12]</td></tr>
#     <tr><th align="left">AppName</th><td>main</td></tr>
#   </table>
# </div>
#
#             </div>
#                total        used        free      shared  buff/cache   available
# Mem:            62Gi        16Gi        29Gi       398Mi        18Gi        46Gi
# Swap:          8.0Gi          0B       8.0Gi

# %%
from pyspark.sql import SparkSession
from pyspark.sql import functions as F
from pyspark.sql.types import (
    ByteType,
    DateType,
    DecimalType,
    IntegerType,
    LongType,
    ShortType,
    StringType,
    StructField,
    StructType,
)


spark = (
    SparkSession.builder
    .appName("NYC Property Master")
    .master("local[16]")
    .getOrCreate()
)


# (field name, field size, Spark data type)
fields = [
    ("PARID", 30, StringType()),
    ("BORO", 1, ByteType()),
    ("BLOCK", 5, StringType()),
    ("LOT", 4, StringType()),
    ("EASE", 1, StringType()),
    ("SUBIDENT_REUC", 10, StringType()),
    ("RECTYPE", 1, ByteType()),
    ("TAXYR", 4, ShortType()),
    ("IDENT", 10, StringType()),
    ("SUBIDENT", 10, StringType()),
    ("ROLL_SECTION", 1, ByteType()),
    ("SECVOL", 5, StringType()),

    ("PYMKTLAND", 12, LongType()),
    ("PYMKTTOT", 12, LongType()),
    ("PYACTLAND", 12, LongType()),
    ("PYACTTOT", 12, LongType()),
    ("PYACTEXTOT", 12, LongType()),
    ("PYTRNLAND", 12, LongType()),
    ("PYTRNTOT", 12, LongType()),
    ("PYTRNEXTOT", 12, LongType()),
    ("PYTXBTOT", 12, LongType()),
    ("PYTXBEXTOT", 12, LongType()),
    ("PYTAXCLASS", 2, StringType()),

    ("TENMKTLAND", 12, LongType()),
    ("TENMKTTOT", 12, LongType()),
    ("TENACTLAND", 12, LongType()),
    ("TENACTTOT", 12, LongType()),
    ("TENACTEXTOT", 12, LongType()),
    ("TENTRNLAND", 12, LongType()),
    ("TENTRNTOT", 12, LongType()),
    ("TENTRNEXTOT", 12, LongType()),
    ("TENTXBTOT", 12, LongType()),
    ("TENTXBEXTOT", 12, LongType()),
    ("TENTAXCLASS", 2, StringType()),

    ("CBNMKTLAND", 12, LongType()),
    ("CBNMKTTOT", 12, LongType()),
    ("CBNACTLAND", 12, LongType()),
    ("CBNACTTOT", 12, LongType()),
    ("CBNACTEXTOT", 12, LongType()),
    ("CBNTRNLAND", 12, LongType()),
    ("CBNTRNTOT", 12, LongType()),
    ("CBNTRNEXTOT", 12, LongType()),
    ("CBNTXBTOT", 12, LongType()),
    ("CBNTXBEXTOT", 12, LongType()),
    ("CBNTAXCLASS", 2, StringType()),

    ("FINMKTLAND", 12, LongType()),
    ("FINMKTTOT", 12, LongType()),
    ("FINACTLAND", 12, LongType()),
    ("FINACTTOT", 12, LongType()),
    ("FINACTEXTOT", 12, LongType()),
    ("FINTRNLAND", 12, LongType()),
    ("FINTRNTOT", 12, LongType()),
    ("FINTRNEXTOT", 12, LongType()),
    ("FINTXBTOT", 12, LongType()),
    ("FINTXBEXTOT", 12, LongType()),
    ("FINTAXCLASS", 2, StringType()),

    ("CURMKTLAND", 12, LongType()),
    ("CURMKTTOT", 12, LongType()),
    ("CURACTLAND", 12, LongType()),
    ("CURACTTOT", 12, LongType()),
    ("CURACTEXTOT", 12, LongType()),
    ("CURTRNLAND", 12, LongType()),
    ("CURTRNTOT", 12, LongType()),
    ("CURTRNEXTOT", 12, LongType()),
    ("CURTXBTOT", 12, LongType()),
    ("CURTXBEXTOT", 12, LongType()),
    ("CURTAXCLASS", 2, StringType()),

    ("PERIOD", 1, ByteType()),
    ("NEWDROP", 1, ByteType()),
    ("NOAV", 1, StringType()),
    ("VALREF", 1, StringType()),
    ("BLDG_CLASS", 2, StringType()),

    ("OWNER", 80, StringType()),
    ("ZONING", 10, StringType()),
    ("HOUSENUM_LO", 12, StringType()),
    ("HOUSENUM_HI", 12, StringType()),
    ("STREET_NAME", 30, StringType()),
    ("ZIP_CODE", 10, StringType()),
    ("GEOSUPPORT_RC", 2, StringType()),
    ("STCODE", 12, StringType()),

    ("LOT_FRT", 8, DecimalType(7, 2)),
    ("LOT_DEP", 8, DecimalType(7, 2)),
    ("LOT_IRREG", 1, StringType()),
    ("BLD_FRT", 8, DecimalType(7, 2)),
    ("BLD_DEP", 8, DecimalType(7, 2)),
    ("BLD_EXT", 2, StringType()),
    ("BLD_STORY", 7, DecimalType(6, 2)),
    ("CORNER", 2, StringType()),

    ("LAND_AREA", 10, LongType()),
    ("NUM_BLDGS", 6, IntegerType()),

    ("YRBUILT", 4, ShortType()),
    ("YRBUILT_RANGE", 4, ShortType()),
    ("YRBUILT_FLAG", 1, StringType()),
    ("YRALT1", 4, ShortType()),
    ("YRALT1_RANGE", 4, ShortType()),
    ("YRALT2", 4, ShortType()),
    ("YRALT2_RANGE", 4, ShortType()),

    ("COOP_APTS", 6, IntegerType()),
    ("UNITS", 6, IntegerType()),

    ("REUC_REF", 20, StringType()),
    ("APTNO", 10, StringType()),
    ("COOP_NUM", 7, StringType()),

    ("CPB_BORO", 1, ByteType()),
    ("CPB_DIST", 2, ByteType()),
    ("APPT_DATE", 8, StringType()),
    ("APPT_BORO", 1, ByteType()),
    ("APPT_BLOCK", 5, StringType()),
    ("APPT_LOT", 4, StringType()),
    ("APPT_EASE", 1, StringType()),

    ("CONDO_NUMBER", 6, StringType()),
    ("CONDO_SFX1", 1, StringType()),
    ("CONDO_SFX2", 1, StringType()),
    ("CONDO_SFX3", 1, StringType()),

    ("UAF_LAND", 12, DecimalType(10, 7)),
    ("UAF_BLDG", 12, DecimalType(10, 7)),

    ("PROTEST_1", 3, StringType()),
    ("PROTEST_2", 3, StringType()),
    ("PROTEST_OLD", 3, StringType()),

    ("ATTORNEY_GROUP1", 4, StringType()),
    ("ATTORNEY_GROUP2", 4, StringType()),
    ("ATTORNEY_GROUP_OLD", 4, StringType()),

    ("GROSS_SQFT", 10, LongType()),
    ("HOTEL_AREA_GROSS", 9, LongType()),
    ("OFFICE_AREA_GROSS", 9, LongType()),
    ("RESIDENTIAL_AREA_GROSS", 9, LongType()),
    ("RETAIL_AREA_GROSS", 9, LongType()),
    ("LOFT_AREA_GROSS", 9, LongType()),
    ("FACTORY_AREA_GROSS", 9, LongType()),
    ("WAREHOUSE_AREA_GROSS", 9, LongType()),
    ("STORAGE_AREA_GROSS", 9, LongType()),
    ("GARAGE_AREA", 9, LongType()),
    ("OTHER_AREA_GROSS", 9, LongType()),

    ("REUC_DESCRIPTION", 500, StringType()),

    ("EXTRACTDT", 8, DateType()),

    # Read T/F fields as strings first.
    ("PYTAXFLAG", 1, StringType()),
    ("TENTAXFLAG", 1, StringType()),
    ("CBNTAXFLAG", 1, StringType()),
    ("FINTAXFLAG", 1, StringType()),
    ("CURTAXFLAG", 1, StringType()),
]


schema = StructType(
    [
        StructField(name, data_type, True)
        for name, size, data_type in fields
    ]
    + [
        StructField("_TRAILING", StringType(), True)
    ]
)


path = "/home/jovyan/work/data/nyc.gov/PROPMAST_ORE_2027_FIN.txt"


df = (
    spark.read
    .option("sep", "\t")
    .option("header", False)
    .option("mode", "FAILFAST")
    .option("ignoreLeadingWhiteSpace", True)
    .option("ignoreTrailingWhiteSpace", True)
    .option("dateFormat", "yyyyMMdd")
    .schema(schema)
    .csv(path)
    .drop("_TRAILING")
)


# Convert T/F columns to Boolean.
boolean_columns = [
    "PYTAXFLAG",
    "TENTAXFLAG",
    "CBNTAXFLAG",
    "FINTAXFLAG",
    "CURTAXFLAG",
]

for column in boolean_columns:
    df = df.withColumn(
        column,
        F.when(F.col(column) == "T", F.lit(True))
        .when(F.col(column) == "A", F.lit(False))
        .when(F.col(column).isNull(), F.lit(None).cast("boolean"))
        .otherwise(
            F.raise_error(
                F.concat(
                    F.lit(f"Invalid boolean value in {column}: "),
                    F.col(column),
                )
            )
        ),
    )


# Convert T/F columns to Boolean.
boolean_columns = [
    "NOAV",
]

for column in boolean_columns:
    df = df.withColumn(
        column,
        F.when(F.col(column) == "Y", F.lit(True))
        .when(F.col(column) == "0", F.lit(False))
        .when(F.col(column).isNull(), F.lit(None).cast("boolean"))
        .otherwise(
            F.raise_error(
                F.concat(
                    F.lit(f"Invalid boolean value in {column}: "),
                    F.col(column),
                )
            )
        ),
    )        


# Validate.
print(f"Records: {df.count():,}")
print(f"Columns: {len(df.columns)}")

df.createOrReplaceTempView("property_master")
df.printSchema()
# Out:
# Records: 1,167,963
# Columns: 139
# root
#  |-- PARID: string (nullable = true)
#  |-- BORO: byte (nullable = true)
#  |-- BLOCK: string (nullable = true)
#  |-- LOT: string (nullable = true)
#  |-- EASE: string (nullable = true)
#  |-- SUBIDENT_REUC: string (nullable = true)
#  |-- RECTYPE: byte (nullable = true)
#  |-- TAXYR: short (nullable = true)
#  |-- IDENT: string (nullable = true)
#  |-- SUBIDENT: string (nullable = true)
#  |-- ROLL_SECTION: byte (nullable = true)
#  |-- SECVOL: string (nullable = true)
#  |-- PYMKTLAND: long (nullable = true)
#  |-- PYMKTTOT: long (nullable = true)
#  |-- PYACTLAND: long (nullable = true)
#  |-- PYACTTOT: long (nullable = true)
#  |-- PYACTEXTOT: long (nullable = true)
#  |-- PYTRNLAND: long (nullable = true)
#  |-- PYTRNTOT: long (nullable = true)
#  |-- PYTRNEXTOT: long (nullable = true)
#  |-- PYTXBTOT: long (nullable = true)
#  |-- PYTXBEXTOT: long (nullable = true)
#  |-- PYTAXCLASS: string (nullable = true)
#  |-- TENMKTLAND: long (nullable = true)
#  |-- TENMKTTOT: long (nullable = true)
#  |-- TENACTLAND: long (nullable = true)
#  |-- TENACTTOT: long (nullable = true)
#  |-- TENACTEXTOT: long (nullable = true)
#  |-- TENTRNLAND: long (nullable = true)
#  |-- TENTRNTOT: long (nullable = true)
#  |-- TENTRNEXTOT: long (nullable = true)
#  |-- TENTXBTOT: long (nullable = true)
#  |-- TENTXBEXTOT: long (nullable = true)
#  |-- TENTAXCLASS: string (nullable = true)
#  |-- CBNMKTLAND: long (nullable = true)
#  |-- CBNMKTTOT: long (nullable = true)
#  |-- CBNACTLAND: long (nullable = true)
#  |-- CBNACTTOT: long (nullable = true)
#  |-- CBNACTEXTOT: long (nullable = true)
#  |-- CBNTRNLAND: long (nullable = true)
#  |-- CBNTRNTOT: long (nullable = true)
#  |-- CBNTRNEXTOT: long (nullable = true)
#  |-- CBNTXBTOT: long (nullable = true)
#  |-- CBNTXBEXTOT: long (nullable = true)
#  |-- CBNTAXCLASS: string (nullable = true)
#  |-- FINMKTLAND: long (nullable = true)
#  |-- FINMKTTOT: long (nullable = true)
#  |-- FINACTLAND: long (nullable = true)
#  |-- FINACTTOT: long (nullable = true)
#  |-- FINACTEXTOT: long (nullable = true)
#  |-- FINTRNLAND: long (nullable = true)
#  |-- FINTRNTOT: long (nullable = true)
#  |-- FINTRNEXTOT: long (nullable = true)
#  |-- FINTXBTOT: long (nullable = true)
#  |-- FINTXBEXTOT: long (nullable = true)
#  |-- FINTAXCLASS: string (nullable = true)
#  |-- CURMKTLAND: long (nullable = true)
#  |-- CURMKTTOT: long (nullable = true)
#  |-- CURACTLAND: long (nullable = true)
#  |-- CURACTTOT: long (nullable = true)
#  |-- CURACTEXTOT: long (nullable = true)
#  |-- CURTRNLAND: long (nullable = true)
#  |-- CURTRNTOT: long (nullable = true)
#  |-- CURTRNEXTOT: long (nullable = true)
#  |-- CURTXBTOT: long (nullable = true)
#  |-- CURTXBEXTOT: long (nullable = true)
#  |-- CURTAXCLASS: string (nullable = true)
#  |-- PERIOD: byte (nullable = true)
#  |-- NEWDROP: byte (nullable = true)
#  |-- NOAV: boolean (nullable = true)
#  |-- VALREF: string (nullable = true)
#  |-- BLDG_CLASS: string (nullable = true)
#  |-- OWNER: string (nullable = true)
#  |-- ZONING: string (nullable = true)
#  |-- HOUSENUM_LO: string (nullable = true)
#  |-- HOUSENUM_HI: string (nullable = true)
#  |-- STREET_NAME: string (nullable = true)
#  |-- ZIP_CODE: string (nullable = true)
#  |-- GEOSUPPORT_RC: string (nullable = true)
#  |-- STCODE: string (nullable = true)
#  |-- LOT_FRT: decimal(7,2) (nullable = true)
#  |-- LOT_DEP: decimal(7,2) (nullable = true)
#  |-- LOT_IRREG: string (nullable = true)
#  |-- BLD_FRT: decimal(7,2) (nullable = true)
#  |-- BLD_DEP: decimal(7,2) (nullable = true)
#  |-- BLD_EXT: string (nullable = true)
#  |-- BLD_STORY: decimal(6,2) (nullable = true)
#  |-- CORNER: string (nullable = true)
#  |-- LAND_AREA: long (nullable = true)
#  |-- NUM_BLDGS: integer (nullable = true)
#  |-- YRBUILT: short (nullable = true)
#  |-- YRBUILT_RANGE: short (nullable = true)
#  |-- YRBUILT_FLAG: string (nullable = true)
#  |-- YRALT1: short (nullable = true)
#  |-- YRALT1_RANGE: short (nullable = true)
#  |-- YRALT2: short (nullable = true)
#  |-- YRALT2_RANGE: short (nullable = true)
#  |-- COOP_APTS: integer (nullable = true)
#  |-- UNITS: integer (nullable = true)
#  |-- REUC_REF: string (nullable = true)
#  |-- APTNO: string (nullable = true)
#  |-- COOP_NUM: string (nullable = true)
#  |-- CPB_BORO: byte (nullable = true)
#  |-- CPB_DIST: byte (nullable = true)
#  |-- APPT_DATE: string (nullable = true)
#  |-- APPT_BORO: byte (nullable = true)
#  |-- APPT_BLOCK: string (nullable = true)
#  |-- APPT_LOT: string (nullable = true)
#  |-- APPT_EASE: string (nullable = true)
#  |-- CONDO_NUMBER: string (nullable = true)
#  |-- CONDO_SFX1: string (nullable = true)
#  |-- CONDO_SFX2: string (nullable = true)
#  |-- CONDO_SFX3: string (nullable = true)
#  |-- UAF_LAND: decimal(10,7) (nullable = true)
#  |-- UAF_BLDG: decimal(10,7) (nullable = true)
#  |-- PROTEST_1: string (nullable = true)
#  |-- PROTEST_2: string (nullable = true)
#  |-- PROTEST_OLD: string (nullable = true)
#  |-- ATTORNEY_GROUP1: string (nullable = true)
#  |-- ATTORNEY_GROUP2: string (nullable = true)
#  |-- ATTORNEY_GROUP_OLD: string (nullable = true)
#  |-- GROSS_SQFT: long (nullable = true)
#  |-- HOTEL_AREA_GROSS: long (nullable = true)
#  |-- OFFICE_AREA_GROSS: long (nullable = true)
#  |-- RESIDENTIAL_AREA_GROSS: long (nullable = true)
#  |-- RETAIL_AREA_GROSS: long (nullable = true)
#  |-- LOFT_AREA_GROSS: long (nullable = true)
#  |-- FACTORY_AREA_GROSS: long (nullable = true)
#  |-- WAREHOUSE_AREA_GROSS: long (nullable = true)
#  |-- STORAGE_AREA_GROSS: long (nullable = true)
#  |-- GARAGE_AREA: long (nullable = true)
#  |-- OTHER_AREA_GROSS: long (nullable = true)
#  |-- REUC_DESCRIPTION: string (nullable = true)
#  |-- EXTRACTDT: date (nullable = true)
#  |-- PYTAXFLAG: boolean (nullable = true)
#  |-- TENTAXFLAG: boolean (nullable = true)
#  |-- CBNTAXFLAG: boolean (nullable = true)
#  |-- FINTAXFLAG: boolean (nullable = true)
#  |-- CURTAXFLAG: boolean (nullable = true)

# %%
df.cache()
# Out:
# DataFrame[PARID: string, BORO: tinyint, BLOCK: string, LOT: string, EASE: string, SUBIDENT_REUC: string, RECTYPE: tinyint, TAXYR: smallint, IDENT: string, SUBIDENT: string, ROLL_SECTION: tinyint, SECVOL: string, PYMKTLAND: bigint, PYMKTTOT: bigint, PYACTLAND: bigint, PYACTTOT: bigint, PYACTEXTOT: bigint, PYTRNLAND: bigint, PYTRNTOT: bigint, PYTRNEXTOT: bigint, PYTXBTOT: bigint, PYTXBEXTOT: bigint, PYTAXCLASS: string, TENMKTLAND: bigint, TENMKTTOT: bigint, TENACTLAND: bigint, TENACTTOT: bigint, TENACTEXTOT: bigint, TENTRNLAND: bigint, TENTRNTOT: bigint, TENTRNEXTOT: bigint, TENTXBTOT: bigint, TENTXBEXTOT: bigint, TENTAXCLASS: string, CBNMKTLAND: bigint, CBNMKTTOT: bigint, CBNACTLAND: bigint, CBNACTTOT: bigint, CBNACTEXTOT: bigint, CBNTRNLAND: bigint, CBNTRNTOT: bigint, CBNTRNEXTOT: bigint, CBNTXBTOT: bigint, CBNTXBEXTOT: bigint, CBNTAXCLASS: string, FINMKTLAND: bigint, FINMKTTOT: bigint, FINACTLAND: bigint, FINACTTOT: bigint, FINACTEXTOT: bigint, FINTRNLAND: bigint, FINTRNTOT: bigint, FINTRNEXTOT: bigint, FINTXBTOT: bigint, FINTXBEXTOT: bigint, FINTAXCLASS: string, CURMKTLAND: bigint, CURMKTTOT: bigint, CURACTLAND: bigint, CURACTTOT: bigint, CURACTEXTOT: bigint, CURTRNLAND: bigint, CURTRNTOT: bigint, CURTRNEXTOT: bigint, CURTXBTOT: bigint, CURTXBEXTOT: bigint, CURTAXCLASS: string, PERIOD: tinyint, NEWDROP: tinyint, NOAV: boolean, VALREF: string, BLDG_CLASS: string, OWNER: string, ZONING: string, HOUSENUM_LO: string, HOUSENUM_HI: string, STREET_NAME: string, ZIP_CODE: string, GEOSUPPORT_RC: string, STCODE: string, LOT_FRT: decimal(7,2), LOT_DEP: decimal(7,2), LOT_IRREG: string, BLD_FRT: decimal(7,2), BLD_DEP: decimal(7,2), BLD_EXT: string, BLD_STORY: decimal(6,2), CORNER: string, LAND_AREA: bigint, NUM_BLDGS: int, YRBUILT: smallint, YRBUILT_RANGE: smallint, YRBUILT_FLAG: string, YRALT1: smallint, YRALT1_RANGE: smallint, YRALT2: smallint, YRALT2_RANGE: smallint, COOP_APTS: int, UNITS: int, REUC_REF: string, APTNO: string, COOP_NUM: string, CPB_BORO: tinyint, CPB_DIST: tinyint, APPT_DATE: string, APPT_BORO: tinyint, APPT_BLOCK: string, APPT_LOT: string, APPT_EASE: string, CONDO_NUMBER: string, CONDO_SFX1: string, CONDO_SFX2: string, CONDO_SFX3: string, UAF_LAND: decimal(10,7), UAF_BLDG: decimal(10,7), PROTEST_1: string, PROTEST_2: string, PROTEST_OLD: string, ATTORNEY_GROUP1: string, ATTORNEY_GROUP2: string, ATTORNEY_GROUP_OLD: string, GROSS_SQFT: bigint, HOTEL_AREA_GROSS: bigint, OFFICE_AREA_GROSS: bigint, RESIDENTIAL_AREA_GROSS: bigint, RETAIL_AREA_GROSS: bigint, LOFT_AREA_GROSS: bigint, FACTORY_AREA_GROSS: bigint, WAREHOUSE_AREA_GROSS: bigint, STORAGE_AREA_GROSS: bigint, GARAGE_AREA: bigint, OTHER_AREA_GROSS: bigint, REUC_DESCRIPTION: string, EXTRACTDT: date, PYTAXFLAG: boolean, TENTAXFLAG: boolean, CBNTAXFLAG: boolean, FINTAXFLAG: boolean, CURTAXFLAG: boolean]

# %%
record_count = df.count()
print(record_count)
# Out:
# 1167963

# %%
viewdf(df)
# Out:
# <!--| quarto-html-table-processing: none -->
# <table id="itables_1828d3a8_71b9_4c14_8d33_e686212f13a5" hidden="hidden">
#   <tbody>
#     <tr>
#       <td style="vertical-align:middle; text-align:left"><a href=https://itables.org/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:var(--itables-logo-paper,#d9d7fc)">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:var(--itables-logo-ink,#1a1366);stroke:var(--itables-logo-ink,#1a1366);">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#         Loading ITables v2.9.1 from the internet...
#         (need <a href=https://itables.org/troubleshooting.html>help</a>?)
#       </td>
#     </tr>
#   </tbody>
# </table>
# <div id="itables_1828d3a8_71b9_4c14_8d33_e686212f13a5_fallback"><table style="border-collapse:collapse"><thead>    <tr style="text-align: right;">
#       <th style="border:1px solid #ddd;padding:8px"><sup><noscript><span title="JavaScript not allowed. Please trust this notebook to get interactive tables.">🔒</span></noscript><a href=https://itables.org/fallbacks/static_preview.html title="ITables v2.9.1 static preview">ⓘ</a></sup>PARID</th>
#       <th style="border:1px solid #ddd;padding:8px">BORO</th>
#       <th style="border:1px solid #ddd;padding:8px">BLOCK</th>
#       <th style="border:1px solid #ddd;padding:8px">LOT</th>
#       <th style="border:1px solid #ddd;padding:8px">EASE</th>
#       <th style="border:1px solid #ddd;padding:8px">SUBIDENT_REUC</th>
#       <th style="border:1px solid #ddd;padding:8px">RECTYPE</th>
#       <th style="border:1px solid #ddd;padding:8px">TAXYR</th>
#       <th style="border:1px solid #ddd;padding:8px">IDENT</th>
#       <th style="border:1px solid #ddd;padding:8px">SUBIDENT</th>
#       <th style="border:1px solid #ddd;padding:8px">ROLL_SECTION</th>
#       <th style="border:1px solid #ddd;padding:8px">SECVOL</th>
#       <th style="border:1px solid #ddd;padding:8px">PYMKTLAND</th>
#       <th style="border:1px solid #ddd;padding:8px">PYMKTTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">PYACTLAND</th>
#       <th style="border:1px solid #ddd;padding:8px">PYACTTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">PYACTEXTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">PYTRNLAND</th>
#       <th style="border:1px solid #ddd;padding:8px">PYTRNTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">PYTRNEXTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">PYTXBTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">PYTXBEXTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">PYTAXCLASS</th>
#       <th style="border:1px solid #ddd;padding:8px">TENMKTLAND</th>
#       <th style="border:1px solid #ddd;padding:8px">TENMKTTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">TENACTLAND</th>
#       <th style="border:1px solid #ddd;padding:8px">TENACTTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">TENACTEXTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">TENTRNLAND</th>
#       <th style="border:1px solid #ddd;padding:8px">TENTRNTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">TENTRNEXTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">TENTXBTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">TENTXBEXTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">TENTAXCLASS</th>
#       <th style="border:1px solid #ddd;padding:8px">CBNMKTLAND</th>
#       <th style="border:1px solid #ddd;padding:8px">CBNMKTTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">CBNACTLAND</th>
#       <th style="border:1px solid #ddd;padding:8px">CBNACTTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">CBNACTEXTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">CBNTRNLAND</th>
#       <th style="border:1px solid #ddd;padding:8px">CBNTRNTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">CBNTRNEXTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">CBNTXBTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">CBNTXBEXTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">CBNTAXCLASS</th>
#       <th style="border:1px solid #ddd;padding:8px">FINMKTLAND</th>
#       <th style="border:1px solid #ddd;padding:8px">FINMKTTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">FINACTLAND</th>
#       <th style="border:1px solid #ddd;padding:8px">YRBUILT_RANGE</th>
#       <th style="border:1px solid #ddd;padding:8px">YRBUILT_FLAG</th>
#       <th style="border:1px solid #ddd;padding:8px">YRALT1</th>
#       <th style="border:1px solid #ddd;padding:8px">YRALT1_RANGE</th>
#       <th style="border:1px solid #ddd;padding:8px">YRALT2</th>
#       <th style="border:1px solid #ddd;padding:8px">YRALT2_RANGE</th>
#       <th style="border:1px solid #ddd;padding:8px">COOP_APTS</th>
#       <th style="border:1px solid #ddd;padding:8px">UNITS</th>
#       <th style="border:1px solid #ddd;padding:8px">REUC_REF</th>
#       <th style="border:1px solid #ddd;padding:8px">APTNO</th>
#       <th style="border:1px solid #ddd;padding:8px">COOP_NUM</th>
#       <th style="border:1px solid #ddd;padding:8px">CPB_BORO</th>
#       <th style="border:1px solid #ddd;padding:8px">CPB_DIST</th>
#       <th style="border:1px solid #ddd;padding:8px">APPT_DATE</th>
#       <th style="border:1px solid #ddd;padding:8px">APPT_BORO</th>
#       <th style="border:1px solid #ddd;padding:8px">APPT_BLOCK</th>
#       <th style="border:1px solid #ddd;padding:8px">APPT_LOT</th>
#       <th

# %%
# Save as a managed Delta table.
table_name = "nyc_property_master"

(
    df.write
    .format("delta")
    .mode("overwrite")
    .option("overwriteSchema", "true")
    .saveAsTable(table_name)
)

# %%
# Verify the Parquet table.
df_parquet = spark.sql(f"""
    SELECT
        PARID,
        BLOCK,
        LOT,
        OWNER,
        ZONING,
        STREET_NAME,
        GROSS_SQFT,
        EXTRACTDT,
        CURTAXFLAG
    FROM {table_name}
    LIMIT 20
""")
viewdf(df_parquet)
# Out:
# <!--| quarto-html-table-processing: none -->
# <table id="itables_3a5049e7_cc63_480d_9b3e_8b2f4ca65a9e" hidden="hidden">
#   <tbody>
#     <tr>
#       <td style="vertical-align:middle; text-align:left"><a href=https://itables.org/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:var(--itables-logo-paper,#d9d7fc)">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:var(--itables-logo-ink,#1a1366);stroke:var(--itables-logo-ink,#1a1366);">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#         Loading ITables v2.9.1 from the internet...
#         (need <a href=https://itables.org/troubleshooting.html>help</a>?)
#       </td>
#     </tr>
#   </tbody>
# </table>
# <div id="itables_3a5049e7_cc63_480d_9b3e_8b2f4ca65a9e_fallback"><table style="border-collapse:collapse"><thead>    <tr style="text-align: right;">
#       <th style="border:1px solid #ddd;padding:8px"><sup><noscript><span title="JavaScript not allowed. Please trust this notebook to get interactive tables.">🔒</span></noscript><a href=https://itables.org/fallbacks/static_preview.html title="ITables v2.9.1 static preview">ⓘ</a></sup>PARID</th>
#       <th style="border:1px solid #ddd;padding:8px">BLOCK</th>
#       <th style="border:1px solid #ddd;padding:8px">LOT</th>
#       <th style="border:1px solid #ddd;padding:8px">OWNER</th>
#       <th style="border:1px solid #ddd;padding:8px">ZONING</th>
#       <th style="border:1px solid #ddd;padding:8px">STREET_NAME</th>
#       <th style="border:1px solid #ddd;padding:8px">GROSS_SQFT</th>
#       <th style="border:1px solid #ddd;padding:8px">EXTRACTDT</th>
#       <th style="border:1px solid #ddd;padding:8px">CURTAXFLAG</th>
#     </tr></thead><tbody>
# <tr><td style="border:1px solid #ddd;padding:8px">4027260047</td><td style="border:1px solid #ddd;padding:8px">02726</td><td style="border:1px solid #ddd;padding:8px">0047</td><td style="border:1px solid #ddd;padding:8px">HEATHER E. SCIACCA, TRUSTEE</td><td style="border:1px solid #ddd;padding:8px">R4B</td><td style="border:1px solid #ddd;padding:8px">59 AVENUE</td><td style="border:1px solid #ddd;padding:8px">1562</td><td style="border:1px solid #ddd;padding:8px">2026-05-15</td><td style="border:1px solid #ddd;padding:8px">True</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">4027260048</td><td style="border:1px solid #ddd;padding:8px">02726</td><td style="border:1px solid #ddd;padding:8px">0048</td><td style="border:1px solid #ddd;padding:8px">ROBERT FISCHER</td><td style="border:1px solid #ddd;padding:8px">R4B</td><td style="border:1px solid #ddd;padding:8px">59 AVENUE</td><td style="border:1px solid #ddd;padding:8px">1562</td><td style="border:1px solid #ddd;padding:8px">2026-05-15</td><td style="border:1px solid #ddd;padding:8px">True</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">4027260049</td><td style="border:1px solid #ddd;padding:8px">02726</td><td style="border:1px solid #ddd;padding:8px">0049</td><td style="border:1px solid #ddd;padding:8px">ZHU, QIN</td><td style="border:1px solid #ddd;padding:8px">R4B</td><td style="border:1px solid #ddd;padding:8px">59 AVENUE</td><td style="border:1px solid #ddd;padding:8px">1562</td><td style="border:1px solid #ddd;padding:8px">2026-05-15</td><td style="border:1px solid #ddd;padding:8px">True</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">4027260050</td><td style="border:1px solid #ddd;padding:8px">02726</td><td style="border:1px solid #ddd;padding:8px">0050</td><td style="border:1px solid #ddd;padding:8px">BARROS, SHANTAL</td><td style="border:1px solid #ddd;padding:8px">R4B</td><td style="border:1px solid #ddd;padding:8px">59 AVENUE</td><td style="border:1px solid #ddd;padding:8px">1574</td><td style="border:1px solid #ddd;padding:8px">2026-05-15</td><td style="border:1px solid #ddd;padding:8px">True</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">4027260051</td><td style="border:1px solid #ddd;padding:8px">02726</td><td style="border:1px solid #ddd;padding:8px">0051</td><td style="border:1px solid #ddd;padding:8px">DEARMAS, ORBEIN A</td><td style="border:1px solid #ddd;padding:8px">R4B</td><td style="border:1px solid #ddd;padding:8px">59 AVENUE</td><td style="border:1px solid #ddd;padding:8px">1562</td><td style="border:1px solid #ddd;padding:8px">2026-05-15</td><td style="border:1px solid #ddd;padding:8px">True</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">4027260052</td><td style="border:1px solid #ddd;padding:8px">02726</td><td style="border:1px solid #ddd;padding:8px">0052</td><td style="border:1px solid #ddd;padding:8px">VARELA, SUSAN</td><td style="border:1px solid #ddd;padding:8px">R4B</td><td style="border:1px solid #ddd;padding:8px">59 AVENUE</td><td style="border:1px solid #ddd;padding:8px">1562</td><td style="border:1px solid #ddd;padding:8px">2026-05-15</td><td style="border:1px solid #ddd;padding:8px">True</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">4027260115</td><td style="border:1px solid #ddd;padding:8px">02726</td><td style="border:1px solid #ddd;padding:8px">0115</td><td style="border:1px solid #ddd;padding:8px">S &amp; A FAMILY WEALTH LLC</td><td style="border:1px solid #ddd;padding:8px">R4B</td><td style="border:1px solid #ddd;padding:8px">FLUSHING AVENUE</td><td style="border:1px solid #ddd;padding:8px">0</td><td style="border:1px solid #ddd;padding:8px">2026-05-15</td><td style="border:1px solid #ddd;padding:8px">True</t

# %%
# %sql SELECT * FROM {table_name}
# Out:
# <!--| quarto-html-table-processing: none -->
# <table id="itables_30a46d26_e744_4471_bfce_ec092ee24505" hidden="hidden">
#   <tbody>
#     <tr>
#       <td style="vertical-align:middle; text-align:left"><a href=https://itables.org/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:var(--itables-logo-paper,#d9d7fc)">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:var(--itables-logo-ink,#1a1366);stroke:var(--itables-logo-ink,#1a1366);">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#         Loading ITables v2.9.1 from the internet...
#         (need <a href=https://itables.org/troubleshooting.html>help</a>?)
#       </td>
#     </tr>
#   </tbody>
# </table>
# <div id="itables_30a46d26_e744_4471_bfce_ec092ee24505_fallback"><table style="border-collapse:collapse"><thead>    <tr style="text-align: right;">
#       <th style="border:1px solid #ddd;padding:8px"><sup><noscript><span title="JavaScript not allowed. Please trust this notebook to get interactive tables.">🔒</span></noscript><a href=https://itables.org/fallbacks/static_preview.html title="ITables v2.9.1 static preview">ⓘ</a></sup>PARID</th>
#       <th style="border:1px solid #ddd;padding:8px">BORO</th>
#       <th style="border:1px solid #ddd;padding:8px">BLOCK</th>
#       <th style="border:1px solid #ddd;padding:8px">LOT</th>
#       <th style="border:1px solid #ddd;padding:8px">EASE</th>
#       <th style="border:1px solid #ddd;padding:8px">SUBIDENT_REUC</th>
#       <th style="border:1px solid #ddd;padding:8px">RECTYPE</th>
#       <th style="border:1px solid #ddd;padding:8px">TAXYR</th>
#       <th style="border:1px solid #ddd;padding:8px">IDENT</th>
#       <th style="border:1px solid #ddd;padding:8px">SUBIDENT</th>
#       <th style="border:1px solid #ddd;padding:8px">ROLL_SECTION</th>
#       <th style="border:1px solid #ddd;padding:8px">SECVOL</th>
#       <th style="border:1px solid #ddd;padding:8px">PYMKTLAND</th>
#       <th style="border:1px solid #ddd;padding:8px">PYMKTTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">PYACTLAND</th>
#       <th style="border:1px solid #ddd;padding:8px">PYACTTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">PYACTEXTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">PYTRNLAND</th>
#       <th style="border:1px solid #ddd;padding:8px">PYTRNTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">PYTRNEXTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">PYTXBTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">PYTXBEXTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">PYTAXCLASS</th>
#       <th style="border:1px solid #ddd;padding:8px">TENMKTLAND</th>
#       <th style="border:1px solid #ddd;padding:8px">TENMKTTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">TENACTLAND</th>
#       <th style="border:1px solid #ddd;padding:8px">TENACTTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">TENACTEXTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">TENTRNLAND</th>
#       <th style="border:1px solid #ddd;padding:8px">TENTRNTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">TENTRNEXTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">TENTXBTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">TENTXBEXTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">TENTAXCLASS</th>
#       <th style="border:1px solid #ddd;padding:8px">CBNMKTLAND</th>
#       <th style="border:1px solid #ddd;padding:8px">CBNMKTTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">CBNACTLAND</th>
#       <th style="border:1px solid #ddd;padding:8px">CBNACTTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">CBNACTEXTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">CBNTRNLAND</th>
#       <th style="border:1px solid #ddd;padding:8px">CBNTRNTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">CBNTRNEXTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">CBNTXBTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">CBNTXBEXTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">CBNTAXCLASS</th>
#       <th style="border:1px solid #ddd;padding:8px">FINMKTLAND</th>
#       <th style="border:1px solid #ddd;padding:8px">FINMKTTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">FINACTLAND</th>
#       <th style="border:1px solid #ddd;padding:8px">YRBUILT_RANGE</th>
#       <th style="border:1px solid #ddd;padding:8px">YRBUILT_FLAG</th>
#       <th style="border:1px solid #ddd;padding:8px">YRALT1</th>
#       <th style="border:1px solid #ddd;padding:8px">YRALT1_RANGE</th>
#       <th style="border:1px solid #ddd;padding:8px">YRALT2</th>
#       <th style="border:1px solid #ddd;padding:8px">YRALT2_RANGE</th>
#       <th style="border:1px solid #ddd;padding:8px">COOP_APTS</th>
#       <th style="border:1px solid #ddd;padding:8px">UNITS</th>
#       <th style="border:1px solid #ddd;padding:8px">REUC_REF</th>
#       <th style="border:1px solid #ddd;padding:8px">APTNO</th>
#       <th style="border:1px solid #ddd;padding:8px">COOP_NUM</th>
#       <th style="border:1px solid #ddd;padding:8px">CPB_BORO</th>
#       <th style="border:1px solid #ddd;padding:8px">CPB_DIST</th>
#       <th style="border:1px solid #ddd;padding:8px">APPT_DATE</th>
#       <th style="border:1px solid #ddd;padding:8px">APPT_BORO</th>
#       <th style="border:1px solid #ddd;padding:8px">APPT_BLOCK</th>
#       <th style="border:1px solid #ddd;padding:8px">APPT_LOT</th>
#       <th

# %%
# %%sql
# SELECT *
# FROM nyc_property_master
# Out:
# <!--| quarto-html-table-processing: none -->
# <table id="itables_dba4ac81_334a_4417_9f99_75fb31fdf798" hidden="hidden">
#   <tbody>
#     <tr>
#       <td style="vertical-align:middle; text-align:left"><a href=https://itables.org/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:var(--itables-logo-paper,#d9d7fc)">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:var(--itables-logo-ink,#1a1366);stroke:var(--itables-logo-ink,#1a1366);">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#         Loading ITables v2.9.1 from the internet...
#         (need <a href=https://itables.org/troubleshooting.html>help</a>?)
#       </td>
#     </tr>
#   </tbody>
# </table>
# <div id="itables_dba4ac81_334a_4417_9f99_75fb31fdf798_fallback"><table style="border-collapse:collapse"><thead>    <tr style="text-align: right;">
#       <th style="border:1px solid #ddd;padding:8px"><sup><noscript><span title="JavaScript not allowed. Please trust this notebook to get interactive tables.">🔒</span></noscript><a href=https://itables.org/fallbacks/static_preview.html title="ITables v2.9.1 static preview">ⓘ</a></sup>PARID</th>
#       <th style="border:1px solid #ddd;padding:8px">BORO</th>
#       <th style="border:1px solid #ddd;padding:8px">BLOCK</th>
#       <th style="border:1px solid #ddd;padding:8px">LOT</th>
#       <th style="border:1px solid #ddd;padding:8px">EASE</th>
#       <th style="border:1px solid #ddd;padding:8px">SUBIDENT_REUC</th>
#       <th style="border:1px solid #ddd;padding:8px">RECTYPE</th>
#       <th style="border:1px solid #ddd;padding:8px">TAXYR</th>
#       <th style="border:1px solid #ddd;padding:8px">IDENT</th>
#       <th style="border:1px solid #ddd;padding:8px">SUBIDENT</th>
#       <th style="border:1px solid #ddd;padding:8px">ROLL_SECTION</th>
#       <th style="border:1px solid #ddd;padding:8px">SECVOL</th>
#       <th style="border:1px solid #ddd;padding:8px">PYMKTLAND</th>
#       <th style="border:1px solid #ddd;padding:8px">PYMKTTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">PYACTLAND</th>
#       <th style="border:1px solid #ddd;padding:8px">PYACTTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">PYACTEXTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">PYTRNLAND</th>
#       <th style="border:1px solid #ddd;padding:8px">PYTRNTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">PYTRNEXTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">PYTXBTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">PYTXBEXTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">PYTAXCLASS</th>
#       <th style="border:1px solid #ddd;padding:8px">TENMKTLAND</th>
#       <th style="border:1px solid #ddd;padding:8px">TENMKTTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">TENACTLAND</th>
#       <th style="border:1px solid #ddd;padding:8px">TENACTTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">TENACTEXTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">TENTRNLAND</th>
#       <th style="border:1px solid #ddd;padding:8px">TENTRNTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">TENTRNEXTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">TENTXBTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">TENTXBEXTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">TENTAXCLASS</th>
#       <th style="border:1px solid #ddd;padding:8px">CBNMKTLAND</th>
#       <th style="border:1px solid #ddd;padding:8px">CBNMKTTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">CBNACTLAND</th>
#       <th style="border:1px solid #ddd;padding:8px">CBNACTTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">CBNACTEXTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">CBNTRNLAND</th>
#       <th style="border:1px solid #ddd;padding:8px">CBNTRNTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">CBNTRNEXTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">CBNTXBTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">CBNTXBEXTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">CBNTAXCLASS</th>
#       <th style="border:1px solid #ddd;padding:8px">FINMKTLAND</th>
#       <th style="border:1px solid #ddd;padding:8px">FINMKTTOT</th>
#       <th style="border:1px solid #ddd;padding:8px">FINACTLAND</th>
#       <th style="border:1px solid #ddd;padding:8px">YRBUILT_RANGE</th>
#       <th style="border:1px solid #ddd;padding:8px">YRBUILT_FLAG</th>
#       <th style="border:1px solid #ddd;padding:8px">YRALT1</th>
#       <th style="border:1px solid #ddd;padding:8px">YRALT1_RANGE</th>
#       <th style="border:1px solid #ddd;padding:8px">YRALT2</th>
#       <th style="border:1px solid #ddd;padding:8px">YRALT2_RANGE</th>
#       <th style="border:1px solid #ddd;padding:8px">COOP_APTS</th>
#       <th style="border:1px solid #ddd;padding:8px">UNITS</th>
#       <th style="border:1px solid #ddd;padding:8px">REUC_REF</th>
#       <th style="border:1px solid #ddd;padding:8px">APTNO</th>
#       <th style="border:1px solid #ddd;padding:8px">COOP_NUM</th>
#       <th style="border:1px solid #ddd;padding:8px">CPB_BORO</th>
#       <th style="border:1px solid #ddd;padding:8px">CPB_DIST</th>
#       <th style="border:1px solid #ddd;padding:8px">APPT_DATE</th>
#       <th style="border:1px solid #ddd;padding:8px">APPT_BORO</th>
#       <th style="border:1px solid #ddd;padding:8px">APPT_BLOCK</th>
#       <th style="border:1px solid #ddd;padding:8px">APPT_LOT</th>
#       <th

# %%
df = spark.sql("DESCRIBE DETAIL nyc_property_master")
viewdf(df)
# Out:
# <!--| quarto-html-table-processing: none -->
# <table id="itables_020cc978_7f05_4674_9054_1cf5991514bb" hidden="hidden">
#   <tbody>
#     <tr>
#       <td style="vertical-align:middle; text-align:left"><a href=https://itables.org/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:var(--itables-logo-paper,#d9d7fc)">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:var(--itables-logo-ink,#1a1366);stroke:var(--itables-logo-ink,#1a1366);">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#         Loading ITables v2.9.1 from the internet...
#         (need <a href=https://itables.org/troubleshooting.html>help</a>?)
#       </td>
#     </tr>
#   </tbody>
# </table>
# <div id="itables_020cc978_7f05_4674_9054_1cf5991514bb_fallback"><table style="border-collapse:collapse"><thead>    <tr style="text-align: right;">
#       <th style="border:1px solid #ddd;padding:8px"><sup><noscript><span title="JavaScript not allowed. Please trust this notebook to get interactive tables.">🔒</span></noscript><a href=https://itables.org/fallbacks/static_preview.html title="ITables v2.9.1 static preview">ⓘ</a></sup>format</th>
#       <th style="border:1px solid #ddd;padding:8px">id</th>
#       <th style="border:1px solid #ddd;padding:8px">name</th>
#       <th style="border:1px solid #ddd;padding:8px">description</th>
#       <th style="border:1px solid #ddd;padding:8px">location</th>
#       <th style="border:1px solid #ddd;padding:8px">createdAt</th>
#       <th style="border:1px solid #ddd;padding:8px">lastModified</th>
#       <th style="border:1px solid #ddd;padding:8px">partitionColumns</th>
#       <th style="border:1px solid #ddd;padding:8px">clusteringColumns</th>
#       <th style="border:1px solid #ddd;padding:8px">numFiles</th>
#       <th style="border:1px solid #ddd;padding:8px">sizeInBytes</th>
#       <th style="border:1px solid #ddd;padding:8px">properties</th>
#       <th style="border:1px solid #ddd;padding:8px">minReaderVersion</th>
#       <th style="border:1px solid #ddd;padding:8px">minWriterVersion</th>
#       <th style="border:1px solid #ddd;padding:8px">tableFeatures</th>
#     </tr></thead><tbody>
# <tr><td style="border:1px solid #ddd;padding:8px">delta</td><td style="border:1px solid #ddd;padding:8px">dbb3072d-37b7-4c4b-ae64-fd2a0d8b277f</td><td style="border:1px solid #ddd;padding:8px">spark_catalog.default.nyc_property_master</td><td style="border:1px solid #ddd;padding:8px">None</td><td style="border:1px solid #ddd;padding:8px">file:/home/jovyan/work/data/datalake/jupyter-spark-4.1/spark-4.1/delta/warehouse/nyc_property_master</td><td style="border:1px solid #ddd;padding:8px">2026-08-26 14:16:26.122</td><td style="border:1px solid #ddd;padding:8px">2026-08-26 14:16:29.636</td><td style="border:1px solid #ddd;padding:8px">[]</td><td style="border:1px solid #ddd;padding:8px">[]</td><td style="border:1px solid #ddd;padding:8px">16</td><td style="border:1px solid #ddd;padding:8px">194765425</td><td style="border:1px solid #ddd;padding:8px">{}</td><td style="border:1px solid #ddd;padding:8px">1</td><td style="border:1px solid #ddd;padding:8px">2</td><td style="border:1px solid #ddd;padding:8px">[appendOnly, invariants]</td></tr>
# </tbody></table></div><script>document.getElementById("itables_020cc978_7f05_4674_9054_1cf5991514bb")?.removeAttribute("hidden");document.getElementById("itables_020cc978_7f05_4674_9054_1cf5991514bb_fallback")?.setAttribute("hidden", "hidden");</script>
# <link href="https://www.unpkg.com/dt_for_itables@2.5.8/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import { ITable, jQuery as $ } from 'https://www.unpkg.com/dt_for_itables@2.5.8/dt_bundle.js';
#
#     document.querySelectorAll("#itables_020cc978_7f05_4674_9054_1cf5991514bb:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         let dt_args = {
#           "classes": ["display", "nowrap", "compact"],
#           "data_json": "[[\"delta\", \"dbb3072d-37b7-4c4b-ae64-fd2a0d8b277f\", \"spark_catalog.default.nyc_property_master\", \"None\", \"file:/home/jovyan/work/data/datalake/jupyter-spark-4.1/spark-4.1/delta/warehouse/nyc_property_master\", \"2026-08-26 14:16:26.122\", \"2026-08-26 14:16:29.636\", \"[]\", \"[]\", 16, 194765425, \"{}\", 1, 2, \"[appendOnly, invariants]\"]]",
#           "layout": {"bottomEnd": null, "bottomStart": null, "topEnd": null, "topStart": null},
#           "lengthMenu": [10, 25, 50, 100],
#           "order": [],
#           "pageLength": 25,
#           "scrollCollapse": true,
#           "scrollX": true,
#           "scrollY": "500px",
#           "style": {"caption-side": "bottom", "margin": "0", "table-layout": "auto", "width": "auto"},
#           "table_html": "<table><thead>\n    <tr style=\"text-align: right;\">\n      \n      <th>format</th>\n      <th>id</th>\n      <th>name</th>\n      <th>description</th>\n      <th>location</th>\n      <th>createdAt</th>\n      <th>lastModified</th>\n      <th>partitionColumns</th>\n      <th>clusteringColumns</th>\n      <th>numFiles</th>\n      <th>sizeInBytes</th>\n      <th>properties</th>\n      <th>minReaderVersion</th>\n      <th>minWriterVersion</th>\n      <th>tableFeatures</th>\n    </tr>\n  </thead></table>",
#           "text_in_header_can_be_selected": true
#         };
#         new ITable(table, dt_args);
#     });
# </script>

# %%
df = spark.sql("DESCRIBE DETAIL nyc_property_master")
location = df.select("location").first()["location"]
size_in_bytes = df.select("sizeInBytes").first()["sizeInBytes"]

location = location.removeprefix("file:")
print(f"{location} {humanize.intword(size_in_bytes)} bytes")
# Out:
# /home/jovyan/work/data/datalake/jupyter-spark-4.1/spark-4.1/delta/warehouse/nyc_
# property_master 194.8 million bytes

# %%
# !ls -lahS {location}
# Out:
# total 188M
# -rw-r--r--. 1 jovyan users  17M Aug 26 14:16 part-00001-b2627702-a11e-4888-9535-0ae569150a7b-c000.snappy.parquet
# -rw-r--r--. 1 jovyan users  17M Aug 26 14:16 part-00000-8057731b-e42f-4a91-9ec2-2c8c36eb7e38-c000.snappy.parquet
# -rw-r--r--. 1 jovyan users  15M Aug 26 14:16 part-00002-790781b6-4cb7-44ea-bfb5-cb51f87b1e5f-c000.snappy.parquet
# -rw-r--r--. 1 jovyan users  13M Aug 26 14:16 part-00005-1187160c-4ada-4807-bfb3-754a15d1912a-c000.snappy.parquet
# -rw-r--r--. 1 jovyan users  13M Aug 26 14:16 part-00006-e38bd488-100a-4503-909f-06e35d117b18-c000.snappy.parquet
# -rw-r--r--. 1 jovyan users  12M Aug 26 14:16 part-00004-b4b5b087-d5ff-48e3-8ded-40016823d126-c000.snappy.parquet
# -rw-r--r--. 1 jovyan users  12M Aug 26 14:16 part-00009-0b00143f-a7f2-48eb-a4b5-2fe944e429b8-c000.snappy.parquet
# -rw-r--r--. 1 jovyan users  11M Aug 26 14:16 part-00007-2c929c8a-2c73-49aa-8ae0-b292e561cdfe-c000.snappy.parquet
# -rw-r--r--. 1 jovyan users  11M Aug 26 14:16 part-00010-f1cdb2eb-90cd-44e6-81aa-d0864ac222a0-c000.snappy.parquet
# -rw-r--r--. 1 jovyan users  11M Aug 26 14:16 part-00003-916b0562-c5c5-4ddb-8820-8a56466942b6-c000.snappy.parquet
# -rw-r--r--. 1 jovyan users  11M Aug 26 14:16 part-00011-cd1d13c0-0759-4776-a178-e113f36c588a-c000.snappy.parquet
# -rw-r--r--. 1 jovyan users  11M Aug 26 14:16 part-00014-da2c36f0-b993-42cc-9fab-215c09a51f71-c000.snappy.parquet
# -rw-r--r--. 1 jovyan users  11M Aug 26 14:16 part-00008-21733947-7703-4cd8-b17c-df23ac0e13fa-c000.snappy.parquet
# -rw-r--r--. 1 jovyan users 9.5M Aug 26 14:16 part-00012-17e31b93-b531-4f32-a7fb-3e6bbdacd83c-c000.snappy.parquet
# -rw-r--r--. 1 jovyan users 9.3M Aug 26 14:16 part-00013-ba165618-3a33-49b5-90c8-aaeae6c3081c-c000.snappy.parquet
# -rw-r--r--. 1 jovyan users 8.8M Aug 26 14:16 part-00015-de1159e3-6959-45fb-81d8-f67b6ab8d588-c000.snappy.parquet
# -rw-r--r--. 1 jovyan users 130K Aug 26 14:16 .part-00001-b2627702-a11e-4888-9535-0ae569150a7b-c000.snappy.parquet.crc
# -rw-r--r--. 1 jovyan users 130K Aug 26 14:16 .part-00000-8057731b-e42f-4a91-9ec2-2c8c36eb7e38-c000.snappy.parquet.crc
# -rw-r--r--. 1 jovyan users 113K Aug 26 14:16 .part-00002-790781b6-4cb7-44ea-bfb5-cb51f87b1e5f-c000.snappy.parquet.crc
# -rw-r--r--. 1 jovyan users 100K Aug 26 14:16 .part-00005-1187160c-4ada-4807-bfb3-754a15d1912a-c000.snappy.parquet.crc
# -rw-r--r--. 1 jovyan users  98K Aug 26 14:16 .part-00006-e38bd488-100a-4503-909f-06e35d117b18-c000.snappy.parquet.crc
# -rw-r--r--. 1 jovyan users  96K Aug 26 14:16 .part-00004-b4b5b087-d5ff-48e3-8ded-40016823d126-c000.snappy.parquet.crc
# -rw-r--r--. 1 jovyan users  94K Aug 26 14:16 .part-00009-0b00143f-a7f2-48eb-a4b5-2fe944e429b8-c000.snappy.parquet.crc
# -rw-r--r--. 1 jovyan users  88K Aug 26 14:16 .part-00007-2c929c8a-2c73-49aa-8ae0-b292e561cdfe-c000.snappy.parquet.crc
# -rw-r--r--. 1 jovyan users  87K Aug 26 14:16 .part-00010-f1cdb2eb-90cd-44e6-81aa-d0864ac222a0-c000.snappy.parquet.crc
# -rw-r--r--. 1 jovyan users  87K Aug 26 14:16 .part-00003-916b0562-c5c5-4ddb-8820-8a56466942b6-c000.snappy.parquet.crc
# -rw-r--r--. 1 jovyan users  85K Aug 26 14:16 .part-00011-cd1d13c0-0759-4776-a178-e113f36c588a-c000.snappy.parquet.crc
# -rw-r--r--. 1 jovyan users  82K Aug 26 14:16 .part-00014-da2c36f0-b993-42cc-9fab-215c09a51f71-c000.snappy.parquet.crc
# -rw-r--r--. 1 jovyan users  82K Aug 26 14:16 .part-00008-21733947-7703-4cd8-b17c-df23ac0e13fa-c000.snappy.parquet.crc
# -rw-r--r--. 1 jovyan users  76K Aug 26 14:16 .part-00012-17e31b93-b531-4f32-a7fb-3e6bbdacd83c-c000.snappy.parquet.crc
# -rw-r--r--. 1 jovyan users  74K Aug 26 14:16 .part-00013-ba165618-3a33-49b5-90c8-aaeae6c3081c-c000.snappy.parquet.crc
# -rw-r--r--. 1 jovyan users  71K Aug 26 14:16 .part-00015-de1159e3-6959-45fb-81d8-f67b6ab8d588-c000.snappy.parquet.crc
# drwxr-xr-x. 1 jovyan users 4.4K Aug 26 14:16 .
# drwxr-xr-x. 1 jovyan users  246 Aug 26 14:16 _delta_log
# drwxr-xr-x. 1 jovyan users   38 Aug 26 14:16 ..
