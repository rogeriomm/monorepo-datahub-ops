# %%
print("hello world")
# Out:
# hello world

# %%
# !which python
# Out:
# /usr/bin/python

# %%
# !source ../.venv/bin/activate && which python
# Out:
# /var/home/rogermm/git/monorepo-datahub-ops-private/data-projects/dbt/hello-world/duckdb/.venv/bin/python

# %%
# !which python
# Out:
# /usr/bin/python

# %%
# !echo $JAVA_HOME
# Out:
# /var/home/rogermm/.local/share/mise/installs/java/21.0.2
